# %% [markdown]
# ### Import packages

# %%
import time
import itertools
import numpy as np
import pandas as pd
import lightgbm as lgb
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split

from utilities import cal_score, convert_types

# %% [markdown]
# ### Columns

# %%
cols_num = ['txn_dt', 'total_floor', 'building_complete_dt', 'parking_area', 'parking_price', 'txn_floor', 'land_area', 'building_area', 'lat', 'lon', 'village_income_median', 'town_population', 'town_area', 'town_population_density', 'doc_rate', 'master_rate', 'bachelor_rate', 'jobschool_rate', 'highschool_rate', 'junior_rate', 'elementary_rate', 'born_rate', 'death_rate', 'marriage_rate', 'divorce_rate', 'N_50', 'N_500', 'N_1000', 'N_5000', 'N_10000', 'I_10', 'I_50', 'I_100', 'I_250', 'I_500', 'I_1000', 'I_5000', 'I_10000', 'I_MIN', 'II_10', 'II_50', 'II_100', 'II_250', 'II_500', 'II_1000', 'II_5000', 'II_10000', 'II_MIN', 'III_10', 'III_50', 'III_100', 'III_250', 'III_500', 'III_1000', 'III_5000', 'III_10000', 'III_MIN', 'IV_10', 'IV_50', 'IV_100', 'IV_250', 'IV_500', 'IV_1000', 'IV_5000', 'IV_10000', 'IV_MIN', 'V_10', 'V_50', 'V_100', 'V_250', 'V_500', 'V_1000', 'V_5000', 'V_10000', 'V_MIN', 'VI_50', 'VI_100', 'VI_250', 'VI_500', 'VI_1000', 'VI_5000', 'VI_10000', 'VI_MIN', 'VII_10', 'VII_50', 'VII_100', 'VII_250', 'VII_500', 'VII_1000', 'VII_5000', 'VII_10000', 'VII_MIN', 'VIII_10', 'VIII_50', 'VIII_100', 'VIII_250', 'VIII_500', 'VIII_1000', 'VIII_5000', 'VIII_10000', 'VIII_MIN', 'IX_10', 'IX_50', 'IX_100', 'IX_250', 'IX_500', 'IX_1000', 'IX_5000', 'IX_10000', 'IX_MIN', 'X_10', 'X_50', 'X_100', 'X_250', 'X_500', 'X_1000', 'X_5000', 'X_10000', 'X_MIN', 'XI_10', 'XI_50', 'XI_100', 'XI_250', 'XI_500', 'XI_1000', 'XI_5000', 'XI_10000', 'XI_MIN', 'XII_10', 'XII_50', 'XII_100', 'XII_250', 'XII_500', 'XII_1000', 'XII_5000', 'XII_10000', 'XII_MIN', 'XIII_10', 'XIII_50', 'XIII_100', 'XIII_250', 'XIII_500', 'XIII_1000', 'XIII_5000', 'XIII_10000', 'XIII_MIN', 'XIV_10', 'XIV_50', 'XIV_100', 'XIV_250', 'XIV_500', 'XIV_1000', 'XIV_5000', 'XIV_10000', 'XIV_MIN']
cols_cat = ['building_material', 'city', 'building_type', 'building_use', 'parking_way', 'town', 'village']
cols_bin = ['I_index_50', 'I_index_500', 'I_index_1000', 'II_index_50', 'II_index_500', 'II_index_1000', 'III_index_50', 'III_index_500', 'III_index_1000', 'IV_index_50', 'IV_index_500', 'IV_index_1000', 'IV_index_5000', 'V_index_50', 'V_index_500', 'V_index_1000', 'VI_10', 'VI_index_50', 'VI_index_500', 'VI_index_1000', 'VII_index_50', 'VII_index_500', 'VII_index_1000', 'VIII_index_50', 'VIII_index_500', 'VIII_index_1000', 'IX_index_50', 'IX_index_500', 'IX_index_1000', 'IX_index_5000', 'X_index_50', 'X_index_500', 'X_index_1000', 'XI_index_50', 'XI_index_500', 'XI_index_1000', 'XI_index_5000', 'XI_index_10000', 'XII_index_50', 'XII_index_500', 'XII_index_1000', 'XIII_index_50', 'XIII_index_500', 'XIII_index_1000', 'XIII_index_5000', 'XIII_index_10000', 'XIV_index_50', 'XIV_index_500', 'XIV_index_1000']
cols_feats = cols_num + cols_cat + cols_bin

col_target = 'total_price'
col_target_log1p = 'target'

# %% [markdown]
# ### Read data

# %%
df = pd.read_csv('dataset/train.csv', dtype=object)

# %%
df.columns
# Out:
# Index(['building_id', 'building_material', 'city', 'txn_dt', 'total_floor',
#        'building_type', 'building_use', 'building_complete_dt', 'parking_way',
#        'parking_area',
#        ...
#        'XIV_500', 'XIV_index_500', 'XIV_1000', 'XIV_index_1000', 'XIV_5000',
#        'XIV_index_5000', 'XIV_10000', 'XIV_index_10000', 'XIV_MIN',
#        'total_price'],
#       dtype='object', length=235)

# %% [markdown]
# ### Preprocessing

# %%
# Convert types
df = convert_types(df, cols_num, col_target=col_target)

# Generate feats (train-test-same feats)
#create_feats(df)

# %% [markdown]
# ### Feat engineering

# %%
from feature_engineering import CategoricalColumnsEncoder

# %%
class FeatureEngineering():
    def __init__(self):
        pass
    
    def fit_transform(self, df, cols_cat, cols_bin):
        df = df.copy()
        # Denote categorical-type
        self.cat_encoder = CategoricalColumnsEncoder(mode='pandas')
        self.cat_encoder.fit_transform(df, cols_cat+cols_bin)
        return df
    
    def transform(self, df):
        df = df.copy()
        self.cat_encoder.transform(df)
        return df

# %% [markdown]
# ### Grid search

# %%
# pars
is_log1p = True # if train on log1p target
# pars

# grid search
params_fix = {'task': 'train',
              'boosting_type': 'gbdt',
              'objective': 'mse',
              'metric': 'mape',
              'learning_rate': 0.100,
              }

# %% [markdown]
# #### Round 1

# %%
t0 = time.time()

params_gsearch1 = {'num_leaves': [63, 255, 511],           # may reduce in dim-reduction exp
                   'feature_fraction': [0.5, 0.75, 1.0],
                   'min_data_in_leaf': [5, 20, 50]
                   }

gsearch = {}
folds = KFold(n_splits=3, shuffle=True, random_state=123)
for i_fold, (itrain, ival) in enumerate(folds.split(df)): # kfold
    print('==== Fold', i_fold+1, '====')
    
    # split train, val
    df_train = df.loc[itrain]
    df_val = df.loc[ival]
    
    # feat eng
    feat_eng = FeatureEngineering()
    df_train = feat_eng.fit_transform(df_train, cols_cat, cols_bin)
    df_val = feat_eng.transform(df_val)

    # Construct lgb dataset
    if is_log1p:
        lgb_train = lgb.Dataset(df_train[cols_feats], df_train['target']).construct()
        lgb_val = lgb.Dataset(df_val[cols_feats], df_val['target'], reference=lgb_train).construct()
    else:
        lgb_train = lgb.Dataset(df_train[cols_feats], df_train['total_price']).construct()
        lgb_val = lgb.Dataset(df_val[cols_feats], df_val['total_price'], reference=lgb_train).construct()
        
    # grid search
    for values in itertools.product(*[params_gsearch1[key] for key in params_gsearch1]):
        params = params_fix.copy()
        params.update( dict(zip(params_gsearch1.keys(), values)) )
        print('params:', params)

        model = lgb.train(params, lgb_train,
                          num_boost_round=10000,
                          valid_sets=lgb_val,
                          verbose_eval=2000,
                          early_stopping_rounds=200)
        y_pred = model.predict(df_val[cols_feats])
        
        if is_log1p:
            y_pred_expm1 = np.expm1(y_pred)
            y_pred_final = np.clip(y_pred_expm1, 0, None)
        else:
            y_pred_final = y_pred
            
        score = cal_score(df_val['total_price'], y_pred_final)
        tuple_params = tuple(params.items())
        gsearch[tuple_params] = gsearch.get(tuple_params, []) + [score]

# aggregate, sort gsearch results
gsearch_results1 = [[key, np.mean(val), val] for key, val in gsearch.items()]
gsearch_results1.sort(key= lambda x: x[1], reverse=True)
display(gsearch_results1)

print(f'total computing time: {time.time()-t0}')
# Out:
# ==== Fold 1 ====
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 63, 'feature_fraction': 0.5, 'min_data_in_leaf': 5}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00905288
# [4000]	valid_0's mape: 0.00898725
# [6000]	valid_0's mape: 0.00897212
# [8000]	valid_0's mape: 0.0089668
# [10000]	valid_0's mape: 0.00896467
# Did not meet early stopping. Best iteration is:
# [9999]	valid_0's mape: 0.00896466
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 63, 'feature_fraction': 0.5, 'min_data_in_leaf': 20}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00901935
# [4000]	valid_0's mape: 0.0089757
# Early stopping, best iteration is:
# [4584]	valid_0's mape: 0.00897188
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 63, 'feature_fraction': 0.5, 'min_data_in_leaf': 50}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00914908
# [4000]	valid_0's mape: 0.00911251
# [6000]	valid_0's mape: 0.00910306
# Early stopping, best iteration is:
# [6936]	valid_0's mape: 0.00910055
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 63, 'feature_fraction': 0.75, 'min_data_in_leaf': 5}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.
],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 63),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20)),
#   5219.519710122363,
#   [5224.853834340084, 5234.8554026741685, 5198.849893352834]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 511),
#    ('feature_fraction', 0.75),
#    ('min_data_in_leaf', 5)),
#   5218.853053486777,
#   [5246.853794611113, 5210.855192012056, 5198.8501738371615]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 511),
#    ('feature_fraction', 0.75),
#    ('min_data_in_leaf', 20)),
#   5217.186561867384,
#   [5228.854777291686, 5224.855196281257, 5197.8497120292095]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 255),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 50)),
#   5214.8524342423025,
#   [5226.851813869462, 5254.855237153216, 5162.850251704231]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 511),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20)),
#   5214.851679425655,
#   [5226.8524068110155, 5222.854501423771, 5194.848130042177]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 63),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 5)),
#   5213.519998942017,
#   [5227.853752650524, 5242.855936157346, 5169.85030801818]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 63),
#    ('feature_fraction', 0.5),
#    ('min_data_in_leaf', 20)),
#   5210.187826223209,
#   [5233.85634345727, 5204.855457262151, 5191.851677950209]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 63),
#    ('feature_fraction', 0.75),
#    ('min_data_in_leaf', 50)),
#   5209.854335366611,
#   [5229.855463597127, 5206.8559650111165, 5192.851577491589]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 511),
#    ('feature_fraction', 0.75),
#    ('min_data_in_leaf', 50)),
#   5195.519935323774,
#   [5220.855136792712, 5172.854111534481, 5192.85055764413]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 63),
#    ('feature_fraction', 0.5),
#    ('min_data_in_leaf', 50)),
#   5183.853422029185,
#   [5178.853990161182, 5195.855563649672, 5176.850712276699]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 255),
#    ('feature_fraction', 0.5),
#    ('min_data_in_leaf', 20)),
#   5177.51902995946,
#   [5230.854406321135, 5140.852886069244, 5160.849797487999]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 511),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 50)),
#   5171.183637307694,
#   [5172.850059539033, 5184.852416258773, 5155.848436125273]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 63),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 50)),
#   5165.852070614702,
#   [5180.852913694597, 5167.854020833191, 5148.849277316317]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 255),
#    ('feature_fraction', 0.5),
#    ('min_data_in_leaf', 50)),
#   5153.5193529581165,
#   [5202.854638409806, 5104.852804352782, 5152.850616111761]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 255),
#    ('feature_fraction', 0.5),
#    ('min_data_in_leaf', 5)),
#   5147.51873763146,
#   [5149.8538010717175, 5170.852603964346, 5121.849807858315]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 511),
#    ('feature_fraction', 0.5),
#    ('min_data_in_leaf', 50)),
#   5080.1825250447255,
#   [5124.851579528767, 5024.849011988086, 5090.846983617325]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 511),
#    ('feature_fraction', 0.5),
#    ('min_data_in_leaf', 20)),
#   5062.848379952779,
#   [5110.850335440346, 5046.8490870140695, 5030.845717403924]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 511),
#    ('feature_fraction', 0.5),
#    ('min_data_in_leaf', 5)),
#   5059.180653525371,
#   [5077.850193129019, 5032.8472114320075, 5066.844556015088]]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-5fa83a2d4a22> in <module>
#      56 display(gsearch_results1)
#      57
# ---> 58 print(f'total computing time: {time.time()-t0}')
#
# AttributeError: 'float' object has no attribute 'time'

# %% [markdown]
# #### Round 2

# %%
t0 = time.time()

params_gsearch2 = {'lambda_l1': [0, 0.01, 0.1],
                   'lambda_l2': [0, 0.01, 0.1]
                  }

gsearch = {}
folds = KFold(n_splits=3, shuffle=True, random_state=246)
for i_fold, (itrain, ival) in enumerate(folds.split(df)): # kfold
    print('==== Fold', i_fold+1, '====')
    
    # split train, val
    df_train = df.loc[itrain]
    df_val = df.loc[ival]
    
    # feat eng
    feat_eng = FeatureEngineering()
    df_train = feat_eng.fit_transform(df_train, cols_cat, cols_bin)
    df_val = feat_eng.transform(df_val)

    # Construct lgb dataset
    if is_log1p:
        lgb_train = lgb.Dataset(df_train[cols_feats], df_train['target']).construct()
        lgb_val = lgb.Dataset(df_val[cols_feats], df_val['target'], reference=lgb_train).construct()
    else:
        lgb_train = lgb.Dataset(df_train[cols_feats], df_train['total_price']).construct()
        lgb_val = lgb.Dataset(df_val[cols_feats], df_val['total_price'], reference=lgb_train).construct()
        
    # grid search
    # pick top 5 params from round 1
    for result1 in gsearch_results1[:5]:
        params1 = dict(result1[0])
        for values in itertools.product(*[params_gsearch2[key] for key in params_gsearch2]):
            params = params1.copy()
            params.update( dict(zip(params_gsearch2.keys(), values)) )
            print('params:', params)

            model = lgb.train(params, lgb_train,
                              num_boost_round=10000,
                              valid_sets=lgb_val,
                              verbose_eval=2000,
                              early_stopping_rounds=200)
            y_pred = model.predict(df_val[cols_feats])

            if is_log1p:
                y_pred_expm1 = np.expm1(y_pred)
                y_pred_final = np.clip(y_pred_expm1, 0, None)
            else:
                y_pred_final = y_pred

            score = cal_score(df_val['total_price'], y_pred_final)
            tuple_params = tuple(params.items())
            gsearch[tuple_params] = gsearch.get(tuple_params, []) + [score]

# aggregate, sort gsearch results
gsearch_results2 = [[key, np.mean(val), val] for key, val in gsearch.items()]
gsearch_results2.sort(key= lambda x: x[1], reverse=True)
display(gsearch_results2)

print(f'total computing time: {time.time()-t0}')
# Out:
# ==== Fold 1 ====
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 5, 'lambda_l1': 0, 'lambda_l2': 0}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00908757
# [4000]	valid_0's mape: 0.00908563
# [6000]	valid_0's mape: 0.0090855
# [8000]	valid_0's mape: 0.00908549
# [10000]	valid_0's mape: 0.00908549
# Did not meet early stopping. Best iteration is:
# [9999]	valid_0's mape: 0.
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 5, 'lambda_l1': 0, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00903958
# [4000]	valid_0's mape: 0.00903771
# [6000]	valid_0's mape: 0.00903763
# [8000]	valid_0's mape: 0.00903762
# Early stopping, best iteration is:
# [8783]	valid_0's mape: 0.00903762
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 5, 'lambda_l1': 0.01, 'lambda_l2': 0}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.009106
# Early stopping, best iteration is:
# [2954]	valid_0's mape: 0.00910486
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 5, 'lambda_l1': 0.01, 'lambda_l2': 0.01}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.0090296
# Early stopping, best iteration is:
# [2961]	valid_0's mape: 0.0090281
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 5, 'lambda_l1': 0.01, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00900528
# Early stopping, best iteration is:
# [2961]	valid_0's mape: 0.00900411
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.0090661
# Early stopping, best iteration is:
# [1839]	valid_0's mape: 0.00906608
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0.01}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00903018
# Early stopping, best iteration is:
# [1874]	valid_0's mape: 0.00903017
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.009008
# Early stopping, best iteration is:
# [1852]	valid_0's mape: 0.009008
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00908957
# [4000]	valid_0's mape: 0.00908804
# [6000]	valid_0's mape: 0.00908775
# [8000]	valid_0's mape: 0.00908771
# Early stopping, best iteration is:
# [8069]	valid_0's mape: 0.00908771
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0.01}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00907716
# [4000]	valid_0's mape: 0.00907518
# [6000]	valid_0's mape: 0.00907495
# [8000]	valid_0's mape: 0.00907489
# [10000]	valid_0's mape: 0.00907488
# Did not meet early stopping. Best iteration is:
# [9996]	valid_0's mape: 0.00907488
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00906091
# [4000]	valid_0's mape: 0.00905928
# [6000]	valid_0's mape: 0.00905893
# [8000]	valid_0's mape: 0.00905884
# [10000]	valid_0's mape: 0.00905882
# Did not meet early stopping. Best iteration is:
# [10000]	valid_0's mape: 0.00905882
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.01, 'lambda_l2': 0}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00901549
# Early stopping, best iteration is:
# [3446]	valid_0's mape: 0.00901433
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.01, 'lambda_l2': 0.01}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00908304
# Early stopping, best iteration is:
# [3439]	valid_0's mape: 0.00908162
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.01, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.0090582
# Early stopping, best iteration is:
# [3403]	valid_0's mape: 0.00905628
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.0090939
# Early stopping, best iteration is:
# [1920]	valid_0's mape: 0.0090939
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0.01}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00904801
# Early stopping, best iteration is:
# [1828]	valid_0's mape: 0.00904797
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00901447
# Early stopping, best iteration is:
# [1895]	valid_0's mape: 0.00901446
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 1.0, 'min_data_in_leaf': 5, 'lambda_l1': 0, 'lambda_l2': 0}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00919899
# [4000]	valid_0's mape: 0.00919813
# [6000]	valid_0's mape: 0.0091981
# Early stopping, best iteration is:
# [6333]	valid_0's mape: 0.0091981
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 1.0, 'min_data_in_leaf': 5, 'lambda_l1': 0, 'lambda_l2': 0.01}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00922438
# [4000]	valid_0's mape: 0.00922304
# [6000]	valid_0's mape: 0.00922301
# [8000]	valid_0's mape: 0.00922301
# Early stopping, best iteration is:
# [7901]	valid_0's mape: 0.00922301
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 1.0, 'min_data_in_leaf': 5, 'lambda_l1': 0, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.0091657
# [4000]	valid_0's mape: 0.00916431
# [6000]	valid_0's mape: 0.00916427
# [8000]	valid_0's mape: 0.00916426
# [10000]	valid_0's mape: 0.00916426
# Did not meet early stopping. Best iteration is:
# [10000]	valid_0's mape: 0.00916426
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 1.0, 'min_data_in_leaf': 5, 'lambda_l1': 0.01, 'lambda_l2': 0}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00919078
# Early stopping, best iteration is:
# [2839]	valid_0's mape: 0.00918977
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 1.0, 'min_data_in_leaf': 5, 'lambda_l1': 0.01, 'lambda_l2': 0.01}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00918968
# Early stopping, best iteration is:
# [2896]	valid_0's mape: 0.00918859
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 1.0, 'min_data_in_leaf': 5, 'lambda_l1': 0.01, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00916348
# Early stopping, best iteration is:
# [2783]	valid_0's mape: 0.00916243
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 1.0, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00920312
# Early stopping, best iteration is:
# [1826]	valid_0's mape: 0.00920312
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 1.0, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0.01}
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1756]	valid_0's mape: 0.00921418
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 1.0, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1773]	valid_0's mape: 0.0091951
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 50, 'lambda_l1': 0, 'lambda_l2': 0}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00912228
# Early stopping, best iteration is:
# [2171]	valid_0's mape: 0.00912175
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 50, 'lambda_l1': 0, 'lambda_l2': 0.01}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00915883
# [4000]	valid_0's mape: 0.00915701
# Early stopping, best iteration is:
# [4988]	valid_0's mape: 0.00915656
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 50, 'lambda_l1': 0, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00911627
# Early stopping, best iteration is:
# [3304]	valid_0's mape: 0.0091148
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 50, 'lambda_l1': 0.01, 'lambda_l2': 0}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00914075
# [4000]	valid_0's mape: 0.00913779
# Early stopping, best iteration is:
# [4193]	valid_0's mape: 0.00913768
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 50, 'lambda_l1': 0.01, 'lambda_l2': 0.01}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0.01}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00902462
# Early stopping, best iteration is:
# [1895]	valid_0's mape: 0.00902462
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00903591
# Early stopping, best iteration is:
# [1929]	valid_0's mape: 0.0090359
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00909639
# [4000]	valid_0's mape: 0.00909287
# [6000]	valid_0's mape: 0.00909255
# [8000]	valid_0's mape: 0.00909251
# Early stopping, best iteration is:
# [9327]	valid_0's mape: 0.0090925
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0.01}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00909039
# [4000]	valid_0's mape: 0.00908774
# [6000]	valid_0's mape: 0.00908738
# [8000]	valid_0's mape: 0.00908731
# [10000]	valid_0's mape: 0.0090873
# Did not meet early stopping. Best iteration is:
# [9974]	valid_0's mape: 0.0090873
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00905557
# [4000]	valid_0's mape: 0.00905279
# [6000]	valid_0's mape: 0.00905257
# [8000]	valid_0's mape: 0.00905254
# [10000]	valid_0's mape: 0.00905253
# Did not meet early stopping. Best iteration is:
# [9971]	valid_0's mape: 0.00905253
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.01, 'lambda_l2': 0}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00903816
# Early stopping, best iteration is:
# [3444]	valid_0's mape: 0.00903572
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.01, 'lambda_l2': 0.01}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00905242
# Early stopping, best iteration is:
# [3407]	valid_0's mape: 0.00904946
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.01, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00903161
# Early stopping, best iteration is:
# [3386]	valid_0's mape: 0.009029
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00904152
# Early stopping, best iteration is:
# [1881]	valid_0's mape: 0.00904152
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0.01}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00902319
# Early stopping, best iteration is:
# [1918]	valid_0's mape: 0.00902319
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 0.75, 'min_data_in_leaf': 20, 'lambda_l1': 0.1, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00905303
# Early stopping, best iteration is:
# [1874]	valid_0's mape: 0.00905299
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 1.0, 'min_data_in_leaf': 5, 'lambda_l1': 0, 'lambda_l2': 0}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00920615
# [4000]	valid_0's mape: 0.00920513
# [6000]	valid_0's mape: 0.0092051
# [8000]	valid_0's mape: 0.00920509
# Early stopping, best iteration is:
# [9211]	valid_0's mape: 0.00920509
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 1.0, 'min_data_in_leaf': 5, 'lambda_l1': 0, 'lambda_l2': 0.01}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00916574
# [4000]	valid_0's mape: 0.00916439
# [6000]	valid_0's mape: 0.00916436
# Early stopping, best iteration is:
# [7660]	valid_0's mape: 0.00916436
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 1.0, 'min_data_in_leaf': 5, 'lambda_l1': 0, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00920838
# [4000]	valid_0's mape: 0.00920695
# [6000]	valid_0's mape: 0.00920692
# [8000]	valid_0's mape: 0.00920692
# [10000]	valid_0's mape: 0.00920692
# Did not meet early stopping. Best iteration is:
# [10000]	valid_0's mape: 0.00920692
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 255, 'feature_fraction': 1.0, 'min_data_in_leaf': 5, 'lambda_l1': 0.01, 'lambda_l2': 0}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00914132
# Early stopping, best iteration is:
# [2832]	valid_0's mape: 0.0091403
# ...
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.0090862
# [4000]	valid_0's mape: 0.00902064
# [6000]	valid_0's mape: 0.00900849
# Early stopping, best iteration is:
# [7121]	valid_0's mape: 0.00900575
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.1, 'num_leaves': 63, 'feature_fraction': 0.75, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 200 rounds.
# [2000]	valid_0's mape: 0.00907148
# [4000]	valid_0's mape: 0.00901019
# [6000]	valid_0's mape: 0.00899802
# Early stopping, best iteration is:
# [7059]	valid_0's mape: 0.0089959
# [[(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 255),
#    ('feature_fraction', 0.75),
#    ('min_data_in_leaf', 5),
#    ('lambda_l1', 0.01),
#    ('lambda_l2', 0.01)),
#   5280.5223792655715,
#   [5272.855039949397, 5284.855721199942, 5283.856376647377]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 255),
#    ('feature_fraction', 0.75),
#    ('min_data_in_leaf', 5),
#    ('lambda_l1', 0.1),
#    ('lambda_l2', 0)),
#   5278.189105502227,
#   [5296.855836352749, 5292.855008633959, 5244.856471519973]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 63),
#    ('feature_fraction', 0.75),
#    ('min_data_in_leaf', 5),
#    ('lambda_l1', 0.01),
#    ('lambda_l2', 0.01)),
#   5277.521540321143,
#   [5278.853372049127, 5280.855076611605, 5272.856172302698]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 255),
#    ('feature_fraction', 0.75),
#    ('min_data_in_leaf', 5),
#    ('lambda_l1', 0.1),
#    ('lambda_l2', 0.01)),
#   5276.189122860165,
#   [5248.855782427668, 5302.855615979391, 5276.8559701734375]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 63),
#    ('feature_fraction', 0.75),
#    ('min_data_in_leaf', 5),
#    ('lambda_l1', 0.1),
#    ('lambda_l2', 0.1)),
#   5274.188564588755,
#   [5280.854255742593, 5262.855087021232, 5278.8563510024405]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 63),
#    ('feature_fraction', 0.75),
#    ('min_data_in_leaf', 5),
#    ('lambda_l1', 0.1),
#    ('lambda_l2', 0.01)),
#   5273.855290733801,
#   [5273.854579364364, 5256.854988679618, 5290.856304157421]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 255),
#    ('feature_fraction', 0.75),
#    ('min_data_in_leaf', 5),
#    ('lambda_l1', 0.01),
#    ('lambda_l2', 0.1)),
#   5273.522607290074,
#   [5282.856090145442, 5292.8561461602685, 5244.855585564513]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 255),
#    ('feature_fraction', 0.75),
#    ('min_data_in_leaf', 5),
#    ('lambda_l1', 0.01),
#    ('lambda_l2', 0)),
#   5272.855241479024,
#   [5238.855209857337, 5258.854301621808, 5320.856212957925]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.1),
#    ('num_leaves', 63),
#    ('feature_fraction', 0.75),
#    ('min_data_in_leaf', 5),
#    ('lambda_l1', 0.1),
#    ('lambda_l2', 0)),
#   