# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_folder = 'dataset/'

# %%
df_train = pd.read_csv(data_folder+'train.csv')
df_test = pd.read_csv(data_folder+'test.csv')

# %%
df_train.head()
# Out:
#         building_id  building_material  city  txn_dt  total_floor  \
# 0  e3mMIMR3JJqCaXz1                  8    21   18674            4
# 1  LgwzgklNvy4QCtq5                  8     7   18800            5
# 2  ucIR2NLLsC3T650L                  8     7   19289            4
# 3  jre1pJhcQj91Kdky                  8    21   20385           24
# 4  rQpYpY9nRG7X5mmr                  1    21   20657            2
#
#    building_type  building_use  building_complete_dt  parking_way  \
# 0              3             2                  6271            2
# 1              1             2                  7885            2
# 2              1             2                  6028            2
# 3              0             2                 18325            0
# 4              4             2                  6880            2
#
#    parking_area      ...       XIV_500  XIV_index_500  XIV_1000  \
# 0           NaN      ...            58              1       157
# ...

# %%
df_test.head()
# Out:
#         building_id  building_material  city  txn_dt  total_floor  \
# 0  X5gsdTWGS3W7JJQB                  1    13   18634            2
# 1  BTshNOJyKHnT2YIT                  8     7   20199           10
# 2  dhdymr0lV8N5kZOT                  8    12   19769            4
# 3  VEwyGGMcD56w5BOc                 10     7   20479           19
# 4  wmUeMoJZfsqaSX9b                  8     3   18164           13
#
#    building_type  building_use  building_complete_dt  parking_way  \
# 0              4             2                  1857            2
# 1              3             2                 16011            2
# 2              4            10                 18294            2
# 3              2             0                 17837            2
# 4              0             2                 13272            2
#
#    parking_area     ...      XIV_250  XIV_500  XIV_index_500  XIV_1000  \
# 0           NaN     ...            7       21              1       129
# ...

# %%
#df_train.info(max_cols=1000)

# %% [markdown]
# ## Price per area

# %%
df_train['log_price'] = np.log1p(df_train['total_price'])

# %%
df_train['price_per_area'] = df_train['total_price'] / df_train['building_area']

# %%
df_train['log_price_per_area'] = np.log1p(df_train['price_per_area'])

# %%
plt.figure(figsize=(12, 6))
plt.hist(df_train['price_per_area'], bins=100)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.hist(df_train['log_price_per_area'], bins=100)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.hist(df_train['log_price'], bins=100)
plt.show()
