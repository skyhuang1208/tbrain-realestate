# %% [markdown]
# - Shuffle txn_dt
# - Folk from `exp-b01-lgb-baseline-lr015`.

# %% [markdown]
# ### Import packages

# %%
import itertools
import numpy as np
import pandas as pd
import lightgbm as lgb
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split

from utilities import cal_score, convert_types
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/lightgbm/__init__.py:45: FutureWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS will be built by the Apple Clang compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you won't need to install the gcc compiler anymore.
# Instead of that, you'll need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", FutureWarning)

# %% [markdown]
# ### Columns

# %%
cols_num = ['txn_dt', 'total_floor', 'building_complete_dt', 'parking_area', 'parking_price', 'txn_floor', 'land_area', 'building_area', 'lat', 'lon', 'village_income_median', 'town_population', 'town_area', 'town_population_density', 'doc_rate', 'master_rate', 'bachelor_rate', 'jobschool_rate', 'highschool_rate', 'junior_rate', 'elementary_rate', 'born_rate', 'death_rate', 'marriage_rate', 'divorce_rate', 'N_50', 'N_500', 'N_1000', 'N_5000', 'N_10000', 'I_10', 'I_50', 'I_100', 'I_250', 'I_500', 'I_1000', 'I_5000', 'I_10000', 'I_MIN', 'II_10', 'II_50', 'II_100', 'II_250', 'II_500', 'II_1000', 'II_5000', 'II_10000', 'II_MIN', 'III_10', 'III_50', 'III_100', 'III_250', 'III_500', 'III_1000', 'III_5000', 'III_10000', 'III_MIN', 'IV_10', 'IV_50', 'IV_100', 'IV_250', 'IV_500', 'IV_1000', 'IV_5000', 'IV_10000', 'IV_MIN', 'V_10', 'V_50', 'V_100', 'V_250', 'V_500', 'V_1000', 'V_5000', 'V_10000', 'V_MIN', 'VI_50', 'VI_100', 'VI_250', 'VI_500', 'VI_1000', 'VI_5000', 'VI_10000', 'VI_MIN', 'VII_10', 'VII_50', 'VII_100', 'VII_250', 'VII_500', 'VII_1000', 'VII_5000', 'VII_10000', 'VII_MIN', 'VIII_10', 'VIII_50', 'VIII_100', 'VIII_250', 'VIII_500', 'VIII_1000', 'VIII_5000', 'VIII_10000', 'VIII_MIN', 'IX_10', 'IX_50', 'IX_100', 'IX_250', 'IX_500', 'IX_1000', 'IX_5000', 'IX_10000', 'IX_MIN', 'X_10', 'X_50', 'X_100', 'X_250', 'X_500', 'X_1000', 'X_5000', 'X_10000', 'X_MIN', 'XI_10', 'XI_50', 'XI_100', 'XI_250', 'XI_500', 'XI_1000', 'XI_5000', 'XI_10000', 'XI_MIN', 'XII_10', 'XII_50', 'XII_100', 'XII_250', 'XII_500', 'XII_1000', 'XII_5000', 'XII_10000', 'XII_MIN', 'XIII_10', 'XIII_50', 'XIII_100', 'XIII_250', 'XIII_500', 'XIII_1000', 'XIII_5000', 'XIII_10000', 'XIII_MIN', 'XIV_10', 'XIV_50', 'XIV_100', 'XIV_250', 'XIV_500', 'XIV_1000', 'XIV_5000', 'XIV_10000', 'XIV_MIN']
cols_cat = ['building_material', 'city', 'building_type', 'building_use', 'parking_way', 'town', 'village']
cols_bin = ['I_index_50', 'I_index_500', 'I_index_1000', 'II_index_50', 'II_index_500', 'II_index_1000', 'III_index_50', 'III_index_500', 'III_index_1000', 'IV_index_50', 'IV_index_500', 'IV_index_1000', 'IV_index_5000', 'V_index_50', 'V_index_500', 'V_index_1000', 'VI_10', 'VI_index_50', 'VI_index_500', 'VI_index_1000', 'VII_index_50', 'VII_index_500', 'VII_index_1000', 'VIII_index_50', 'VIII_index_500', 'VIII_index_1000', 'IX_index_50', 'IX_index_500', 'IX_index_1000', 'IX_index_5000', 'X_index_50', 'X_index_500', 'X_index_1000', 'XI_index_50', 'XI_index_500', 'XI_index_1000', 'XI_index_5000', 'XI_index_10000', 'XII_index_50', 'XII_index_500', 'XII_index_1000', 'XIII_index_50', 'XIII_index_500', 'XIII_index_1000', 'XIII_index_5000', 'XIII_index_10000', 'XIV_index_50', 'XIV_index_500', 'XIV_index_1000']
cols_feats = cols_num + cols_cat + cols_bin

col_target = 'total_price'
col_target_log1p = 'target'

# %% [markdown]
# ### Read data

# %%
df = pd.read_csv('../dataset/train.csv', dtype=object)

# %%
df.columns
# Out:
# Index(['building_id', 'building_material', 'city', 'txn_dt', 'total_floor',
#        'building_type', 'building_use', 'building_complete_dt', 'parking_way',
#        'parking_area',
#        ...
#        'XIV_500', 'XIV_index_500', 'XIV_1000', 'XIV_index_1000', 'XIV_5000',
#        'XIV_index_5000', 'XIV_10000', 'XIV_index_10000', 'XIV_MIN',
#        'total_price'],
#       dtype='object', length=235)

# %% [markdown]
# ### Preprocessing

# %%
# Convert types
df = convert_types(df, cols_num, col_target=col_target)

# Generate feats (train-test-same feats)
#create_feats(df)

# %%
# Convert bin to num
for c in cols_bin:
    df[c] = df[c].astype('int32')

# %% [markdown]
# ### Target transform

# %%
def target_transform(df):  # Add new columns inplace!!
    '''Transform the original target to the target for model to train on'''
    df['log_total_price'] = np.log1p(df['total_price'])
    return df

def target_inverse_transform(df, y_pred):
    '''Inverse transorform the model target to the original target of our problem'''
    y_pred_expm1 = np.expm1(y_pred)
    y_pred_final = np.clip(y_pred_expm1, 0, None)
    return y_pred_final

# %%
df = target_transform(df)

# %%
# transformed target fit by the model
col_model_target = 'log_total_price'
#col_model_target = 'total_price'

# %% [markdown]
# ### Feat engineering

# %%
from feature_engineering import CategoricalColumnsEncoder

# %%
class FeatureEngineering():
    def __init__(self):
        pass
    
    def fit_transform(self, df, cols_cat, cols_bin):
        df = df.copy()
        # Denote categorical-type
        self.cat_encoder = CategoricalColumnsEncoder(mode='pandas')
        self.cat_encoder.fit_transform(df, cols_cat+cols_bin)
        return df
    
    def transform(self, df):
        df = df.copy()
        self.cat_encoder.transform(df)
        return df

# %% [markdown]
# ### One run testing

# %%
# grid search
params_fix = dict((
    ('task', 'train'),
    ('boosting_type', 'gbdt'),
    ('objective', 'mse'),
    ('metric', 'mape'),
    ('learning_rate', 0.015),
    ('num_leaves', 255),
    ('feature_fraction', 0.5),
    ('min_data_in_leaf', 5),
    ('lambda_l1', 0.1),
    ('lambda_l2', 0.1)
))
lgb_other_params = {'num_boost_round': 10000,
                    'verbose_eval': 2000,
                    'early_stopping_rounds': 1000,
                   }

# %%
plt.figure(figsize=(14, 4))
plt.hist(df['txn_dt'], bins=200)
plt.show()

# %%
plt.figure(figsize=(14, 4))
sq = (df['txn_dt'].astype('int32') / 7).astype('int32')
plt.hist(sq, bins=np.arange(sq.min(), sq.max()+2, 1))
plt.show()

# %%
sq.unique()
# Out:
# array([5, 4, 1, 0, 6, 2, 3])

# %%
plt.figure(figsize=(14, 4))
sq = (df['txn_dt'].astype('int32') % 7).astype('int32')
plt.hist(sq, bins=np.arange(sq.min(), sq.max()+2, 1))
plt.show()

# %%
plt.figure(figsize=(14, 4))
sq = (df['txn_dt'].astype('int32') / 14).astype('int32')
plt.hist(sq, bins=np.arange(sq.min(), sq.max()+2, 1))
plt.show()

# %%
plt.figure(figsize=(14, 4))
sq = (df['txn_dt'].astype('int32') / 182).astype('int32')
plt.hist(sq, bins=np.arange(sq.min(), sq.max()+1, 1))
plt.show()

# %%
plt.figure(figsize=(14, 4))
sq = (df['txn_dt'].astype('int32') / 365.25).astype('int32')
plt.hist(sq, bins=np.arange(sq.min(), sq.max()+1, 1))
plt.show()

# %%
# %%time
params_gsearch1 = {'num_leaves': [255],           # may reduce in dim-reduction exp
                   }

gsearch = {}
folds = KFold(n_splits=3, shuffle=True, random_state=123)
for i_fold, (itrain, ival) in enumerate(folds.split(df)): # kfold
    print('==== Fold', i_fold+1, '====')
    
    # split train, val
    df_train = df.loc[itrain]
    df_val = df.loc[ival]
    
    # feat eng
    feat_eng = FeatureEngineering()
    # treat binary as numerical
    df_train = feat_eng.fit_transform(df_train, cols_cat, cols_bin)
    df_val = feat_eng.transform(df_val)
    # ad-hoc feature engineering - weeks in the year instead of txn_dt
    df_train['txn_dt'] = (df_train['txn_dt'] / 7).astype('int32')
    df_val['txn_dt'] = (df_val['txn_dt'] / 7).astype('int32')

    # Construct lgb dataset
    lgb_train = lgb.Dataset(df_train[cols_feats], df_train[col_model_target]).construct()
    lgb_val = lgb.Dataset(df_val[cols_feats], df_val[col_model_target], reference=lgb_train).construct()
        
    # grid search
    for values in itertools.product(*[params_gsearch1[key] for key in params_gsearch1]):
        params = params_fix.copy()
        params.update( dict(zip(params_gsearch1.keys(), values)) )
        print('params:', params)

        model = lgb.train(params, lgb_train, valid_sets=lgb_val, **lgb_other_params)

        y_pred = model.predict(df_val[cols_feats])
        
        y_pred_final = target_inverse_transform(df_val, y_pred)
            
        score = cal_score(df_val['total_price'], y_pred_final)
        print(score)
        tuple_params = tuple(params.items())
        gsearch[tuple_params] = gsearch.get(tuple_params, []) + [score]

# aggregate, sort gsearch results
gsearch_results1 = [[key, np.mean(val), val] for key, val in gsearch.items()]
gsearch_results1.sort(key= lambda x: x[1], reverse=True)
# Out:
# ==== Fold 1 ====
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.015, 'num_leaves': 255, 'feature_fraction': 0.5, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 1000 rounds.
# [2000]	valid_0's mape: 0.00864244
# [4000]	valid_0's mape: 0.00851701
# [6000]	valid_0's mape: 0.00848576
# [8000]	valid_0's mape: 0.00847373
# [10000]	valid_0's mape: 0.00846861
# Did not meet early stopping. Best iteration is:
# [9999]	valid_0's mape: 0.00846861
# 5537.864704196815
# ==== Fold 2 ====
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.015, 'num_leaves': 255, 'feature_fraction': 0.5, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 1000 rounds.
# [2000]	valid_0's mape: 0.00877379
# [4000]	valid_0's mape: 0.00865065
# [6000]	valid_0's mape: 0.00861682
# [8000]	valid_0's mape: 0.00860513
# [10000]	valid_0's mape: 0.00859922
# Did not meet early stopping. Best iteration is:
# [9991]	valid_0's mape: 0.0085992
# 5471.864434183952
# ==== Fold 3 ====
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.015, 'num_leaves': 255, 'feature_fraction': 0.5, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 1000 rounds.
# [2000]	valid_0's mape: 0.00880427
# [4000]	valid_0's mape: 0.00867755
# [6000]	valid_0's mape: 0.00864543
# [8000]	valid_0's mape: 0.00863213
# [10000]	valid_0's mape: 0.00862619
# Did not meet early stopping. Best iteration is:
# [9991]	valid_0's mape: 0.00862618
# 5484.860678456507
# CPU times: user 2h 22min 29s, sys: 1min 51s, total: 2h 24min 20s
# Wall time: 12min 44s

# %%
display(gsearch_results1)
# Out:
# [[(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.015),
#    ('num_leaves', 255),
#    ('feature_fraction', 0.5),
#    ('min_data_in_leaf', 5),
#    ('lambda_l1', 0.1),
#    ('lambda_l2', 0.1)),
#   5498.196605612425,
#   [5537.864704196815, 5471.864434183952, 5484.860678456507]]]

# %%
lgb.plot_importance(model, figsize=(12, 6), height=0.5, max_num_features=30)
plt.show()

# %%
lgb.plot_importance(model, figsize=(12, 6), height=0.5, importance_type='gain', max_num_features=30)
plt.show()

# %% [markdown]
# ### With dt diff

# %%
# %%time
params_gsearch1 = {'num_leaves': [255],           # may reduce in dim-reduction exp
                   }

gsearch = {}
folds = KFold(n_splits=3, shuffle=True, random_state=123)
for i_fold, (itrain, ival) in enumerate(folds.split(df)): # kfold
    print('==== Fold', i_fold+1, '====')
    
    # split train, val
    df_train = df.loc[itrain]
    df_val = df.loc[ival]
    
    # feat eng
    feat_eng = FeatureEngineering()
    # treat binary as numerical
    df_train = feat_eng.fit_transform(df_train, cols_cat, cols_bin)
    df_val = feat_eng.transform(df_val)
    # ad-hoc feature engineering - building age
    df_train['dt_diff'] = ((df_train['txn_dt'] - df_train['building_complete_dt']) / 30).astype('int32')
    df_val['dt_diff'] = ((df_val['txn_dt'] - df_val['building_complete_dt']) / 30).astype('int32')

    # Construct lgb dataset
    lgb_train = lgb.Dataset(df_train[cols_feats+['dt_diff']], df_train[col_model_target]).construct()
    lgb_val = lgb.Dataset(df_val[cols_feats+['dt_diff']], df_val[col_model_target], reference=lgb_train).construct()
        
    # grid search
    for values in itertools.product(*[params_gsearch1[key] for key in params_gsearch1]):
        params = params_fix.copy()
        params.update( dict(zip(params_gsearch1.keys(), values)) )
        print('params:', params)

        model = lgb.train(params, lgb_train, valid_sets=lgb_val, **lgb_other_params)

        y_pred = model.predict(df_val[cols_feats+['dt_diff']])
        
        y_pred_final = target_inverse_transform(df_val, y_pred)
            
        score = cal_score(df_val['total_price'], y_pred_final)
        print(score)
        tuple_params = tuple(params.items())
        gsearch[tuple_params] = gsearch.get(tuple_params, []) + [score]

# aggregate, sort gsearch results
gsearch_results1 = [[key, np.mean(val), val] for key, val in gsearch.items()]
gsearch_results1.sort(key= lambda x: x[1], reverse=True)
# Out:
# ==== Fold 1 ====
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.015, 'num_leaves': 255, 'feature_fraction': 0.5, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 1000 rounds.
# [2000]	valid_0's mape: 0.00865936
# [4000]	valid_0's mape: 0.00852972
# [6000]	valid_0's mape: 0.00849762
# [8000]	valid_0's mape: 0.00848653
# [10000]	valid_0's mape: 0.00848141
# Did not meet early stopping. Best iteration is:
# [10000]	valid_0's mape: 0.00848141
# 5535.864545149495
# ==== Fold 2 ====
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.015, 'num_leaves': 255, 'feature_fraction': 0.5, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 1000 rounds.
# [2000]	valid_0's mape: 0.00877377
# [4000]	valid_0's mape: 0.0086489
# [6000]	valid_0's mape: 0.00861855
# [8000]	valid_0's mape: 0.00860727
# [10000]	valid_0's mape: 0.00860217
# Did not meet early stopping. Best iteration is:
# [9998]	valid_0's mape: 0.00860217
# 5470.864520734769
# ==== Fold 3 ====
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.015, 'num_leaves': 255, 'feature_fraction': 0.5, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 1000 rounds.
# [2000]	valid_0's mape: 0.00878739
# [4000]	valid_0's mape: 0.00865547
# [6000]	valid_0's mape: 0.00862084
# [8000]	valid_0's mape: 0.00860756
# [10000]	valid_0's mape: 0.0086012
# Did not meet early stopping. Best iteration is:
# [10000]	valid_0's mape: 0.0086012
# 5543.861271398042
# CPU times: user 2h 23min 29s, sys: 1min 50s, total: 2h 25min 19s
# Wall time: 12min 49s

# %%
(0.00848141 + 0.00860217 + 0.0086012)/3
# Out:
# 0.008561593333333334

# %%
display(gsearch_results1)
# Out:
# [[(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.015),
#    ('num_leaves', 255),
#    ('feature_fraction', 0.5),
#    ('min_data_in_leaf', 5),
#    ('lambda_l1', 0.1),
#    ('lambda_l2', 0.1)),
#   5516.8634457607695,
#   [5535.864545149495, 5470.864520734769, 5543.861271398042]]]

# %%
lgb.plot_importance(model, figsize=(12, 6), height=0.5, max_num_features=30)
plt.show()

# %%
lgb.plot_importance(model, figsize=(12, 6), height=0.5, importance_type='gain', max_num_features=30)
plt.show()

# %% [markdown]
# ### With height ratio

# %%
# %%time
params_gsearch1 = {'num_leaves': [255],           # may reduce in dim-reduction exp
                   }

gsearch = {}
folds = KFold(n_splits=3, shuffle=True, random_state=123)
for i_fold, (itrain, ival) in enumerate(folds.split(df)): # kfold
    print('==== Fold', i_fold+1, '====')
    
    # split train, val
    df_train = df.loc[itrain]
    df_val = df.loc[ival]
    
    # feat eng
    feat_eng = FeatureEngineering()
    # treat binary as numerical
    df_train = feat_eng.fit_transform(df_train, cols_cat, cols_bin)
    df_val = feat_eng.transform(df_val)
    # ad-hoc feature engineering - height ratio
    df_train['height_r'] = df_train['txn_floor'] / df_train['total_floor']
    df_val['height_r'] = df_val['txn_floor'] / df_val['total_floor']

    # Construct lgb dataset
    lgb_train = lgb.Dataset(df_train[cols_feats+['height_r']], df_train[col_model_target]).construct()
    lgb_val = lgb.Dataset(df_val[cols_feats+['height_r']], df_val[col_model_target], reference=lgb_train).construct()
        
    # grid search
    for values in itertools.product(*[params_gsearch1[key] for key in params_gsearch1]):
        params = params_fix.copy()
        params.update( dict(zip(params_gsearch1.keys(), values)) )
        print('params:', params)

        model = lgb.train(params, lgb_train, valid_sets=lgb_val, **lgb_other_params)

        y_pred = model.predict(df_val[cols_feats+['height_r']])
        
        y_pred_final = target_inverse_transform(df_val, y_pred)
            
        score = cal_score(df_val['total_price'], y_pred_final)
        print(score)
        tuple_params = tuple(params.items())
        gsearch[tuple_params] = gsearch.get(tuple_params, []) + [score]

# aggregate, sort gsearch results
gsearch_results1 = [[key, np.mean(val), val] for key, val in gsearch.items()]
gsearch_results1.sort(key= lambda x: x[1], reverse=True)
# Out:
# ==== Fold 1 ====
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.015, 'num_leaves': 255, 'feature_fraction': 0.5, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 1000 rounds.
# [2000]	valid_0's mape: 0.00864621
# [4000]	valid_0's mape: 0.0085212
# [6000]	valid_0's mape: 0.00848985
# [8000]	valid_0's mape: 0.00847901
# [10000]	valid_0's mape: 0.00847439
# Did not meet early stopping. Best iteration is:
# [10000]	valid_0's mape: 0.00847439
# 5528.8644841935065
# ==== Fold 2 ====
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.015, 'num_leaves': 255, 'feature_fraction': 0.5, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 1000 rounds.
# [2000]	valid_0's mape: 0.00872548
# [4000]	valid_0's mape: 0.00860425
# [6000]	valid_0's mape: 0.00857398
# [8000]	valid_0's mape: 0.00856242
# [10000]	valid_0's mape: 0.0085573
# Did not meet early stopping. Best iteration is:
# [9997]	valid_0's mape: 0.0085573
# 5508.865244005094
# ==== Fold 3 ====
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.015, 'num_leaves': 255, 'feature_fraction': 0.5, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 1000 rounds.
# [2000]	valid_0's mape: 0.00877956
# [4000]	valid_0's mape: 0.0086484
# [6000]	valid_0's mape: 0.00861469
# [8000]	valid_0's mape: 0.00860156
# [10000]	valid_0's mape: 0.00859552
# Did not meet early stopping. Best iteration is:
# [10000]	valid_0's mape: 0.00859552
# 5522.861203712341
# CPU times: user 2h 21min 51s, sys: 1min 32s, total: 2h 23min 23s
# Wall time: 12min 32s

# %%
(0.00847439 + 0.0085573 + 0.00859552)/3
# Out:
# 0.008542403333333335

# %%
display(gsearch_results1)
# Out:
# [[(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.015),
#    ('num_leaves', 255),
#    ('feature_fraction', 0.5),
#    ('min_data_in_leaf', 5),
#    ('lambda_l1', 0.1),
#    ('lambda_l2', 0.1)),
#   5520.196977303647,
#   [5528.8644841935065, 5508.865244005094, 5522.861203712341]]]

# %%
lgb.plot_importance(model, figsize=(12, 6), height=0.5, max_num_features=30)
plt.show()

# %%
lgb.plot_importance(model, figsize=(12, 6), height=0.5, importance_type='gain', max_num_features=30)
plt.show()

# %% [markdown]
# ### Baseline

# %%
# grid search
params_fix = dict((
    ('task', 'train'),
    ('boosting_type', 'gbdt'),
    ('objective', 'mse'),
    ('metric', 'mape'),
    ('learning_rate', 0.015),
    ('num_leaves', 255),
    ('feature_fraction', 0.5),
    ('min_data_in_leaf', 5),
    ('lambda_l1', 0.1),
    ('lambda_l2', 0.1)
))
lgb_other_params = {'num_boost_round': 10000,
                    'verbose_eval': 2000,
                    'early_stopping_rounds': 1000,
                   }

# %%
# %%time
params_gsearch1 = {'num_leaves': [255],           # may reduce in dim-reduction exp
                   }

gsearch = {}
folds = KFold(n_splits=3, shuffle=True, random_state=123)
for i_fold, (itrain, ival) in enumerate(folds.split(df)): # kfold
    print('==== Fold', i_fold+1, '====')
    
    # split train, val
    df_train = df.loc[itrain]
    df_val = df.loc[ival]
    
    # feat eng
    feat_eng = FeatureEngineering()
    # treat binary as categorical
    df_train = feat_eng.fit_transform(df_train, cols_cat, cols_bin=cols_bin)
    df_val = feat_eng.transform(df_val)

    # Construct lgb dataset
    lgb_train = lgb.Dataset(df_train[cols_feats], df_train[col_model_target]).construct()
    lgb_val = lgb.Dataset(df_val[cols_feats], df_val[col_model_target], reference=lgb_train).construct()
        
    # grid search
    for values in itertools.product(*[params_gsearch1[key] for key in params_gsearch1]):
        params = params_fix.copy()
        params.update( dict(zip(params_gsearch1.keys(), values)) )
        print('params:', params)

        model = lgb.train(params, lgb_train, valid_sets=lgb_val, **lgb_other_params)

        y_pred = model.predict(df_val[cols_feats])
        
        y_pred_final = target_inverse_transform(df_val, y_pred)
            
        score = cal_score(df_val['total_price'], y_pred_final)
        print(score)
        tuple_params = tuple(params.items())
        gsearch[tuple_params] = gsearch.get(tuple_params, []) + [score]

# aggregate, sort gsearch results
gsearch_results1 = [[key, np.mean(val), val] for key, val in gsearch.items()]
gsearch_results1.sort(key= lambda x: x[1], reverse=True)
# Out:
# ==== Fold 1 ====
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.015, 'num_leaves': 255, 'feature_fraction': 0.5, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 1000 rounds.
# [2000]	valid_0's mape: 0.00864723
# [4000]	valid_0's mape: 0.00852551
# [6000]	valid_0's mape: 0.00849339
# [8000]	valid_0's mape: 0.00848205
# [10000]	valid_0's mape: 0.00847767
# Did not meet early stopping. Best iteration is:
# [10000]	valid_0's mape: 0.00847767
# 5533.864596386099
# ==== Fold 2 ====
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.015, 'num_leaves': 255, 'feature_fraction': 0.5, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 1000 rounds.
# [2000]	valid_0's mape: 0.00877073
# [4000]	valid_0's mape: 0.00864796
# [6000]	valid_0's mape: 0.00861686
# [8000]	valid_0's mape: 0.00860554
# [10000]	valid_0's mape: 0.00860066
# Did not meet early stopping. Best iteration is:
# [9999]	valid_0's mape: 0.00860065
# 5488.864347820807
# ==== Fold 3 ====
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'metric': 'mape', 'learning_rate': 0.015, 'num_leaves': 255, 'feature_fraction': 0.5, 'min_data_in_leaf': 5, 'lambda_l1': 0.1, 'lambda_l2': 0.1}
# Training until validation scores don't improve for 1000 rounds.
# [2000]	valid_0's mape: 0.00878881
# [4000]	valid_0's mape: 0.00866038
# [6000]	valid_0's mape: 0.00862511
# [8000]	valid_0's mape: 0.00861186
# [10000]	valid_0's mape: 0.00860639
# Did not meet early stopping. Best iteration is:
# [10000]	valid_0's mape: 0.00860639
# 5502.860967304766
# CPU times: user 2h 29min 10s, sys: 2min 17s, total: 2h 31min 28s
# Wall time: 13min 31s

# %%
(0.00847767 + 0.00860065 + 0.00860639)/3
# Out:
# 0.00856157

# %%
display(gsearch_results1)
# Out:
# [[(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('metric', 'mape'),
#    ('learning_rate', 0.015),
#    ('num_leaves', 255),
#    ('feature_fraction', 0.5),
#    ('min_data_in_leaf', 5),
#    ('lambda_l1', 0.1),
#    ('lambda_l2', 0.1)),
#   5508.52997050389,
#   [5533.864596386099, 5488.864347820807, 5502.860967304766]]]

# %% [markdown]
# Not much difference

# %% [markdown]
# ### Other info

# %%
lgb.plot_importance(model, figsize=(12, 30), height=0.5)
plt.show()

# %%
lgb.plot_importance(model, figsize=(12, 30), height=0.5, importance_type='gain')
plt.show()
