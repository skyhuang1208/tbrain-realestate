# %% [markdown]
# ### Import packages

# %%
import time
import pickle
import itertools
import numpy as np
import pandas as pd
import lightgbm as lgb
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from utilities import *

# %%
model_name = 'model-07-keras-embedding'

# %% [markdown]
# ### Params

# %%
is_log_target = True
is_per_area_target = True
is_embedding = True
is_tar_encoded = False

map_target = {
    (True, True):   'log_per_area_total_price',
    (True, False):  'log_total_price',
    (False, True):  'per_area_total_price',
    (False, False): 'total_price'
}
col_target = map_target[(is_log_target, is_per_area_target)]
cols_num_add = ['land_per_building_area']
cols_cat_add = ['encoded_latlon']
cols_bin_add = []

# cols_feats_add = ['encoded_latlon', 'building_per_land_area'] # add feats into model
cols_feats_rm = [] # TODO: implement before using it
#['day_in_year_txn_dt', 'day_in_year_building_complete_dt', 'dt_diff_building_complete_dt_txn_dt'] # dt num feats
#['dow_txn_dt', 'dow_building_complete_dt', 'month_txn_dt', 'month_building_complete_dt',
# 'quarter_txn_dt', 'quarter_building_complete_dt', 'year_txn_dt', 'year_building_complete_dt'] # dt cat feats

rare_village_threshold = 1
rare_town_threshold = 1

print('Target:', col_target)
# Out:
# Target: log_per_area_total_price

# %% [markdown]
# ### Columns

# %%
cols_num = ['txn_dt', 'total_floor', 'building_complete_dt', 'parking_area', 'parking_price', 'txn_floor', 'land_area', 'building_area', 'lat', 'lon', 'village_income_median', 'town_population', 'town_area', 'town_population_density', 'doc_rate', 'master_rate', 'bachelor_rate', 'jobschool_rate', 'highschool_rate', 'junior_rate', 'elementary_rate', 'born_rate', 'death_rate', 'marriage_rate', 'divorce_rate', 'N_50', 'N_500', 'N_1000', 'N_5000', 'N_10000', 'I_10', 'I_50', 'I_100', 'I_250', 'I_500', 'I_1000', 'I_5000', 'I_10000', 'I_MIN', 'II_10', 'II_50', 'II_100', 'II_250', 'II_500', 'II_1000', 'II_5000', 'II_10000', 'II_MIN', 'III_10', 'III_50', 'III_100', 'III_250', 'III_500', 'III_1000', 'III_5000', 'III_10000', 'III_MIN', 'IV_10', 'IV_50', 'IV_100', 'IV_250', 'IV_500', 'IV_1000', 'IV_5000', 'IV_10000', 'IV_MIN', 'V_10', 'V_50', 'V_100', 'V_250', 'V_500', 'V_1000', 'V_5000', 'V_10000', 'V_MIN', 'VI_50', 'VI_100', 'VI_250', 'VI_500', 'VI_1000', 'VI_5000', 'VI_10000', 'VI_MIN', 'VII_10', 'VII_50', 'VII_100', 'VII_250', 'VII_500', 'VII_1000', 'VII_5000', 'VII_10000', 'VII_MIN', 'VIII_10', 'VIII_50', 'VIII_100', 'VIII_250', 'VIII_500', 'VIII_1000', 'VIII_5000', 'VIII_10000', 'VIII_MIN', 'IX_10', 'IX_50', 'IX_100', 'IX_250', 'IX_500', 'IX_1000', 'IX_5000', 'IX_10000', 'IX_MIN', 'X_10', 'X_50', 'X_100', 'X_250', 'X_500', 'X_1000', 'X_5000', 'X_10000', 'X_MIN', 'XI_10', 'XI_50', 'XI_100', 'XI_250', 'XI_500', 'XI_1000', 'XI_5000', 'XI_10000', 'XI_MIN', 'XII_10', 'XII_50', 'XII_100', 'XII_250', 'XII_500', 'XII_1000', 'XII_5000', 'XII_10000', 'XII_MIN', 'XIII_10', 'XIII_50', 'XIII_100', 'XIII_250', 'XIII_500', 'XIII_1000', 'XIII_5000', 'XIII_10000', 'XIII_MIN', 'XIV_10', 'XIV_50', 'XIV_100', 'XIV_250', 'XIV_500', 'XIV_1000', 'XIV_5000', 'XIV_10000', 'XIV_MIN']
cols_bin = ['I_index_50', 'I_index_500', 'I_index_1000', 'II_index_50', 'II_index_500', 'II_index_1000', 'III_index_50', 'III_index_500', 'III_index_1000', 'IV_index_50', 'IV_index_500', 'IV_index_1000', 'IV_index_5000', 'V_index_50', 'V_index_500', 'V_index_1000', 'VI_10', 'VI_index_50', 'VI_index_500', 'VI_index_1000', 'VII_index_50', 'VII_index_500', 'VII_index_1000', 'VIII_index_50', 'VIII_index_500', 'VIII_index_1000', 'IX_index_50', 'IX_index_500', 'IX_index_1000', 'IX_index_5000', 'X_index_50', 'X_index_500', 'X_index_1000', 'XI_index_50', 'XI_index_500', 'XI_index_1000', 'XI_index_5000', 'XI_index_10000', 'XII_index_50', 'XII_index_500', 'XII_index_1000', 'XIII_index_50', 'XIII_index_500', 'XIII_index_1000', 'XIII_index_5000', 'XIII_index_10000', 'XIV_index_50', 'XIV_index_500', 'XIV_index_1000']
cols_cat = ['building_material', 'city', 'building_type', 'building_use', 'parking_way', 'town', 'village']

cols_num = [c for c in cols_num if c not in cols_feats_rm]
cols_bin = [c for c in cols_bin if c not in cols_feats_rm]
cols_cat = [c for c in cols_cat if c not in cols_feats_rm]

# informational cols
cols_dt = ['txn_dt', 'building_complete_dt']

# right skew cols
#cols_right_skew = ['parking_area', 'land_area', 'building_area']+[c for c in cols_num if 'MIN' in c]

print('Num:', len(cols_num), 'Bin:', len(cols_bin), 'Cat:', len(cols_cat))
print('Add:', len(cols_num_add), len(cols_bin_add), len(cols_cat_add))
#print('Right skew:', cols_right_skew)
#print('Total:', len(cols_feats))
# Out:
# Num: 155 Bin: 49 Cat: 7
# Add: 1 0 1

# %% [markdown]
# ### Read data

# %%
train = pd.read_csv('dataset/train.csv', dtype=object)
test = pd.read_csv('dataset/test.csv', dtype=object)
train.head(5)
test.head(5)

id_cv = []
for i in range(5):
    id_one_fold = pd.read_csv(f'dataset/id_cv{i}.csv', dtype=object)['building_id']
    id_cv.append(id_one_fold)

# %% [markdown]
# ### Preprocessing

# %%
def pre_processing(df, cols_num, cols_cat, cols_bin):
    """Preprocess (inplace) that are independent of train and validatoin set"""
    # Convert types
    df[cols_num] = df[cols_num].astype('float32')
    df[cols_bin] = df[cols_bin].astype('float32')
    df[cols_cat] = df[cols_cat].astype('int32')
    
    # target transform base (store this for inverse transform)
    if is_per_area_target:
        df['building_area_ori'] = df['building_area']
    
    # generate target
    if 'total_price' in df:
        df['total_price'] = df['total_price'].astype('float32')
        df['log_total_price'] = np.log1p(df['total_price'])
        df['per_area_total_price'] = df['total_price'] / df['building_area_ori']
        df['log_per_area_total_price'] = np.log1p(df['per_area_total_price'])
        df['target'] = df[col_target]

    # generate lat/lon encoded
    kmeans = pickle.load(open('./object_kmeans_k6_combined.pkl', 'rb'))
    df['encoded_latlon'] = kmeans.predict(df[['lat','lon']])
    
    # generate dt feats
    df = create_dt_feats(df, 'txn_dt')
    df = create_dt_feats(df, 'building_complete_dt')
    df['dt_diff_building_complete_dt_txn_dt'] = df['txn_dt'] - df['building_complete_dt']
    
    # generate building to land ratio
    df['land_per_building_area'] = df['land_area'] / df['building_area']
    
    # label for stratified train test split
    #df['stratified'] = 
    
    return df

# %%
def post_processing(y_pred, df):
    """Post processing target
       Args: 
          y_pred (1d np.array): raw prediction y
          df (pd.Dataframe): input feature df
       Return: np.array
    """
    y_pred_final = y_pred.copy()
    
    if is_log_target:
        y_pred_final = np.expm1(y_pred_final)
        y_pred_final = np.clip(y_pred_final, 0, None)

    if is_per_area_target:
        y_pred_final = y_pred_final * df['building_area_ori'].values
        
    return y_pred_final

# %%
train = pre_processing(train, cols_num, cols_cat, cols_bin)
test = pre_processing(test, cols_num, cols_cat, cols_bin)
# Out:
# c:\python36\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator KMeans from version 0.20.3 when using version 0.21.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# c:\python36\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator KMeans from version 0.20.3 when using version 0.21.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
# Add those added feature columns (run this after preprocess has done)
cols_num = cols_num + [c for c in cols_num_add if c not in cols_num]
cols_cat = cols_cat + [c for c in cols_cat_add if c not in cols_cat]
cols_bin = cols_bin + [c for c in cols_bin_add if c not in cols_bin]
cols_feats = cols_num + cols_cat + cols_bin
print('Feat columns:', len(cols_feats))

# Target mean encoded columns
cols_tar_encoded = ['encoded_'+c for c in cols_cat] if is_tar_encoded else []
    
print('\nTarget mean encoded columns:', len(cols_tar_encoded))

# Compute skew columns
cols_right_skew = [c for c in cols_num if train[c].skew() > 2.2]
print('\nRight skew columns:', len(cols_right_skew))

# Fillna values for null columns
fillna_values = {
    'parking_area': -1.,
    'parking_price': -1.,
    'txn_floor': 0.,
    #'village_income_median': 'median',
}
# Out:
# Feat columns: 213
#
# Target mean encoded columns: 0
#
# Right skew columns: 77

# %% [markdown]
# ### Feature engineering
# Include cat encoding, fillna, scaling

# %%
from feature_engineering import CategoricalColumnsEncoder
from feature_engineering import TargetMeanEncoding
from feature_engineering import MultiLabelEncoding
from feature_engineering import PdStandardScaler, PdMedianScaler, PdMinMaxScaler

# %%
class FeatureEngineering():
    def __init__(self, cols_num, cols_cat, cols_bin, col_target, 
                 fillna_values={}, cols_right_skew=[], is_embedding=False, is_tar_encoded=True,
                 n_ran_encode=4, rare_village_threshold=1, rare_town_threshold=1):
        # Cols
        self.cols_num = cols_num
        self.cols_cat = cols_cat
        self.cols_bin = cols_bin
        self.col_target = col_target
        self.cols_right_skew = cols_right_skew
        
        # Numbers
        #self.n_ran_encode = n_ran_encode
        
        # Cat encoders
        self.is_tar_encoded = is_tar_encoded
        if is_tar_encoded:
            self.tar_encoder = TargetMeanEncoding(col_target = self.col_target)
        #self.ran_encoder = MultiLabelEncoding(self.n_ran_encode)
        self.is_embedding = is_embedding
        if is_embedding:
            self.cat_astyper = CategoricalColumnsEncoder(mode='keras', reserve_missing=True)
        
        # Fillna
        self.fillna_values = fillna_values
        
        # Skewness
        self.mins_right_skew_cols = {}  # map from the col name to the original min
        
        # Normalization
        self.scaler = PdStandardScaler()
        
        # Target normalization
        self.target_scaler = PdStandardScaler()
        
        # Rare village and town threshold
        self.rare_village_threshold = rare_village_threshold
        self.rare_town_threshold = rare_town_threshold
        
    def fit_transform(self, df, df_test):
        df = df.copy()
        
        # Rare village and town
        train_towns = df['town'].value_counts()
        rare_towns = (set(train_towns.index[train_towns <= self.rare_town_threshold])
                      - set(df_test['town']))
        df.loc[df['town'].isin(rare_towns), 'town'] = np.nan
        
        train_villages = df['village'].value_counts()        
        rare_villages = (set(train_villages.index[train_villages <= self.rare_village_threshold])
                         - set(df_test['village']))
        df.loc[df['village'].isin(rare_villages), 'village'] = np.nan        
        
        # Cat encoders
        if self.is_tar_encoded:
            df_tar_encoded = self.tar_encoder.fit_transform(df[self.cols_cat], df[self.col_target])
            self.cols_tar_encoded = [c for c in df_tar_encoded]
            for c in df_tar_encoded:
                df[c] = df_tar_encoded[c].astype('float32')
        else:
            self.cols_tar_encoded = []
        #encoded2 = self.ran_encoder.fit_transform(df[self.cols_cat])
        if self.is_embedding:
            self.cat_astyper.fit_transform(df, self.cols_cat)
        
        # Fillna
        self.fillna_values['village_income_median'] = df['village_income_median'].median()
        for c, v in self.fillna_values.items():
            df[c] = df[c].fillna(v)
    
        # Skewness
        for c in self.cols_right_skew:
            # if the minimum of the col < 0, then subtract the min first (to make it positive)
            self.mins_right_skew_cols[c] = min(df[c].min(), 0)
            df[c] = np.log10(0.1 + df[c] - self.mins_right_skew_cols[c]).astype('float32')
    
        # Normalization
        self.scaler.fit(df, cols=self.cols_num+self.cols_tar_encoded)
        self.scaler.transform(df)  # transform inplace!
        
        # Target normalization
        assert self.col_target in df, 'Target column not found in the dataframe'
        self.target_scaler.fit(df, cols=[self.col_target])
        self.target_scaler.transform(df, cols_input=[self.col_target], cols_transformed=[self.col_target+'_scaled'])
        
        return df
        #return pd.concat([df, encoded1, encoded2], axis=1)
    
    def transform(self, df):
        df = df.copy()
        # Cat encoders
        if self.is_tar_encoded:
            df_tar_encoded = self.tar_encoder.transform(df[self.cols_cat])
            for c in df_tar_encoded:
                df[c] = df_tar_encoded[c].astype('float32')
        #encoded2 = self.ran_encoder.transform(df[self.cols_cat])     # TODO: add generated feats into cols_feats
        if self.is_embedding:
            self.cat_astyper.transform(df)
    
        # Fillna
        for c, v in self.fillna_values.items():
            df[c] = df[c].fillna(v)    

        # Skewness
        for c in self.cols_right_skew:
            df[c] = np.log10(0.1 + df[c] - self.mins_right_skew_cols[c]).astype('float32')
        
        # Normalization
        self.scaler.transform(df)  # transform inplace!
        
        # Target normalization
        if self.col_target in df:
            self.target_scaler.transform(df, cols_input=[self.col_target], cols_transformed=[self.col_target+'_scaled'])
        
        return df
        #return pd.concat([df, encoded1, encoded2], axis=1)
        
    def target_inverse_transform(self, df, col_scaled_target, col_unscaled_target):
        self.target_scaler.inverse_transform(df, cols_input=[col_scaled_target], 
                                             cols_transformed=[col_unscaled_target])
        return df[col_unscaled_target]

# %% [markdown]
# #### Debug

# %%
# for debug only
feat_eng_t = FeatureEngineering(
    cols_num, cols_cat, cols_bin, col_target, fillna_values, cols_right_skew, 
    is_embedding=is_embedding, is_tar_encoded=is_tar_encoded,
)

# %%
dfp2 = feat_eng_t.fit_transform(train, test)

# %%
df_test_2 = feat_eng_t.transform(test)

# %%
for c in cols_cat:
    print(c, dfp2[c].min(), df_test_2[c].min())
# Out:
# building_material 1 1
# city 1 1
# building_type 1 1
# building_use 1 1
# parking_way 1 1
# town 0 0
# village 0 0
# encoded_latlon 1 1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Columns: 253 entries, building_id to land_per_building_area
# dtypes: float32(212), int32(18), object(23)
# memory usage: 63.2+ MB

# %%
dfp2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Columns: 254 entries, building_id to log_per_area_total_price_scaled
# dtypes: float32(213), int16(2), int32(10), int8(6), object(23)
# memory usage: 62.1+ MB

# %%
dfp2['building_area_ori'].check()
# Out:
# 0         3.418175
# 1         4.041309
# 2         5.584279
# 3        13.563030
# 4         4.688108
# 59995     6.754059
# 59996     5.356788
# 59997     8.223644
# 59998     8.728287
# 59999     5.356788
# Name: building_area_ori, dtype: float32
# shape = (60000,)

# %%
#dfp2.loc[:, cols_right_skew].check()

# %%
plt.hist(dfp2['log_per_area_total_price_scaled'], bins=100); plt.show()

# %%
for c in cols_num:
    plt.figure(figsize=(12, 2))
    plt.hist(dfp2[c], bins=100)
    plt.xlabel('num: '+c); plt.show()
for c in cols_bin:
    plt.figure(figsize=(12, 2))
    plt.hist(dfp2[c], bins=100)
    plt.xlabel('bin: '+c); plt.show()

# %%
for c in cols_tar_encoded:
    plt.figure(figsize=(12, 2))
    plt.hist(dfp2[c], bins=100)
    plt.xlabel('tar: '+c); plt.show()

# %% [markdown]
# ### Keras Model

# %%
import keras
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Dense, Embedding, Flatten, Reshape, concatenate
from keras.optimizers import Adam, SGD
print('keras:', keras.__version__, 'tensorflow:', tf.__version__)
# Out:
# c:\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# keras: 2.1.3 tensorflow: 1.10.0

# %%
from keras_get_best import GetBest

def build_model(n_cols_num_bin, cat_n_classes={}, cat_embed_sizes={}, 
                n_neurons=(512,)*10, learning_rate=0.001, optimizer=Adam):
    '''Args: 
       n_cols_num_bin: number of numerical and binary features
       cat_n_classes: dict of cat column name to number of classes in the cat column
       cat_embed_sizes: dict of cat column name to embedding output size
       n_neurons: list of number of neurons for each dense layer
    '''
    is_embedding = len(cat_n_classes) > 0
    num_bin_input = Input(shape=(n_cols_num_bin,), dtype='float32', name='num_bin')
    cats_inputs = {c: Input(shape=(1,), dtype='int32', name=c) for c in cat_n_classes}
    if is_embedding:
        cats_embedding_layers = [
            Reshape(target_shape=(cat_embed_sizes[c],))(
                Embedding(input_dim=c_input_dim, output_dim=cat_embed_sizes[c])(cats_inputs[c])
            ) 
            for c, c_input_dim in cat_n_classes.items()
        ]
        x_layer = concatenate([num_bin_input]+cats_embedding_layers)  # output shape = 258
    else:
        x_layer = num_bin_input
    for n in n_neurons:
        x_layer = Dense(n, activation='relu')(x_layer)
    output = Dense(1)(x_layer)
    model = Model(inputs=[num_bin_input]+list(cats_inputs.values()),
                  outputs=output)
    model.compile(optimizer=optimizer(lr=learning_rate), loss='mae', metrics=['mse'])
    return model    

def build_features_matrices(df, cols_num, cols_cat, cols_bin):
    Xs = {'num_bin': df[cols_num+cols_bin].values}
    for c in cols_cat:
        Xs[c] = df[c].values
    return Xs

def plot_keras_hist(hists, ylim=None, metrics_plot=None):
    if not isinstance(hists, list): hists=[hists]
    if metrics_plot is None:
        metrics_plot = [c for c in hists[0].history.keys() if not c.startswith('val')]
    for m in metrics_plot:
        plt.figure(figsize=(14, 4))
        for i, hist in enumerate(hists):
            for c in hist.history:
                if c.endswith(m):
                    plt.plot(hist.history[c], label=c+' '+str(i), alpha=0.9)
        if ylim != None:
            plt.ylim(*ylim)
        plt.xlabel('epochs'); plt.title(m)
        plt.legend(); plt.grid(); plt.show()

# %% [markdown]
# ### Params

# %%
params = {'epochs': 200,
          'n_neurons': (1024,)*5+(512,)*5,
          'optimizer': Adam,
          'learning_rate': 0.001,
          'batch_size': 64,
         }

# %% [markdown]
# ### kfold cross-predict

# %%
t0 = time.time()

predicts_val = []
predicts_test = test[['building_id']].copy()
hists = []
best_iterations = []
scores = []
for i, id_fold in enumerate(id_cv):
    print('==== Fold', i+1, '====')
    
    # split train, val
    df_train = train.loc[~train['building_id'].isin(id_fold)].copy().reset_index(drop=True)
    df_val = train.loc[train['building_id'].isin(id_fold)].copy().reset_index(drop=True)
    df_test = test.copy()

    # Feature engineering
    feat_eng = FeatureEngineering(cols_num=cols_num, 
                                  cols_cat=cols_cat, 
                                  cols_bin=cols_bin, 
                                  col_target=col_target, 
                                  fillna_values=fillna_values, 
                                  cols_right_skew=cols_right_skew,
                                  is_embedding=is_embedding, 
                                  is_tar_encoded=is_tar_encoded,
                                  rare_village_threshold=rare_village_threshold, 
                                  rare_town_threshold=rare_town_threshold,)
    df_train = feat_eng.fit_transform(df_train, df_val)
    df_val = feat_eng.transform(df_val)
    df_test = feat_eng.transform(df_test)

    # Construct X y matrices
    if is_embedding:
        X_train = build_features_matrices(df_train, cols_num=cols_num+cols_tar_encoded, cols_cat=cols_cat, cols_bin=cols_bin)
        X_val = build_features_matrices(df_val, cols_num=cols_num+cols_tar_encoded, cols_cat=cols_cat, cols_bin=cols_bin)
        X_test = build_features_matrices(df_test, cols_num=cols_num+cols_tar_encoded, cols_cat=cols_cat, cols_bin=cols_bin)
    else:
        X_train = build_features_matrices(df_train, cols_num=cols_num+cols_tar_encoded, cols_cat=[], cols_bin=cols_bin)
        X_val = build_features_matrices(df_val, cols_num=cols_num+cols_tar_encoded, cols_cat=[], cols_bin=cols_bin)
        X_test = build_features_matrices(df_test, cols_num=cols_num+cols_tar_encoded, cols_cat=[], cols_bin=cols_bin)
    y_train = df_train[col_target+'_scaled']
    y_val = df_val[col_target+'_scaled']
    
    # Compute network size
    n_cols_num_bin = len(cols_num+cols_bin+cols_tar_encoded)
    if is_embedding:
        cat_n_classes = {c: feat_eng.cat_astyper.cat_n_classes[c] for c in cols_cat}
        cat_embed_sizes = {c: int(2*np.log(cat_n_classes[c]+1)+1) for c in cat_n_classes}
    else:
        cat_n_classes = {}
        cat_embed_sizes = {}
    print('Numerical input dims:', n_cols_num_bin)
    print('Embeding  input dims:', cat_n_classes)
    print('Embeding output dims:', cat_embed_sizes)
    print('Total embedding output dims:', np.sum(list(cat_embed_sizes.values())))

    # Build model
    model = build_model(n_cols_num_bin, cat_n_classes, cat_embed_sizes, 
                        n_neurons=params['n_neurons'], learning_rate=params['learning_rate'], 
                        optimizer=params['optimizer'])

    # Train model
    hist = model.fit(x=X_train, y=y_train, batch_size=params['batch_size'], epochs=params['epochs'], 
                     verbose=2, validation_data=(X_val, y_val), 
                     callbacks=[GetBest(monitor='val_loss', verbose=0, mode='min')])
    best_iterations.append(np.argmin(hist.history['val_loss'])+1)
    hists.append(hist)

    # Predict on val set
    df_val[col_target+'_scaled_pred'] = model.predict(X_val, batch_size=1024)
    feat_eng.target_inverse_transform(df_val, col_target+'_scaled_pred', col_target+'_pred')
    df_val['total_price_pred'] = post_processing(df_val[col_target+'_pred'], df_val)

    mse = mean_squared_error(df_val[col_target], df_val[col_target+'_pred'])
    mae = mean_absolute_error(df_val[col_target], df_val[col_target+'_pred'])
    mape = cal_mape(df_val[col_target], df_val[col_target+'_pred'])
    score = cal_score(df_val['total_price'], df_val['total_price_pred'])
    scores.append(score)

    print('(Fold %d) score, mse, mae, mape: %.5f, %.5f, %.5f, %.5f.' % (i, score, mse, mae, mape))
    predicts_val.append(pd.DataFrame({'building_id': df_val['building_id'],
                                      'total_price': df_val['total_price'],
                                      'total_price_predict': df_val['total_price_pred']}))

    
    # Predict on test set
    df_test[col_target+'_scaled_pred'] = model.predict(X_test, batch_size=1024)
    feat_eng.target_inverse_transform(df_test, col_target+'_scaled_pred', col_target+'_pred')

    predicts_test['target_{}'.format(i)] = df_test[col_target+'_pred']

t1 = time.time()
# Out:
# ==== Fold 1 ====
# Numerical input dims: 205
# Embeding  input dims: {'building_material': 10, 'city': 12, 'building_type': 6, 'building_use': 11, 'parking_way': 4, 'town': 209, 'village': 2606, 'encoded_latlon': 7}
# Embeding output dims: {'building_material': 5, 'city': 6, 'building_type': 4, 'building_use': 5, 'parking_way': 4, 'town': 11, 'village': 16, 'encoded_latlon': 5}
# Total embedding output dims: 56
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/200
#  - 97s - loss: 0.2768 - mean_squared_error: 0.1470 - val_loss: 0.2201 - val_mean_squared_error: 0.0896
# Epoch 2/200
#  - 96s - loss: 0.2109 - mean_squared_error: 0.0851 - val_loss: 0.1997 - val_mean_squared_error: 0.0769
# Epoch 3/200
#  - 97s - loss: 0.1915 - mean_squared_error: 0.0718 - val_loss: 0.1869 - val_mean_squared_error: 0.0696
# Epoch 4/200
#  - 96s - loss: 0.1815 - mean_squared_error: 0.0658 - val_loss: 0.1788 - val_mean_squared_error: 0.0636
# Epoch 5/200
#  - 96s - loss: 0.1735 - mean_squared_error: 0.0611 - val_loss: 0.2242 - val_mean_squared_error: 0.0914
# Epoch 6/200
#  - 96s - loss: 0.1648 - mean_squared_error: 0.0560 - val_loss: 0.1804 - val_mean_squared_error: 0.0638
# Epoch 7/200
#  - 96s - loss: 0.1591 - mean_squared_error: 0.0521 - val_loss: 0.1779 - val_mean_squared_error: 0.0633
# Epoch 8/200
#  - 96s - loss: 0.1528 - mean_squared_error: 0.0491 - val_loss: 0.1741 - val_mean_squared_error: 0.0609
# Epoch 9/200
#  - 96s - loss: 0.1484 - mean_squared_error: 0.0467 - val_loss: 0.1726 - val_mean_squared_error: 0.0608
# Epoch 10/200
#  - 96s - loss: 0.1429 - mean_squared_error: 0.0441 - val_loss: 0.1673 - val_mean_squared_error: 0.0577
# Epoch 11/200
#  - 96s - loss: 0.1390 - mean_squared_error: 0.0417 - val_loss: 0.1700 - val_mean_squared_error: 0.0585
# Epoch 12/200
#  - 96s - loss: 0.1360 - mean_squared_error: 0.0403 - val_loss: 0.1698 - val_mean_squared_error: 0.0585
# Epoch 13/200
#  - 96s - loss: 0.1311 - mean_squared_error: 0.0380 - val_loss: 0.1694 - val_mean_squared_error: 0.0571
# Epoch 14/200
#  - 96s - loss: 0.1283 - mean_squared_error: 0.0364 - val_loss: 0.1738 - val_mean_squared_error: 0.0598
# Epoch 15/200
#  - 96s - loss: 0.1237 - mean_squared_error: 0.0345 - val_loss: 0.1609 - val_mean_squared_error: 0.0539
# Epoch 16/200
#  - 96s - loss: 0.1202 - mean_squared_error: 0.0328 - val_loss: 0.1661 - val_mean_squared_error: 0.0559
# Epoch 17/200
#  - 96s - loss: 0.1179 - mean_squared_error: 0.0317 - val_loss: 0.1640 - val_mean_squared_error: 0.0549
# Epoch 18/200
#  - 96s - loss: 0.1136 - mean_squared_error: 0.0300 - val_loss: 0.1636 - val_mean_squared_error: 0.0549
# Epoch 19/200
#  - 96s - loss: 0.1108 - mean_squared_error: 0.0288 - val_loss: 0.1571 - val_mean_squared_error: 0.0521
# Epoch 20/200
#  - 96s - loss: 0.1083 - mean_squared_error: 0.0277 - val_loss: 0.1578 - val_mean_squared_error: 0.0528
# Epoch 21/200
#  - 96s - loss: 0.1065 - mean_squared_error: 0.0268 - val_loss: 0.1605 - val_mean_squared_error: 0.0535
# Epoch 22/200
#  - 96s - loss: 0.1033 - mean_squared_error: 0.0255 - val_loss: 0.1613 - val_mean_squared_error: 0.0549
# Epoch 23/200
#  - 96s - loss: 0.1017 - mean_squared_error: 0.0247 - val_loss: 0.1635 - val_mean_squared_error: 0.0553
# Epoch 24/200
#  - 96s - loss: 0.0992 - mean_squared_error: 0.0237 - val_loss: 0.1565 - val_mean_squared_error: 0.0519
# Epoch 25/200
#  - 97s - loss: 0.0952 - mean_squared_error: 0.0223 - val_loss: 0.1578 - val_mean_squared_error: 0.0532
# Epoch 26/200
#  - 96s - loss: 0.0973 - mean_squared_error: 0.1647 - val_loss: 0.1573 - val_mean_squared_error: 0.0526
# Epoch 27/200
#  - 98s - loss: 0.0924 - mean_squared_error: 0.0212 - val_loss: 0.1601 - val_mean_squared_error: 0.0532
# Epoch 28/200
#  - 100s - loss: 0.0916 - mean_squared_error: 0.0238 - val_loss: 0.1566 - val_mean_squared_error: 0.0525
# Epoch 29/200
#  - 99s - loss: 0.0882 - mean_squared_error: 0.0196 - val_loss: 0.1557 - val_mean_squared_error: 0.0523
# Epoch 30/200
#  - 96s - loss: 0.0861 - mean_squared_error: 0.0188 - val_loss: 0.1590 - val_mean_squared_error: 0.0542
# Epoch 31/200
#  - 97s - loss: 0.0846 - mean_squared_error: 0.0182 - val_loss: 0.1556 - val_mean_squared_error: 0.0524
# Epoch 32/200
#  - 96s - loss: 0.0838 - mean_squared_error: 0.0177 - val_loss: 0.1535 - val_mean_squared_error: 0.0510
# Epoch 33/200
#  - 96s - loss: 0.0823 - mean_squared_error: 0.0174 - val_loss: 0.1595 - val_mean_squared_error: 0.0539
# Epoch 34/200
#  - 96s - loss: 0.0804 - mean_squared_error: 0.0166 - val_loss: 0.1539 - val_mean_squared_error: 0.0515
# Epoch 35/200
#  - 96s - loss: 0.0790 - mean_squared_error: 0.0160 - val_loss: 0.1548 - val_mean_squared_error: 0.0513
# Epoch 36/200
#  - 96s - loss: 0.0770 - mean_squared_error: 0.0155 - val_loss: 0.1576 - val_mean_squared_error: 0.0532
# Epoch 37/200
#  - 96s - loss: 0.0767 - mean_squared_error: 0.0153 - val_loss: 0.1554 - val_mean_squared_error: 0.0521
# Epoch 38/200
#  - 97s - loss: 0.0747 - mean_squared_error: 0.0149 - val_loss: 0.1537 - val_mean_squared_error: 0.0512
# Epoch 39/200
#  - 96s - loss: 0.0732 - mean_squared_error: 0.0142 - val_loss: 0.1546 - val_mean_squared_error: 0.0519
# Epoch 40/200
#  - 96s - loss: 0.0718 - mean_squared_error: 0.0136 - val_loss: 0.1533 - val_mean_squared_error: 0.0516
# Epoch 41/200
#  - 96s - loss: 0.0719 - mean_squared_error: 0.0138 - val_loss: 0.1555 - val_mean_squared_error: 0.0526
# Epoch 42/200
#  - 96s - loss: 0.0692 - mean_squared_error: 0.0129 - val_loss: 0.1569 - val_mean_squared_error: 0.0533
# Epoch 43/200
#  - 96s - loss: 0.0688 - mean_squared_error: 0.0127 - val_loss: 0.1564 - val_mean_squared_error: 0.0528
# Epoch 44/200
#  - 96s - loss: 0.0681 - mean_squared_error: 0.0125 - val_loss: 0.1549 - val_mean_squared_error: 0.0520
# Epoch 45/200
#  - 96s - loss: 0.0674 - mean_squared_error: 0.0122 - val_loss: 0.1539 - val_mean_squared_error: 0.0520
# Epoch 46/200
#  - 96s - loss: 0.0690 - mean_squared_error: 0.0165 - val_loss: 0.1556 - val_mean_squared_error: 0.0526
# Epoch 47/200
#  - 96s - loss: 0.0651 - mean_squared_error: 0.0114 - val_loss: 0.1533 - val_mean_squared_error: 0.0521
# Epoch 48/200
#  - 96s - loss: 0.0640 - mean_squared_error: 0.0112 - val_loss: 0.1548 - val_mean_squared_error: 0.0524
# Epoch 49/200
#  - 97s - loss: 0.0630 - mean_squared_error: 0.0111 - val_loss: 0.1596 - val_mean_squared_error: 0.0551
# Epoch 50/200
#  - 96s - loss: 0.0625 - mean_squared_error: 0.0112 - val_loss: 0.1533 - val_mean_squared_error: 0.0518
# Epoch 51/200
#  - 96s - loss: 0.0611 - mean_squared_error: 0.0104 - val_loss: 0.1539 - val_mean_squared_error: 0.0525
# Epoch 52/200
#  - 96s - loss: 0.0604 - mean_squared_error: 0.0101 - val_loss: 0.1556 - val_mean_squared_error: 0.0526
# Epoch 53/200
#  - 96s - loss: 0.0598 - mean_squared_error: 0.0099 - val_loss: 0.1548 - val_mean_squared_error: 0.0522
# Epoch 54/200
#  - 96s - loss: 0.0587 - mean_squared_error: 0.0096 - val_loss: 0.1533 - val_mean_squared_error: 0.0514
# Epoch 55/200
#  - 96s - loss: 0.0582 - mean_squared_error: 0.0095 - val_loss: 0.1615 - val_mean_squared_error: 0.0546
# Epoch 56/200
#  - 96s - loss: 0.0574 - mean_squared_error: 0.0092 - val_loss: 0.1533 - val_mean_squared_error: 0.0512
# Epoch 57/200
#  - 96s - loss: 0.0558 - mean_squared_error: 0.0089 - val_loss: 0.1536 - val_mean_squared_error: 0.0520
# Epoch 58/200
#  - 96s - loss: 0.0558 - mean_squared_error: 0.0090 - val_loss: 0.1535 - val_mean_squared_error: 0.0517
# Epoch 59/200
#  - 96s - loss: 0.0549 - mean_squared_error: 0.0086 - val_loss: 0.1543 - val_mean_squared_error: 0.0521
# Epoch 60/200
#  - 96s - loss: 0.0541 - mean_squared_error: 0.0084 - val_loss: 0.1533 - val_mean_squared_error: 0.0523
# Epoch 61/200
#  - 97s - loss: 0.0541 - mean_squared_error: 0.0084 - val_loss: 0.1539 - val_mean_squared_error: 0.0517
# Epoch 62/200
#  - 97s - loss: 0.0541 - mean_squared_error: 0.0083 - val_loss: 0.1531 - val_mean_squared_error: 0.0519
# Epoch 63/200
#  - 96s - loss: 0.0521 - mean_squared_error: 0.0079 - val_loss: 0.1533 - val_mean_squared_error: 0.0516
# Epoch 64/200
#  - 96s - loss: 0.0519 - mean_squared_error: 0.0079 - val_loss: 0.1539 - val_mean_squared_error: 0.0524
# Epoch 65/200
#  - 96s - loss: 0.0508 - mean_squared_error: 0.0075 - val_loss: 0.1575 - val_mean_squared_error: 0.0543
# Epoch 66/200
#  - 96s - loss: 0.0514 - mean_squared_error: 0.0077 - val_loss: 0.1535 - val_mean_squared_error: 0.0520
# Epoch 67/200
#  - 96s - loss: 0.0509 - mean_squared_error: 0.0075 - val_loss: 0.1563 - val_mean_squared_error: 0.0535
# Epoch 68/200
#  - 96s - loss: 0.0507 - mean_squared_error: 0.0078 - val_loss: 0.1523 - val_mean_squared_error: 0.0513
# Epoch 69/200
#  - 96s - loss: 0.0498 - mean_squared_error: 0.0072 - val_loss: 0.1550 - val_mean_squared_error: 0.0532
# Epoch 70/200
#  - 96s - loss: 0.0494 - mean_squared_error: 0.0072 - val_loss: 0.1538 - val_mean_squared_error: 0.0518
# Epoch 71/200
#  - 96s - loss: 0.0488 - mean_squared_error: 0.0070 - val_loss: 0.1557 - val_mean_squared_error: 0.0533
# Epoch 72/200
#  - 96s - loss: 0.0476 - mean_squared_error: 0.0067 - val_loss: 0.1549 - val_mean_squared_error: 0.0529
# Epoch 73/200
#  - 96s - loss: 0.0471 - mean_squared_error: 0.0066 - val_loss: 0.1538 - val_mean_squared_error: 0.0526
# Epoch 74/200
#  - 96s - loss: 0.0474 - mean_squared_error: 0.0066 - val_loss: 0.1518 - val_mean_squared_error: 0.0508
# Epoch 75/200
#  - 96s - loss: 0.0469 - mean_squared_error: 0.0065 - val_loss: 0.1552 - val_mean_squared_error: 0.0530
# Epoch 76/200
#  - 96s - loss: 0.0463 - mean_squared_error: 0.0064 - val_loss: 0.1551 - val_mean_squared_error: 0.0530
# Epoch 77/200
#  - 96s - loss: 0.0454 - mean_squared_error: 0.0062 - val_loss: 0.1532 - val_mean_squared_error: 0.0524
# Epoch 78/200
#  - 97s - loss: 0.0455 - mean_squared_error: 0.0062 - val_loss: 0.1534 - val_mean_squared_error: 0.0520
# Epoch 79/200
#  - 97s - loss: 0.0459 - mean_squared_error: 0.0063 - val_loss: 0.1525 - val_mean_squared_error: 0.0520
# Epoch 80/200
#  - 97s - loss: 0.0450 - mean_squared_error: 0.0060 - val_loss: 0.1524 - val_mean_squared_error: 0.0517
# Epoch 81/200
#  - 97s - loss: 0.0447 - mean_squared_error: 0.0060 - val_loss: 0.1554 - val_mean_squared_error: 0.0537
# Epoch 82/200
#  - 97s - loss: 0.0446 - mean_squared_error: 0.0060 - val_loss: 0.1527 - val_mean_squared_error: 0.0520
# Epoch 83/200
#  - 97s - loss: 0.0444 - mean_squared_error: 0.0059 - val_loss: 0.1521 - val_mean_squared_error: 0.0518
# Epoch 84/200
#  - 97s - loss: 0.0430 - mean_squared_error: 0.0057 - val_loss: 0.1511 - val_mean_squared_error: 0.0514
# Epoch 85/200
#  - 97s - loss: 0.0425 - mean_squared_error: 0.0056 - val_loss: 0.1528 - val_mean_squared_error: 0.0519
# Epoch 86/200
#  - 97s - loss: 0.0427 - mean_squared_error: 0.0055 - val_loss: 0.1523 - val_mean_squared_error: 0.0520
# Epoch 87/200
#  - 97s - loss: 0.0426 - mean_squared_error: 0.0055 - val_loss: 0.1525 - val_mean_squared_error: 0.0524
# Epoch 88/200
#  - 97s - loss: 0.0419 - mean_squared_error: 0.0054 - val_loss: 0.1549 - val_mean_squared_error: 0.0533
# Epoch 89/200
#  - 97s - loss: 0.0418 - mean_squared_error: 0.0053 - val_loss: 0.1521 - val_mean_squared_error: 0.0520
# Epoch 90/200
#  - 97s - loss: 0.0413 - mean_squared_error: 0.0052 - val_loss: 0.1522 - val_mean_squared_error: 0.0516
# Epoch 91/200
#  - 97s - loss: 0.0411 - mean_squared_error: 0.0052 - val_loss: 0.1515 - val_mean_squared_error: 0.0517
# Epoch 92/200
#  - 97s - loss: 0.0397 - mean_squared_error: 0.0049 - val_loss: 0.1513 - val_mean_squared_error: 0.0515
# Epoch 93/200
#  - 97s - loss: 0.0405 - mean_squared_error: 0.0051 - val_loss: 0.1516 - val_mean_squared_error: 0.0515
# Epoch 94/200
#  - 97s - loss: 0.0397 - mean_squared_error: 0.0048 - val_loss: 0.1525 - val_mean_squared_error: 0.0522
# Epoch 95/200
#  - 97s - loss: 0.0392 - mean_squared_error: 0.0048 - val_loss: 0.1514 - val_mean_squared_error: 0.0516
# Epoch 96/200
#  - 97s - loss: 0.0393 - mean_squared_error: 0.0048 - val_loss: 0.1523 - val_mean_squared_error: 0.0520
# Epoch 97/200
#  - 98s - loss: 0.0387 - mean_squared_error: 0.0046 - val_loss: 0.1520 - val_mean_squared_error: 0.0517
# Epoch 98/200
#  - 98s - loss: 0.0386 - mean_squared_error: 0.0046 - val_loss: 0.1535 - val_mean_squared_error: 0.0524
# Epoch 99/200
#  - 98s - loss: 0.0386 - mean_squared_error: 0.0047 - val_loss: 0.1512 - val_mean_squared_error: 0.0514
# Epoch 100/200
#  - 99s - loss: 0.0384 - mean_squared_error: 0.0047 - val_loss: 0.1498 - val_mean_squared_error: 0.0508
# Epoch 101/200
#  - 99s - loss: 0.0380 - mean_squared_error: 0.0045 - val_loss: 0.1533 - val_mean_squared_error: 0.0524
# Epoch 102/200
#  - 100s - loss: 0.0382 - mean_squared_error: 0.0045 - val_loss: 0.1530 - val_mean_squared_error: 0.0527
# Epoch 103/200
#  - 100s - loss: 0.0377 - mean_squared_error: 0.0044 - val_loss: 0.1520 - val_mean_squared_error: 0.0520
# Epoch 104/200
#  - 102s - loss: 0.0368 - mean_squared_error: 0.0043 - val_loss: 0.1514 - val_mean_squared_error: 0.0517
# Epoch 105/200
#  - 101s - loss: 0.0372 - mean_squared_error: 0.0043 - val_loss: 0.1522 - val_mean_squared_error: 0.0523
# Epoch 106/200
#  - 102s - loss: 0.0375 - mean_squared_error: 0.0044 - val_loss: 0.1519 - val_mean_squared_error: 0.0519
# Epoch 107/200
#  - 103s - loss: 0.0360 - mean_squared_error: 0.0042 - val_loss: 0.1510 - val_mean_squared_error: 0.0513
# Epoch 108/200
#  - 106s - loss: 0.0365 - mean_squared_error: 0.0042 - val_loss: 0.1514 - val_mean_squared_error: 0.0521
# Epoch 109/200
#  - 105s - loss: 0.0369 - mean_squared_error: 0.0043 - val_loss: 0.1521 - val_mean_squared_error: 0.0520
# Epoch 110/200
#  - 105s - loss: 0.0363 - mean_squared_error: 0.0041 - val_loss: 0.1522 - val_mean_squared_error: 0.0519
# Epoch 111/200
#  - 105s - loss: 0.0358 - mean_squared_error: 0.0043 - val_loss: 0.1515 - val_mean_squared_error: 0.0516
# Epoch 112/200
#  - 105s - loss: 0.0363 - mean_squared_error: 0.0041 - val_loss: 0.1528 - val_mean_squared_error: 0.0521
# Epoch 113/200
#  - 106s - loss: 0.0350 - mean_squared_error: 0.0039 - val_loss: 0.1523 - val_mean_squared_error: 0.0522
# Epoch 114/200
#  - 106s - loss: 0.0352 - mean_squared_error: 0.0039 - val_loss: 0.1516 - val_mean_squared_error: 0.0519
# Epoch 115/200
#  - 106s - loss: 0.0347 - mean_squared_error: 0.0038 - val_loss: 0.1527 - val_mean_squared_error: 0.0524
# Epoch 116/200
#  - 97s - loss: 0.0345 - mean_squared_error: 0.0039 - val_loss: 0.1529 - val_mean_squared_error: 0.0525
# Epoch 117/200
#  - 97s - loss: 0.0351 - mean_squared_error: 0.0039 - val_loss: 0.1520 - val_mean_squared_error: 0.0519
# Epoch 118/200
#  - 99s - loss: 0.0355 - mean_squared_error: 0.0040 - val_loss: 0.1520 - val_mean_squared_error: 0.0520
# Epoch 119/200
#  - 99s - loss: 0.0337 - mean_squared_error: 0.0037 - val_loss: 0.1524 - val_mean_squared_error: 0.0519
# Epoch 120/200
#  - 100s - loss: 0.0334 - mean_squared_error: 0.0036 - val_loss: 0.1513 - val_mean_squared_error: 0.0515
# Epoch 121/200
#  - 100s - loss: 0.0344 - mean_squared_error: 0.0037 - val_loss: 0.1504 - val_mean_squared_error: 0.0513
# Epoch 122/200
#  - 96s - loss: 0.0345 - mean_squared_error: 0.0038 - val_loss: 0.1520 - val_mean_squared_error: 0.0523
# Epoch 123/200
#  - 96s - loss: 0.0331 - mean_squared_error: 0.0036 - val_loss: 0.1528 - val_mean_squared_error: 0.0523
# Epoch 124/200
#  - 96s - loss: 0.0334 - mean_squared_error: 0.0037 - val_loss: 0.1520 - val_mean_squared_error: 0.0522
# Epoch 125/200
#  - 96s - loss: 0.0339 - mean_squared_error: 0.0037 - val_loss: 0.1512 - val_mean_squared_error: 0.0518
# Epoch 126/200
#  - 96s - loss: 0.0331 - mean_squared_error: 0.0036 - val_loss: 0.1512 - val_mean_squared_error: 0.0517
# Epoch 127/200
#  - 96s - loss: 0.0331 - mean_squared_error: 0.0035 - val_loss: 0.1511 - val_mean_squared_error: 0.0519
# Epoch 128/200
#  - 96s - loss: 0.0324 - mean_squared_error: 0.0034 - val_loss: 0.1525 - val_mean_squared_error: 0.0521
# Epoch 129/200
#  - 96s - loss: 0.0331 - mean_squared_error: 0.0035 - val_loss: 0.1515 - val_mean_squared_error: 0.0515
# Epoch 130/200
#  - 96s - loss: 0.0321 - mean_squared_error: 0.0034 - val_loss: 0.1518 - val_mean_squared_error: 0.0518
# Epoch 131/200
#  - 96s - loss: 0.0320 - mean_squared_error: 0.0033 - val_loss: 0.1510 - val_mean_squared_error: 0.0515
# Epoch 132/200
#  - 96s - loss: 0.0315 - mean_squared_error: 0.0033 - val_loss: 0.1508 - val_mean_squared_error: 0.0515
# Epoch 133/200
#  - 96s - loss: 0.0314 - mean_squared_error: 0.0032 - val_loss: 0.1505 - val_mean_squared_error: 0.0517
# Epoch 134/200
#  - 96s - loss: 0.0332 - mean_squared_error: 0.0036 - val_loss: 0.1528 - val_mean_squared_error: 0.0523
# Epoch 135/200
#  - 98s - loss: 0.0332 - mean_squared_error: 0.0039 - val_loss: 0.1504 - val_mean_squared_error: 0.0512
# Epoch 136/200
#  - 97s - loss: 0.0315 - mean_squared_error: 0.0033 - val_loss: 0.1509 - val_mean_squared_error: 0.0518
# Epoch 137/200
#  - 97s - loss: 0.0307 - mean_squared_error: 0.0031 - val_loss: 0.1510 - val_mean_squared_error: 0.0516
# Epoch 138/200
#  - 97s - loss: 0.0311 - mean_squared_error: 0.0032 - val_loss: 0.1513 - val_mean_squared_error: 0.0518
# Epoch 139/200
#  - 97s - loss: 0.0312 - mean_squared_error: 0.0032 - val_loss: 0.1506 - val_mean_squared_error: 0.0513
# Epoch 140/200
#  - 96s - loss: 0.0309 - mean_squared_error: 0.0032 - val_loss: 0.1519 - val_mean_squared_error: 0.0519
# Epoch 141/200
#  - 97s - loss: 0.0307 - mean_squared_error: 0.0031 - val_loss: 0.1518 - val_mean_squared_error: 0.0520
# Epoch 142/200
#  - 96s - loss: 0.0312 - mean_squared_error: 0.0032 - val_loss: 0.1517 - val_mean_squared_error: 0.0520
# Epoch 143/200
#  - 97s - loss: 0.0305 - mean_squared_error: 0.0031 - val_loss: 0.1501 - val_mean_squared_error: 0.0511
# Epoch 144/200
#  - 97s - loss: 0.0303 - mean_squared_error: 0.0030 - val_loss: 0.1521 - val_mean_squared_error: 0.0522
# Epoch 145/200
#  - 97s - loss: 0.0298 - mean_squared_error: 0.0034 - val_loss: 0.1509 - val_mean_squared_error: 0.0516
# Epoch 146/200
#  - 96s - loss: 0.0300 - mean_squared_error: 0.0030 - val_loss: 0.1499 - val_mean_squared_error: 0.0513
# Epoch 147/200
#  - 96s - loss: 0.0297 - mean_squared_error: 0.0029 - val_loss: 0.1500 - val_mean_squared_error: 0.0512
# Epoch 148/200
#  - 96s - loss: 0.0294 - mean_squared_error: 0.0029 - val_loss: 0.1501 - val_mean_squared_error: 0.0509
# Epoch 149/200
#  - 97s - loss: 0.0301 - mean_squared_error: 0.0030 - val_loss: 0.1510 - val_mean_squared_error: 0.0514
# Epoch 150/200
#  - 97s - loss: 0.0302 - mean_squared_error: 0.0030 - val_loss: 0.1529 - val_mean_squared_error: 0.0527
# Epoch 151/200
#  - 97s - loss: 0.0297 - mean_squared_error: 0.0029 - val_loss: 0.1517 - val_mean_squared_error: 0.0522
# Epoch 152/200
#  - 97s - loss: 0.0297 - mean_squared_error: 0.0029 - val_loss: 0.1503 - val_mean_squared_error: 0.0512
# Epoch 153/200
#  - 97s - loss: 0.0295 - mean_squared_error: 0.0029 - val_loss: 0.1503 - val_mean_squared_error: 0.0513
# Epoch 154/200
#  - 97s - loss: 0.0297 - mean_squared_error: 0.0029 - val_loss: 0.1507 - val_mean_squared_error: 0.0516
# Epoch 155/200
#  - 97s - loss: 0.0303 - mean_squared_error: 0.0030 - val_loss: 0.1512 - val_mean_squared_error: 0.0518
# Epoch 156/200
#  - 98s - loss: 0.0290 - mean_squared_error: 0.0028 - val_loss: 0.1509 - val_mean_squared_error: 0.0519
# Epoch 157/200
#  - 98s - loss: 0.0293 - mean_squared_error: 0.0029 - val_loss: 0.1506 - val_mean_squared_error: 0.0511
# Epoch 158/200
#  - 98s - loss: 0.0287 - mean_squared_error: 0.0029 - val_loss: 0.1498 - val_mean_squared_error: 0.0511
# Epoch 159/200
#  - 98s - loss: 0.0286 - mean_squared_error: 0.0031 - val_loss: 0.1513 - val_mean_squared_error: 0.0520
# Epoch 160/200
#  - 98s - loss: 0.0297 - mean_squared_error: 0.0029 - val_loss: 0.1513 - val_mean_squared_error: 0.0519
# Epoch 161/200
#  - 99s - loss: 0.0287 - mean_squared_error: 0.0028 - val_loss: 0.1507 - val_mean_squared_error: 0.0515
# Epoch 162/200
#  - 99s - loss: 0.0282 - mean_squared_error: 0.0027 - val_loss: 0.1514 - val_mean_squared_error: 0.0520
# Epoch 163/200
#  - 99s - loss: 0.0303 - mean_squared_error: 0.0030 - val_loss: 0.1513 - val_mean_squared_error: 0.0518
# Epoch 164/200
#  - 99s - loss: 0.0301 - mean_squared_error: 0.0029 - val_loss: 0.1501 - val_mean_squared_error: 0.0513
# Epoch 165/200
#  - 99s - loss: 0.0292 - mean_squared_error: 0.0029 - val_loss: 0.1508 - val_mean_squared_error: 0.0516
# Epoch 166/200
#  - 101s - loss: 0.0291 - mean_squared_error: 0.0028 - val_loss: 0.1504 - val_mean_squared_error: 0.0514
# Epoch 167/200
#  - 102s - loss: 0.0290 - mean_squared_error: 0.0028 - val_loss: 0.1513 - val_mean_squared_error: 0.0521
# Epoch 168/200
#  - 103s - loss: 0.0308 - mean_squared_error: 0.0032 - val_loss: 0.1512 - val_mean_squared_error: 0.0519
# Epoch 169/200
#  - 101s - loss: 0.0290 - mean_squared_error: 0.0029 - val_loss: 0.1519 - val_mean_squared_error: 0.0520
# Epoch 170/200
#  - 98s - loss: 0.0296 - mean_squared_error: 0.0029 - val_loss: 0.1517 - val_mean_squared_error: 0.0518
# Epoch 171/200
#  - 98s - loss: 0.0286 - mean_squared_error: 0.0028 - val_loss: 0.1509 - val_mean_squared_error: 0.0515
# Epoch 172/200
#  - 99s - loss: 0.0282 - mean_squared_error: 0.0027 - val_loss: 0.1513 - val_mean_squared_error: 0.0518
# Epoch 173/200
#  - 99s - loss: 0.0296 - mean_squared_error: 0.0029 - val_loss: 0.1512 - val_mean_squared_error: 0.0517
# Epoch 174/200
#  - 98s - loss: 0.0288 - mean_squared_error: 0.0028 - val_loss: 0.1502 - val_mean_squared_error: 0.0512
# Epoch 175/200
#  - 99s - loss: 0.0285 - mean_squared_error: 0.0028 - val_loss: 0.1511 - val_mean_squared_error: 0.0518
# Epoch 176/200
#  - 102s - loss: 0.0280 - mean_squared_error: 0.0028 - val_loss: 0.1535 - val_mean_squared_error: 0.0528
# Epoch 177/200
#  - 103s - loss: 0.0286 - mean_squared_error: 0.0029 - val_loss: 0.1500 - val_mean_squared_error: 0.0511
# Epoch 178/200
#  - 102s - loss: 0.0287 - mean_squared_error: 0.0029 - val_loss: 0.1504 - val_mean_squared_error: 0.0515
# Epoch 179/200
#  - 98s - loss: 0.0287 - mean_squared_error: 0.0028 - val_loss: 0.1503 - val_mean_squared_error: 0.0512
# Epoch 180/200
#  - 99s - loss: 0.0293 - mean_squared_error: 0.0029 - val_loss: 0.1507 - val_mean_squared_error: 0.0514
# Epoch 181/200
#  - 101s - loss: 0.0282 - mean_squared_error: 0.0028 - val_loss: 0.1500 - val_mean_squared_error: 0.0510
# Epoch 182/200
#  - 102s - loss: 0.0275 - mean_squared_error: 0.0026 - val_loss: 0.1503 - val_mean_squared_error: 0.0510
# Epoch 183/200
#  - 102s - loss: 0.0283 - mean_squared_error: 0.0028 - val_loss: 0.1501 - val_mean_squared_error: 0.0511
# Epoch 184/200
#  - 102s - loss: 0.0274 - mean_squared_error: 0.0027 - val_loss: 0.1521 - val_mean_squared_error: 0.0520
# Epoch 185/200
#  - 103s - loss: 0.0280 - mean_squared_error: 0.0027 - val_loss: 0.1503 - val_mean_squared_error: 0.0513
# Epoch 186/200
#  - 103s - loss: 0.0283 - mean_squared_error: 0.0028 - val_loss: 0.1501 - val_mean_squared_error: 0.0510
# Epoch 187/200
#  - 104s - loss: 0.0270 - mean_squared_error: 0.0025 - val_loss: 0.1495 - val_mean_squared_error: 0.0508
# Epoch 188/200
#  - 104s - loss: 0.0356 - mean_squared_error: 0.0066 - val_loss: 0.1506 - val_mean_squared_error: 0.0514
# Epoch 189/200
#  - 104s - loss: 0.0286 - mean_squared_error: 0.0027 - val_loss: 0.1508 - val_mean_squared_error: 0.0517
# Epoch 190/200
#  - 105s - loss: 0.0275 - mean_squared_error: 0.0026 - val_loss: 0.1510 - val_mean_squared_error: 0.0516
# Epoch 191/200
#  - 105s - loss: 0.0273 - mean_squared_error: 0.0026 - val_loss: 0.1501 - val_mean_squared_error: 0.0510
# Epoch 192/200
#  - 105s - loss: 0.0270 - mean_squared_error: 0.0026 - val_loss: 0.1501 - val_mean_squared_error: 0.0510
# Epoch 193/200
#  - 106s - loss: 0.0278 - mean_squared_error: 0.0028 - val_loss: 0.1504 - val_mean_squared_error: 0.0515
# Epoch 194/200
#  - 106s - loss: 0.0277 - mean_squared_error: 0.0026 - val_loss: 0.1497 - val_mean_squared_error: 0.0507
# Epoch 195/200
#  - 107s - loss: 0.0274 - mean_squared_error: 0.0026 - val_loss: 0.1515 - val_mean_squared_error: 0.0515
# Epoch 196/200
#  - 107s - loss: 0.0269 - mean_squared_error: 0.0026 - val_loss: 0.1506 - val_mean_squared_error: 0.0515
# Epoch 197/200
#  - 105s - loss: 0.0267 - mean_squared_error: 0.0026 - val_loss: 0.1494 - val_mean_squared_error: 0.0510
# Epoch 198/200
#  - 105s - loss: 0.0262 - mean_squared_error: 0.0025 - val_loss: 0.1489 - val_mean_squared_error: 0.0508
# Epoch 199/200
#  - 104s - loss: 0.0267 - mean_squared_error: 0.0025 - val_loss: 0.1491 - val_mean_squared_error: 0.0508
# Epoch 200/200
#  - 103s - loss: 0.0263 - mean_squared_error: 0.0024 - val_loss: 0.1493 - val_mean_squared_error: 0.0511
# (Fold 0) score, mse, mae, mape: 5214.85179, 0.04739, 0.14389, 0.01082.
# ==== Fold 2 ====
# Numerical input dims: 205
# Embeding  input dims: {'building_material': 10, 'city': 12, 'building_type': 6, 'building_use': 11, 'parking_way': 4, 'town': 208, 'village': 2598, 'encoded_latlon': 7}
# Embeding output dims: {'building_material': 5, 'city': 6, 'building_type': 4, 'building_use': 5, 'parking_way': 4, 'town': 11, 'village': 16, 'encoded_latlon': 5}
# Total embedding output dims: 56
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/200
#  - 107s - loss: 0.2769 - mean_squared_error: 0.1450 - val_loss: 0.2459 - val_mean_squared_error: 0.1056
# Epoch 2/200
#  - 107s - loss: 0.2081 - mean_squared_error: 0.0829 - val_loss: 0.1949 - val_mean_squared_error: 0.0731
# Epoch 3/200
#  - 107s - loss: 0.1929 - mean_squared_error: 0.0726 - val_loss: 0.2035 - val_mean_squared_error: 0.0782
# Epoch 4/200
#  - 101s - loss: 0.1809 - mean_squared_error: 0.0649 - val_loss: 0.2028 - val_mean_squared_error: 0.0806
# Epoch 5/200
#  - 97s - loss: 0.1710 - mean_squared_error: 0.0591 - val_loss: 0.1959 - val_mean_squared_error: 0.0737
# Epoch 6/200
#  - 97s - loss: 0.1653 - mean_squared_error: 0.0558 - val_loss: 0.1846 - val_mean_squared_error: 0.0673
# Epoch 7/200
#  - 97s - loss: 0.1593 - mean_squared_error: 0.0524 - val_loss: 0.1724 - val_mean_squared_error: 0.0604
# Epoch 8/200
#  - 102s - loss: 0.1518 - mean_squared_error: 0.0485 - val_loss: 0.1734 - val_mean_squared_error: 0.0612
# Epoch 9/200
#  - 97s - loss: 0.1469 - mean_squared_error: 0.0455 - val_loss: 0.1768 - val_mean_squared_error: 0.0622
# Epoch 10/200
#  - 98s - loss: 0.1422 - mean_squared_error: 0.0438 - val_loss: 0.1825 - val_mean_squared_error: 0.0648
# Epoch 11/200
#  - 103s - loss: 0.1397 - mean_squared_error: 0.0417 - val_loss: 0.1750 - val_mean_squared_error: 0.0607
# Epoch 12/200
#  - 108s - loss: 0.1345 - mean_squared_error: 0.0394 - val_loss: 0.1706 - val_mean_squared_error: 0.0594
# Epoch 13/200
#  - 106s - loss: 0.1296 - mean_squared_error: 0.0374 - val_loss: 0.1679 - val_mean_squared_error: 0.0574
# Epoch 14/200
#  - 108s - loss: 0.1270 - mean_squared_error: 0.0356 - val_loss: 0.1689 - val_mean_squared_error: 0.0609
# Epoch 15/200
#  - 106s - loss: 0.1237 - mean_squared_error: 0.0341 - val_loss: 0.1646 - val_mean_squared_error: 0.0561
# Epoch 16/200
#  - 110s - loss: 0.1192 - mean_squared_error: 0.0323 - val_loss: 0.1623 - val_mean_squared_error: 0.0556
# Epoch 17/200
#  - 110s - loss: 0.1160 - mean_squared_error: 0.0308 - val_loss: 0.1653 - val_mean_squared_error: 0.0563
# Epoch 18/200
#  - 110s - loss: 0.1136 - mean_squared_error: 0.0299 - val_loss: 0.1626 - val_mean_squared_error: 0.0553
# Epoch 19/200
#  - 103s - loss: 0.1117 - mean_squared_error: 0.0289 - val_loss: 0.1641 - val_mean_squared_error: 0.0568
# Epoch 20/200
#  - 106s - loss: 0.1086 - mean_squared_error: 0.0276 - val_loss: 0.1728 - val_mean_squared_error: 0.0599
# Epoch 21/200
#  - 108s - loss: 0.1056 - mean_squared_error: 0.0264 - val_loss: 0.1595 - val_mean_squared_error: 0.0541
# Epoch 22/200
#  - 110s - loss: 0.1023 - mean_squared_error: 0.0250 - val_loss: 0.1591 - val_mean_squared_error: 0.0544
# Epoch 23/200
#  - 108s - loss: 0.1001 - mean_squared_error: 0.0240 - val_loss: 0.1597 - val_mean_squared_error: 0.0545
# Epoch 24/200
#  - 109s - loss: 0.0978 - mean_squared_error: 0.0232 - val_loss: 0.1596 - val_mean_squared_error: 0.0551
# Epoch 25/200
#  - 110s - loss: 0.0960 - mean_squared_error: 0.0224 - val_loss: 0.1585 - val_mean_squared_error: 0.0539
# Epoch 26/200
#  - 110s - loss: 0.0926 - mean_squared_error: 0.0212 - val_loss: 0.1586 - val_mean_squared_error: 0.0546
# Epoch 27/200
#  - 108s - loss: 0.0910 - mean_squared_error: 0.0205 - val_loss: 0.1595 - val_mean_squared_error: 0.0551
# Epoch 28/200
#  - 108s - loss: 0.0890 - mean_squared_error: 0.0200 - val_loss: 0.1586 - val_mean_squared_error: 0.0548
# Epoch 29/200
#  - 108s - loss: 0.0878 - mean_squared_error: 0.0193 - val_loss: 0.1599 - val_mean_squared_error: 0.0546
# Epoch 30/200
#  - 107s - loss: 0.0869 - mean_squared_error: 0.0190 - val_loss: 0.1572 - val_mean_squared_error: 0.0537
# Epoch 31/200
#  - 105s - loss: 0.0839 - mean_squared_error: 0.0178 - val_loss: 0.1740 - val_mean_squared_error: 0.0619
# Epoch 32/200
#  - 105s - loss: 0.0820 - mean_squared_error: 0.0173 - val_loss: 0.1587 - val_mean_squared_error: 0.0545
# Epoch 33/200
#  - 111s - loss: 0.0806 - mean_squared_error: 0.0174 - val_loss: 0.1583 - val_mean_squared_error: 0.0544
# Epoch 34/200
#  - 110s - loss: 0.0785 - mean_squared_error: 0.0161 - val_loss: 0.1561 - val_mean_squared_error: 0.0537
# Epoch 35/200
#  - 110s - loss: 0.0780 - mean_squared_error: 0.0158 - val_loss: 0.1590 - val_mean_squared_error: 0.0548
# Epoch 36/200
#  - 108s - loss: 0.0776 - mean_squared_error: 0.0156 - val_loss: 0.1563 - val_mean_squared_error: 0.0537
# Epoch 37/200
#  - 108s - loss: 0.0749 - mean_squared_error: 0.0148 - val_loss: 0.1560 - val_mean_squared_error: 0.0539
# Epoch 38/200
#  - 107s - loss: 0.0754 - mean_squared_error: 0.0148 - val_loss: 0.1581 - val_mean_squared_error: 0.0549
# Epoch 39/200
#  - 107s - loss: 0.0728 - mean_squared_error: 0.0139 - val_loss: 0.1590 - val_mean_squared_error: 0.0548
# Epoch 40/200
#  - 109s - loss: 0.0724 - mean_squared_error: 0.0138 - val_loss: 0.1612 - val_mean_squared_error: 0.0553
# Epoch 41/200
#  - 110s - loss: 0.0711 - mean_squared_error: 0.0135 - val_loss: 0.1570 - val_mean_squared_error: 0.0541
# Epoch 42/200
#  - 109s - loss: 0.0697 - mean_squared_error: 0.0130 - val_loss: 0.1578 - val_mean_squared_error: 0.0549
# Epoch 43/200
#  - 109s - loss: 0.0701 - mean_squared_error: 0.0131 - val_loss: 0.1604 - val_mean_squared_error: 0.0554
# Epoch 44/200
#  - 107s - loss: 0.0667 - mean_squared_error: 0.0122 - val_loss: 0.1573 - val_mean_squared_error: 0.0550
# Epoch 45/200
#  - 102s - loss: 0.0665 - mean_squared_error: 0.0120 - val_loss: 0.1549 - val_mean_squared_error: 0.0532
# Epoch 46/200
#  - 97s - loss: 0.0654 - mean_squared_error: 0.0118 - val_loss: 0.1560 - val_mean_squared_error: 0.0535
# Epoch 47/200
#  - 96s - loss: 0.0645 - mean_squared_error: 0.0116 - val_loss: 0.1592 - val_mean_squared_error: 0.0550
# Epoch 48/200
#  - 97s - loss: 0.0639 - mean_squared_error: 0.0113 - val_loss: 0.1572 - val_mean_squared_error: 0.0542
# Epoch 49/200
#  - 97s - loss: 0.0624 - mean_squared_error: 0.0110 - val_loss: 0.1565 - val_mean_squared_error: 0.0537
# Epoch 50/200
#  - 97s - loss: 0.0614 - mean_squared_error: 0.0106 - val_loss: 0.1556 - val_mean_squared_error: 0.0539
# Epoch 51/200
#  - 97s - loss: 0.0609 - mean_squared_error: 0.0104 - val_loss: 0.1571 - val_mean_squared_error: 0.0540
# Epoch 52/200
#  - 98s - loss: 0.0595 - mean_squared_error: 0.0100 - val_loss: 0.1552 - val_mean_squared_error: 0.0538
# Epoch 53/200
#  - 101s - loss: 0.0601 - mean_squared_error: 0.0101 - val_loss: 0.1561 - val_mean_squared_error: 0.0538
# Epoch 54/200
#  - 102s - loss: 0.0580 - mean_squared_error: 0.0095 - val_loss: 0.1562 - val_mean_squared_error: 0.0543
# Epoch 55/200
#  - 103s - loss: 0.0584 - mean_squared_error: 0.0097 - val_loss: 0.1558 - val_mean_squared_error: 0.0542
# Epoch 56/200
#  - 101s - loss: 0.0567 - mean_squared_error: 0.0092 - val_loss: 0.1558 - val_mean_squared_error: 0.0542
# Epoch 57/200
#  - 104s - loss: 0.0564 - mean_squared_error: 0.0092 - val_loss: 0.1555 - val_mean_squared_error: 0.0539
# Epoch 58/200
#  - 105s - loss: 0.0563 - mean_squared_error: 0.0091 - val_loss: 0.1563 - val_mean_squared_error: 0.0548
# Epoch 59/200
#  - 109s - loss: 0.0548 - mean_squared_error: 0.0087 - val_loss: 0.1556 - val_mean_squared_error: 0.0543
# Epoch 60/200
#  - 109s - loss: 0.0548 - mean_squared_error: 0.0086 - val_loss: 0.1554 - val_mean_squared_error: 0.0542
# Epoch 61/200
#  - 109s - loss: 0.0532 - mean_squared_error: 0.0083 - val_loss: 0.1546 - val_mean_squared_error: 0.0536
# Epoch 62/200
#  - 108s - loss: 0.0538 - mean_squared_error: 0.0084 - val_loss: 0.1553 - val_mean_squared_error: 0.0542
# Epoch 63/200
#  - 107s - loss: 0.0525 - mean_squared_error: 0.0081 - val_loss: 0.1550 - val_mean_squared_error: 0.0539
# Epoch 64/200
#  - 102s - loss: 0.0512 - mean_squared_error: 0.0081 - val_loss: 0.1550 - val_mean_squared_error: 0.0541
# Epoch 65/200
#  - 96s - loss: 0.0517 - mean_squared_error: 0.0079 - val_loss: 0.1580 - val_mean_squared_error: 0.0558
# Epoch 66/200
#  - 96s - loss: 0.0510 - mean_squared_error: 0.0078 - val_loss: 0.1559 - val_mean_squared_error: 0.0542
# Epoch 67/200
#  - 96s - loss: 0.0505 - mean_squared_error: 0.0076 - val_loss: 0.1550 - val_mean_squared_error: 0.0544
# Epoch 68/200
#  - 96s - loss: 0.0492 - mean_squared_error: 0.0073 - val_loss: 0.1558 - val_mean_squared_error: 0.0548
# Epoch 69/200
#  - 96s - loss: 0.0496 - mean_squared_error: 0.0073 - val_loss: 0.1565 - val_mean_squared_error: 0.0545
# Epoch 70/200
#  - 96s - loss: 0.0484 - mean_squared_error: 0.0071 - val_loss: 0.1556 - val_mean_squared_error: 0.0543
# Epoch 71/200
#  - 96s - loss: 0.0495 - mean_squared_error: 0.0073 - val_loss: 0.1548 - val_mean_squared_error: 0.0539
# Epoch 72/200
#  - 96s - loss: 0.0478 - mean_squared_error: 0.0070 - val_loss: 0.1548 - val_mean_squared_error: 0.0538
# Epoch 73/200
#  - 96s - loss: 0.0467 - mean_squared_error: 0.0067 - val_loss: 0.1571 - val_mean_squared_error: 0.0547
# Epoch 74/200
#  - 96s - loss: 0.0483 - mean_squared_error: 0.0070 - val_loss: 0.1560 - val_mean_squared_error: 0.0540
# Epoch 75/200
#  - 96s - loss: 0.0459 - mean_squared_error: 0.0066 - val_loss: 0.1548 - val_mean_squared_error: 0.0542
# Epoch 76/200
#  - 96s - loss: 0.0465 - mean_squared_error: 0.0066 - val_loss: 0.1546 - val_mean_squared_error: 0.0538
# Epoch 77/200
#  - 96s - loss: 0.0467 - mean_squared_error: 0.0069 - val_loss: 0.1553 - val_mean_squared_error: 0.0542
# Epoch 78/200
#  - 98s - loss: 0.0456 - mean_squared_error: 0.0065 - val_loss: 0.1595 - val_mean_squared_error: 0.0560
# Epoch 79/200
#  - 97s - loss: 0.0444 - mean_squared_error: 0.0062 - val_loss: 0.1557 - val_mean_squared_error: 0.0539
# Epoch 80/200
#  - 97s - loss: 0.0448 - mean_squared_error: 0.0062 - val_loss: 0.1542 - val_mean_squared_error: 0.0537
# Epoch 81/200
#  - 97s - loss: 0.0450 - mean_squared_error: 0.0079 - val_loss: 0.1556 - val_mean_squared_error: 0.0545
# Epoch 82/200
#  - 97s - loss: 0.0444 - mean_squared_error: 0.0062 - val_loss: 0.1544 - val_mean_squared_error: 0.0536
# Epoch 83/200
#  - 96s - loss: 0.0441 - mean_squared_error: 0.0061 - val_loss: 0.1546 - val_mean_squared_error: 0.0541
# Epoch 84/200
#  - 97s - loss: 0.0432 - mean_squared_error: 0.0060 - val_loss: 0.1548 - val_mean_squared_error: 0.0538
# Epoch 85/200
#  - 97s - loss: 0.0420 - mean_squared_error: 0.0057 - val_loss: 0.1534 - val_mean_squared_error: 0.0538
# Epoch 86/200
#  - 97s - loss: 0.0420 - mean_squared_error: 0.0067 - val_loss: 0.1545 - val_mean_squared_error: 0.0540
# Epoch 87/200
#  - 97s - loss: 0.0416 - mean_squared_error: 0.0056 - val_loss: 0.1541 - val_mean_squared_error: 0.0542
# Epoch 88/200
#  - 96s - loss: 0.0429 - mean_squared_error: 0.0059 - val_loss: 0.1541 - val_mean_squared_error: 0.0537
# Epoch 89/200
#  - 96s - loss: 0.0413 - mean_squared_error: 0.0055 - val_loss: 0.1542 - val_mean_squared_error: 0.0535
# Epoch 90/200
#  - 96s - loss: 0.0415 - mean_squared_error: 0.0055 - val_loss: 0.1536 - val_mean_squared_error: 0.0535
# Epoch 91/200
#  - 96s - loss: 0.0423 - mean_squared_error: 0.0058 - val_loss: 0.1566 - val_mean_squared_error: 0.0548
# Epoch 92/200
#  - 96s - loss: 0.0408 - mean_squared_error: 0.0053 - val_loss: 0.1552 - val_mean_squared_error: 0.0541
# Epoch 93/200
#  - 97s - loss: 0.0412 - mean_squared_error: 0.0054 - val_loss: 0.1574 - val_mean_squared_error: 0.0550
# Epoch 94/200
#  - 97s - loss: 0.0403 - mean_squared_error: 0.0068 - val_loss: 0.1547 - val_mean_squared_error: 0.0538
# Epoch 95/200
#  - 102s - loss: 0.0401 - mean_squared_error: 0.0052 - val_loss: 0.1539 - val_mean_squared_error: 0.0539
# Epoch 96/200
#  - 107s - loss: 0.0396 - mean_squared_error: 0.0051 - val_loss: 0.1557 - val_mean_squared_error: 0.0543
# Epoch 97/200
#  - 106s - loss: 0.0386 - mean_squared_error: 0.0050 - val_loss: 0.1533 - val_mean_squared_error: 0.0536
# Epoch 98/200
#  - 108s - loss: 0.0390 - mean_squared_error: 0.0052 - val_loss: 0.1531 - val_mean_squared_error: 0.0532
# Epoch 99/200
#  - 110s - loss: 0.0386 - mean_squared_error: 0.0049 - val_loss: 0.1552 - val_mean_squared_error: 0.0542
# Epoch 100/200
#  - 110s - loss: 0.0379 - mean_squared_error: 0.0047 - val_loss: 0.1536 - val_mean_squared_error: 0.0546
# Epoch 101/200
#  - 108s - loss: 0.0382 - mean_squared_error: 0.0052 - val_loss: 0.1528 - val_mean_squared_error: 0.0534
# Epoch 102/200
#  - 105s - loss: 0.0383 - mean_squared_error: 0.0048 - val_loss: 0.1540 - val_mean_squared_error: 0.0540
# Epoch 103/200
#  - 105s - loss: 0.0381 - mean_squared_error: 0.0048 - val_loss: 0.1557 - val_mean_squared_error: 0.0543
# Epoch 104/200
#  - 109s - loss: 0.0371 - mean_squared_error: 0.0056 - val_loss: 0.1539 - val_mean_squared_error: 0.0537
# Epoch 105/200
#  - 108s - loss: 0.0376 - mean_squared_error: 0.0047 - val_loss: 0.1541 - val_mean_squared_error: 0.0541
# Epoch 106/200
#  - 109s - loss: 0.0372 - mean_squared_error: 0.0046 - val_loss: 0.1548 - val_mean_squared_error: 0.0545
# Epoch 107/200
#  - 108s - loss: 0.0371 - mean_squared_error: 0.0046 - val_loss: 0.1527 - val_mean_squared_error: 0.0532
# Epoch 108/200
#  - 103s - loss: 0.0366 - mean_squared_error: 0.0046 - val_loss: 0.1537 - val_mean_squared_error: 0.0539
# Epoch 109/200
#  - 101s - loss: 0.0357 - mean_squared_error: 0.0044 - val_loss: 0.1539 - val_mean_squared_error: 0.0540
# Epoch 110/200
#  - 97s - loss: 0.0352 - mean_squared_error: 0.0044 - val_loss: 0.1542 - val_mean_squared_error: 0.0538
# Epoch 111/200
#  - 96s - loss: 0.0350 - mean_squared_error: 0.0043 - val_loss: 0.1546 - val_mean_squared_error: 0.0541
# Epoch 112/200
#  - 96s - loss: 0.0351 - mean_squared_error: 0.0043 - val_loss: 0.1527 - val_mean_squared_error: 0.0532
# Epoch 113/200
#  - 97s - loss: 0.0344 - mean_squared_error: 0.0041 - val_loss: 0.1541 - val_mean_squared_error: 0.0536
# Epoch 114/200
#  - 96s - loss: 0.0350 - mean_squared_error: 0.0042 - val_loss: 0.1534 - val_mean_squared_error: 0.0539
# Epoch 115/200
#  - 97s - loss: 0.0348 - mean_squared_error: 0.0042 - val_loss: 0.1530 - val_mean_squared_error: 0.0536
# Epoch 116/200
#  - 96s - loss: 0.0341 - mean_squared_error: 0.0043 - val_loss: 0.1523 - val_mean_squared_error: 0.0537
# Epoch 117/200
#  - 96s - loss: 0.0346 - mean_squared_error: 0.0041 - val_loss: 0.1571 - val_mean_squared_error: 0.0555
# Epoch 118/200
#  - 96s - loss: 0.0362 - mean_squared_error: 0.0043 - val_loss: 0.1531 - val_mean_squared_error: 0.0538
# Epoch 119/200
#  - 96s - loss: 0.0344 - mean_squared_error: 0.0041 - val_loss: 0.1534 - val_mean_squared_error: 0.0538
# Epoch 120/200
#  - 97s - loss: 0.0335 - mean_squared_error: 0.0039 - val_loss: 0.1519 - val_mean_squared_error: 0.0534
# Epoch 121/200
#  - 97s - loss: 0.0331 - mean_squared_error: 0.0038 - val_loss: 0.1554 - val_mean_squared_error: 0.0554
# Epoch 122/200
#  - 97s - loss: 0.0347 - mean_squared_error: 0.0041 - val_loss: 0.1532 - val_mean_squared_error: 0.0538
# Epoch 123/200
#  - 98s - loss: 0.0345 - mean_squared_error: 0.0040 - val_loss: 0.1526 - val_mean_squared_error: 0.0537
# Epoch 124/200
#  - 98s - loss: 0.0334 - mean_squared_error: 0.0040 - val_loss: 0.1544 - val_mean_squared_error: 0.0545
# Epoch 125/200
#  - 97s - loss: 0.0327 - mean_squared_error: 0.0038 - val_loss: 0.1530 - val_mean_squared_error: 0.0549
# Epoch 126/200
#  - 98s - loss: 0.0326 - mean_squared_error: 0.0038 - val_loss: 0.1532 - val_mean_squared_error: 0.0534
# Epoch 127/200
#  - 98s - loss: 0.0327 - mean_squared_error: 0.0037 - val_loss: 0.1536 - val_mean_squared_error: 0.0541
# Epoch 128/200
#  - 100s - loss: 0.0330 - mean_squared_error: 0.0038 - val_loss: 0.1534 - val_mean_squared_error: 0.0539
# Epoch 129/200
#  - 97s - loss: 0.0334 - mean_squared_error: 0.0040 - val_loss: 0.1551 - val_mean_squared_error: 0.0549
# Epoch 130/200
#  - 97s - loss: 0.0329 - mean_squared_error: 0.0038 - val_loss: 0.1536 - val_mean_squared_error: 0.0538
# Epoch 131/200
#  - 97s - loss: 0.0318 - mean_squared_error: 0.0037 - val_loss: 0.1537 - val_mean_squared_error: 0.0541
# Epoch 132/200
#  - 98s - loss: 0.0318 - mean_squared_error: 0.0036 - val_loss: 0.1532 - val_mean_squared_error: 0.0535
# Epoch 133/200
#  - 98s - loss: 0.0326 - mean_squared_error: 0.0037 - val_loss: 0.1543 - val_mean_squared_error: 0.0542
# Epoch 134/200
#  - 99s - loss: 0.0322 - mean_squared_error: 0.0036 - val_loss: 0.1531 - val_mean_squared_error: 0.0535
# Epoch 135/200
#  - 101s - loss: 0.0309 - mean_squared_error: 0.0034 - val_loss: 0.1533 - val_mean_squared_error: 0.0541
# Epoch 136/200
#  - 104s - loss: 0.0315 - mean_squared_error: 0.0035 - val_loss: 0.1536 - val_mean_squared_error: 0.0537
# Epoch 137/200
#  - 107s - loss: 0.0316 - mean_squared_error: 0.0035 - val_loss: 0.1527 - val_mean_squared_error: 0.0535
# Epoch 138/200
#  - 103s - loss: 0.0312 - mean_squared_error: 0.0035 - val_loss: 0.1529 - val_mean_squared_error: 0.0535
# Epoch 139/200
#  - 101s - loss: 0.0322 - mean_squared_error: 0.0037 - val_loss: 0.1538 - val_mean_squared_error: 0.0536
# Epoch 140/200
#  - 104s - loss: 0.0312 - mean_squared_error: 0.0034 - val_loss: 0.1510 - val_mean_squared_error: 0.0523
# Epoch 141/200
#  - 106s - loss: 0.0299 - mean_squared_error: 0.0032 - val_loss: 0.1523 - val_mean_squared_error: 0.0534
# Epoch 142/200
#  - 109s - loss: 0.0298 - mean_squared_error: 0.0032 - val_loss: 0.1520 - val_mean_squared_error: 0.0530
# Epoch 143/200
#  - 110s - loss: 0.0300 - mean_squared_error: 0.0032 - val_loss: 0.1519 - val_mean_squared_error: 0.0530
# Epoch 144/200
#  - 109s - loss: 0.0309 - mean_squared_error: 0.0034 - val_loss: 0.1542 - val_mean_squared_error: 0.0541
# Epoch 145/200
#  - 105s - loss: 0.0317 - mean_squared_error: 0.0035 - val_loss: 0.1524 - val_mean_squared_error: 0.0533
# Epoch 146/200
#  - 97s - loss: 0.0301 - mean_squared_error: 0.0033 - val_loss: 0.1525 - val_mean_squared_error: 0.0532
# Epoch 147/200
#  - 97s - loss: 0.0288 - mean_squared_error: 0.0031 - val_loss: 0.1522 - val_mean_squared_error: 0.0533
# Epoch 148/200
#  - 97s - loss: 0.0291 - mean_squared_error: 0.0031 - val_loss: 0.1537 - val_mean_squared_error: 0.0546
# Epoch 149/200
#  - 98s - loss: 0.0291 - mean_squared_error: 0.0031 - val_loss: 0.1518 - val_mean_squared_error: 0.0529
# Epoch 150/200
#  - 97s - loss: 0.0299 - mean_squared_error: 0.0033 - val_loss: 0.1537 - val_mean_squared_error: 0.0543
# Epoch 151/200
#  - 103s - loss: 0.0295 - mean_squared_error: 0.0031 - val_loss: 0.1531 - val_mean_squared_error: 0.0541
# Epoch 152/200
#  - 97s - loss: 0.0294 - mean_squared_error: 0.0031 - val_loss: 0.1524 - val_mean_squared_error: 0.0535
# Epoch 153/200
#  - 98s - loss: 0.0294 - mean_squared_error: 0.0031 - val_loss: 0.1535 - val_mean_squared_error: 0.0539
# Epoch 154/200
#  - 98s - loss: 0.0301 - mean_squared_error: 0.0032 - val_loss: 0.1528 - val_mean_squared_error: 0.0538
# Epoch 155/200
#  - 99s - loss: 0.0286 - mean_squared_error: 0.0030 - val_loss: 0.1518 - val_mean_squared_error: 0.0530
# Epoch 156/200
#  - 102s - loss: 0.0288 - mean_squared_error: 0.0030 - val_loss: 0.1519 - val_mean_squared_error: 0.0530
# Epoch 157/200
#  - 104s - loss: 0.0288 - mean_squared_error: 0.0030 - val_loss: 0.1527 - val_mean_squared_error: 0.0537
# Epoch 158/200
#  - 109s - loss: 0.0283 - mean_squared_error: 0.0030 - val_loss: 0.1525 - val_mean_squared_error: 0.0537
# Epoch 159/200
#  - 109s - loss: 0.0285 - mean_squared_error: 0.0030 - val_loss: 0.1529 - val_mean_squared_error: 0.0537
# Epoch 160/200
#  - 109s - loss: 0.0288 - mean_squared_error: 0.0030 - val_loss: 0.1528 - val_mean_squared_error: 0.0539
# Epoch 161/200
#  - 110s - loss: 0.0280 - mean_squared_error: 0.0029 - val_loss: 0.1532 - val_mean_squared_error: 0.0537
# Epoch 162/200
#  - 109s - loss: 0.0279 - mean_squared_error: 0.0044 - val_loss: 0.1524 - val_mean_squared_error: 0.0533
# Epoch 163/200
#  - 108s - loss: 0.0284 - mean_squared_error: 0.0030 - val_loss: 0.1524 - val_mean_squared_error: 0.0534
# Epoch 164/200
#  - 107s - loss: 0.0292 - mean_squared_error: 0.0030 - val_loss: 0.1541 - val_mean_squared_error: 0.0538
# Epoch 165/200
#  - 107s - loss: 0.0294 - mean_squared_error: 0.0031 - val_loss: 0.1521 - val_mean_squared_error: 0.0531
# Epoch 166/200
#  - 108s - loss: 0.0283 - mean_squared_error: 0.0029 - val_loss: 0.1524 - val_mean_squared_error: 0.0534
# Epoch 167/200
#  - 107s - loss: 0.0291 - mean_squared_error: 0.0030 - val_loss: 0.1538 - val_mean_squared_error: 0.0543
# Epoch 168/200
#  - 107s - loss: 0.0285 - mean_squared_error: 0.0029 - val_loss: 0.1529 - val_mean_squared_error: 0.0540
# Epoch 169/200
#  - 108s - loss: 0.0267 - mean_squared_error: 0.0027 - val_loss: 0.1524 - val_mean_squared_error: 0.0533
# Epoch 170/200
#  - 109s - loss: 0.0279 - mean_squared_error: 0.0029 - val_loss: 0.1538 - val_mean_squared_error: 0.0540
# Epoch 171/200
#  - 108s - loss: 0.0284 - mean_squared_error: 0.0030 - val_loss: 0.1519 - val_mean_squared_error: 0.0533
# Epoch 172/200
#  - 107s - loss: 0.0272 - mean_squared_error: 0.0029 - val_loss: 0.1519 - val_mean_squared_error: 0.0533
# Epoch 173/200
#  - 108s - loss: 0.0271 - mean_squared_error: 0.0029 - val_loss: 0.1523 - val_mean_squared_error: 0.0534
# Epoch 174/200
#  - 108s - loss: 0.0264 - mean_squared_error: 0.0028 - val_loss: 0.1527 - val_mean_squared_error: 0.0537
# Epoch 175/200
#  - 109s - loss: 0.0272 - mean_squared_error: 0.0029 - val_loss: 0.1519 - val_mean_squared_error: 0.0532
# Epoch 176/200
#  - 108s - loss: 0.0278 - mean_squared_error: 0.0029 - val_loss: 0.1525 - val_mean_squared_error: 0.0536
# Epoch 177/200
#  - 107s - loss: 0.0276 - mean_squared_error: 0.0028 - val_loss: 0.1517 - val_mean_squared_error: 0.0531
# Epoch 178/200
#  - 107s - loss: 0.0271 - mean_squared_error: 0.0027 - val_loss: 0.1519 - val_mean_squared_error: 0.0534
# Epoch 179/200
#  - 107s - loss: 0.0269 - mean_squared_error: 0.0027 - val_loss: 0.1532 - val_mean_squared_error: 0.0546
# Epoch 180/200
#  - 97s - loss: 0.0262 - mean_squared_error: 0.0026 - val_loss: 0.1520 - val_mean_squared_error: 0.0537
# Epoch 181/200
#  - 96s - loss: 0.0272 - mean_squared_error: 0.0028 - val_loss: 0.1519 - val_mean_squared_error: 0.0534
# Epoch 182/200
#  - 96s - loss: 0.0264 - mean_squared_error: 0.0040 - val_loss: 0.1525 - val_mean_squared_error: 0.0539
# Epoch 183/200
#  - 96s - loss: 0.0266 - mean_squared_error: 0.0027 - val_loss: 0.1517 - val_mean_squared_error: 0.0534
# Epoch 184/200
#  - 96s - loss: 0.0266 - mean_squared_error: 0.0026 - val_loss: 0.1530 - val_mean_squared_error: 0.0544
# Epoch 185/200
#  - 96s - loss: 0.0262 - mean_squared_error: 0.0025 - val_loss: 0.1533 - val_mean_squared_error: 0.0537
# Epoch 186/200
#  - 96s - loss: 0.0271 - mean_squared_error: 0.0027 - val_loss: 0.1515 - val_mean_squared_error: 0.0530
# Epoch 187/200
#  - 96s - loss: 0.0263 - mean_squared_error: 0.0026 - val_loss: 0.1518 - val_mean_squared_error: 0.0530
# Epoch 188/200
#  - 96s - loss: 0.0261 - mean_squared_error: 0.0030 - val_loss: 0.1519 - val_mean_squared_error: 0.0532
# Epoch 189/200
#  - 96s - loss: 0.0257 - mean_squared_error: 0.0025 - val_loss: 0.1516 - val_mean_squared_error: 0.0534
# Epoch 190/200
#  - 96s - loss: 0.0253 - mean_squared_error: 0.0024 - val_loss: 0.1532 - val_mean_squared_error: 0.0540
# Epoch 191/200
#  - 96s - loss: 0.0277 - mean_squared_error: 0.0047 - val_loss: 0.1529 - val_mean_squared_error: 0.0542
# Epoch 192/200
#  - 96s - loss: 0.0263 - mean_squared_error: 0.0025 - val_loss: 0.1545 - val_mean_squared_error: 0.0544
# Epoch 193/200
#  - 96s - loss: 0.0262 - mean_squared_error: 0.0025 - val_loss: 0.1535 - val_mean_squared_error: 0.0543
# Epoch 194/200
#  - 96s - loss: 0.0257 - mean_squared_error: 0.0024 - val_loss: 0.1536 - val_mean_squared_error: 0.0541
# Epoch 195/200
#  - 96s - loss: 0.0250 - mean_squared_error: 0.0024 - val_loss: 0.1524 - val_mean_squared_error: 0.0538
# Epoch 196/200
#  - 96s - loss: 0.0249 - mean_squared_error: 0.0023 - val_loss: 0.1526 - val_mean_squared_error: 0.0538
# Epoch 197/200
#  - 96s - loss: 0.0260 - mean_squared_error: 0.0025 - val_loss: 0.1526 - val_mean_squared_error: 0.0541
# Epoch 198/200
#  - 96s - loss: 0.0247 - mean_squared_error: 0.0023 - val_loss: 0.1526 - val_mean_squared_error: 0.0538
# Epoch 199/200
#  - 96s - loss: 0.0249 - mean_squared_error: 0.0022 - val_loss: 0.1522 - val_mean_squared_error: 0.0537
# Epoch 200/200
#  - 97s - loss: 0.0256 - mean_squared_error: 0.0024 - val_loss: 0.1528 - val_mean_squared_error: 0.0539
# (Fold 1) score, mse, mae, mape: 5138.84829, 0.04886, 0.14594, 0.01095.
# ==== Fold 3 ====
# Numerical input dims: 205
# Embeding  input dims: {'building_material': 10, 'city': 12, 'building_type': 6, 'building_use': 11, 'parking_way': 4, 'town': 207, 'village': 2599, 'encoded_latlon': 7}
# ...
# Epoch 65/200
#  - 97s - loss: 0.0524 - mean_squared_error: 0.0080 - val_loss: 0.1607 - val_mean_squared_error: 0.0605
# Epoch 66/200
#  - 97s - loss: 0.0517 - mean_squared_error: 0.0078 - val_loss: 0.1551 - val_mean_squared_error: 0.0569
# Epoch 67/200
#  - 97s - loss: 0.0505 - mean_squared_error: 0.0075 - val_loss: 0.1554 - val_mean_squared_error: 0.0571
# Epoch 68/200
#  - 97s - loss: 0.0513 - mean_squared_error: 0.0077 - val_loss: 0.1569 - val_mean_squared_error: 0.0582
# Epoch 69/200
#  - 97s - loss: 0.0499 - mean_squared_error: 0.0073 - val_loss: 0.1555 - val_mean_squared_error: 0.0576
# Epoch 70/200
#  - 104s - loss: 0.0489 - mean_squared_error: 0.0071 - val_loss: 0.1558 - val_mean_squared_error: 0.0581
# Epoch 71/200
#  - 109s - loss: 0.0486 - mean_squared_error: 0.0070 - val_loss: 0.1558 - val_mean_squared_error: 0.0576
# Epoch 72/200
#  - 108s - loss: 0.0476 - mean_squared_error: 0.0068 - val_loss: 0.1564 - val_mean_squared_error: 0.0580
# Epoch 73/200
#  - 109s - loss: 0.0484 - mean_squared_error: 0.0069 - val_loss: 0.1554 - val_mean_squared_error: 0.0578
# Epoch 74/200
#  - 105s - loss: 0.0478 - mean_squared_error: 0.0069 - val_loss: 0.1568 - val_mean_squared_error: 0.0585
# Epoch 75/200
#  - 105s - loss: 0.0471 - mean_squared_error: 0.0066 - val_loss: 0.1573 - val_mean_squared_error: 0.0589
# Epoch 76/200
#  - 107s - loss: 0.0473 - mean_squared_error: 0.0067 - val_loss: 0.1604 - val_mean_squared_error: 0.0621
# Epoch 77/200
#  - 107s - loss: 0.0472 - mean_squared_error: 0.0066 - val_loss: 0.1563 - val_mean_squared_error: 0.0574
# Epoch 78/200
#  - 108s - loss: 0.0462 - mean_squared_error: 0.0069 - val_loss: 0.1559 - val_mean_squared_error: 0.0577
# Epoch 79/200
#  - 110s - loss: 0.0450 - mean_squared_error: 0.0064 - val_loss: 0.1553 - val_mean_squared_error: 0.0576
# Epoch 80/200
#  - 110s - loss: 0.0447 - mean_squared_error: 0.0061 - val_loss: 0.1543 - val_mean_squared_error: 0.0569
# Epoch 81/200
#  - 108s - loss: 0.0444 - mean_squared_error: 0.0060 - val_loss: 0.1571 - val_mean_squared_error: 0.0580
# Epoch 82/200
#  - 108s - loss: 0.0447 - mean_squared_error: 0.0060 - val_loss: 0.1575 - val_mean_squared_error: 0.0586
# Epoch 83/200
#  - 106s - loss: 0.0441 - mean_squared_error: 0.0060 - val_loss: 0.1582 - val_mean_squared_error: 0.0587
# Epoch 84/200
#  - 97s - loss: 0.0435 - mean_squared_error: 0.0058 - val_loss: 0.1561 - val_mean_squared_error: 0.0585
# Epoch 85/200
#  - 98s - loss: 0.0435 - mean_squared_error: 0.0058 - val_loss: 0.1592 - val_mean_squared_error: 0.0597
# Epoch 86/200
#  - 98s - loss: 0.0424 - mean_squared_error: 0.0056 - val_loss: 0.1558 - val_mean_squared_error: 0.0578
# Epoch 87/200
#  - 98s - loss: 0.0419 - mean_squared_error: 0.0055 - val_loss: 0.1563 - val_mean_squared_error: 0.0588
# Epoch 88/200
#  - 99s - loss: 0.0422 - mean_squared_error: 0.0065 - val_loss: 0.1544 - val_mean_squared_error: 0.0570
# Epoch 89/200
#  - 99s - loss: 0.0416 - mean_squared_error: 0.0054 - val_loss: 0.1557 - val_mean_squared_error: 0.0577
# Epoch 90/200
#  - 103s - loss: 0.0416 - mean_squared_error: 0.0057 - val_loss: 0.1563 - val_mean_squared_error: 0.0582
# Epoch 91/200
#  - 105s - loss: 0.0411 - mean_squared_error: 0.0054 - val_loss: 0.1556 - val_mean_squared_error: 0.0581
# Epoch 92/200
#  - 102s - loss: 0.0406 - mean_squared_error: 0.0052 - val_loss: 0.1548 - val_mean_squared_error: 0.0575
# Epoch 93/200
#  - 107s - loss: 0.0399 - mean_squared_error: 0.0051 - val_loss: 0.1565 - val_mean_squared_error: 0.0586
# Epoch 94/200
#  - 107s - loss: 0.0398 - mean_squared_error: 0.0050 - val_loss: 0.1548 - val_mean_squared_error: 0.0581
# Epoch 95/200
#  - 98s - loss: 0.0406 - mean_squared_error: 0.0051 - val_loss: 0.1547 - val_mean_squared_error: 0.0569
# Epoch 96/200
#  - 100s - loss: 0.0393 - mean_squared_error: 0.0049 - val_loss: 0.1543 - val_mean_squared_error: 0.0574
# Epoch 97/200
#  - 103s - loss: 0.0388 - mean_squared_error: 0.0048 - val_loss: 0.1544 - val_mean_squared_error: 0.0577
# Epoch 98/200
#  - 103s - loss: 0.0396 - mean_squared_error: 0.0049 - val_loss: 0.1548 - val_mean_squared_error: 0.0577
# Epoch 99/200
#  - 105s - loss: 0.0389 - mean_squared_error: 0.0048 - val_loss: 0.1560 - val_mean_squared_error: 0.0591
# Epoch 100/200
#  - 107s - loss: 0.0381 - mean_squared_error: 0.0047 - val_loss: 0.1552 - val_mean_squared_error: 0.0582
# Epoch 101/200
#  - 107s - loss: 0.0380 - mean_squared_error: 0.0046 - val_loss: 0.1552 - val_mean_squared_error: 0.0584
# Epoch 102/200
#  - 109s - loss: 0.0386 - mean_squared_error: 0.0048 - val_loss: 0.1537 - val_mean_squared_error: 0.0567
# Epoch 103/200
#  - 108s - loss: 0.0379 - mean_squared_error: 0.0046 - val_loss: 0.1543 - val_mean_squared_error: 0.0573
# Epoch 104/200
#  - 108s - loss: 0.0376 - mean_squared_error: 0.0046 - val_loss: 0.1558 - val_mean_squared_error: 0.0583
# Epoch 105/200
#  - 108s - loss: 0.0374 - mean_squared_error: 0.0046 - val_loss: 0.1556 - val_mean_squared_error: 0.0587
# Epoch 106/200
#  - 108s - loss: 0.0380 - mean_squared_error: 0.0046 - val_loss: 0.1571 - val_mean_squared_error: 0.0599
# Epoch 107/200
#  - 108s - loss: 0.0370 - mean_squared_error: 0.0045 - val_loss: 0.1558 - val_mean_squared_error: 0.0588
# Epoch 108/200
#  - 108s - loss: 0.0366 - mean_squared_error: 0.0045 - val_loss: 0.1549 - val_mean_squared_error: 0.0583
# Epoch 109/200
#  - 108s - loss: 0.0356 - mean_squared_error: 0.0043 - val_loss: 0.1551 - val_mean_squared_error: 0.0587
# Epoch 110/200
#  - 108s - loss: 0.0372 - mean_squared_error: 0.0046 - val_loss: 0.1545 - val_mean_squared_error: 0.0577
# Epoch 111/200
#  - 105s - loss: 0.0360 - mean_squared_error: 0.0043 - val_loss: 0.1543 - val_mean_squared_error: 0.0577
# Epoch 112/200
#  - 104s - loss: 0.0363 - mean_squared_error: 0.0045 - val_loss: 0.1550 - val_mean_squared_error: 0.0588
# Epoch 113/200
#  - 107s - loss: 0.0351 - mean_squared_error: 0.0041 - val_loss: 0.1547 - val_mean_squared_error: 0.0578
# Epoch 114/200
#  - 108s - loss: 0.0356 - mean_squared_error: 0.0044 - val_loss: 0.1540 - val_mean_squared_error: 0.0573
# Epoch 115/200
#  - 98s - loss: 0.0351 - mean_squared_error: 0.0041 - val_loss: 0.1547 - val_mean_squared_error: 0.0574
# Epoch 116/200
#  - 100s - loss: 0.0350 - mean_squared_error: 0.0040 - val_loss: 0.1548 - val_mean_squared_error: 0.0581
# Epoch 117/200
#  - 100s - loss: 0.0347 - mean_squared_error: 0.0040 - val_loss: 0.1550 - val_mean_squared_error: 0.0583
# Epoch 118/200
#  - 98s - loss: 0.0343 - mean_squared_error: 0.0040 - val_loss: 0.1548 - val_mean_squared_error: 0.0574
# Epoch 119/200
#  - 97s - loss: 0.0340 - mean_squared_error: 0.0051 - val_loss: 0.1549 - val_mean_squared_error: 0.0582
# Epoch 120/200
#  - 97s - loss: 0.0336 - mean_squared_error: 0.0039 - val_loss: 0.1575 - val_mean_squared_error: 0.0598
# Epoch 121/200
#  - 97s - loss: 0.0343 - mean_squared_error: 0.0039 - val_loss: 0.1573 - val_mean_squared_error: 0.0599
# Epoch 122/200
#  - 97s - loss: 0.0340 - mean_squared_error: 0.0038 - val_loss: 0.1559 - val_mean_squared_error: 0.0588
# Epoch 123/200
#  - 97s - loss: 0.0336 - mean_squared_error: 0.0038 - val_loss: 0.1550 - val_mean_squared_error: 0.0580
# Epoch 124/200
#  - 97s - loss: 0.0346 - mean_squared_error: 0.0040 - val_loss: 0.1553 - val_mean_squared_error: 0.0591
# Epoch 125/200
#  - 97s - loss: 0.0337 - mean_squared_error: 0.0037 - val_loss: 0.1542 - val_mean_squared_error: 0.0582
# Epoch 126/200
#  - 97s - loss: 0.0334 - mean_squared_error: 0.0037 - val_loss: 0.1561 - val_mean_squared_error: 0.0586
# Epoch 127/200
#  - 97s - loss: 0.0333 - mean_squared_error: 0.0037 - val_loss: 0.1538 - val_mean_squared_error: 0.0577
# Epoch 128/200
#  - 97s - loss: 0.0335 - mean_squared_error: 0.0038 - val_loss: 0.1545 - val_mean_squared_error: 0.0575
# Epoch 129/200
#  - 98s - loss: 0.0324 - mean_squared_error: 0.0036 - val_loss: 0.1557 - val_mean_squared_error: 0.0578
# Epoch 130/200
#  - 99s - loss: 0.0322 - mean_squared_error: 0.0035 - val_loss: 0.1554 - val_mean_squared_error: 0.0586
# Epoch 131/200
#  - 105s - loss: 0.0319 - mean_squared_error: 0.0035 - val_loss: 0.1546 - val_mean_squared_error: 0.0572
# Epoch 132/200
#  - 97s - loss: 0.0322 - mean_squared_error: 0.0035 - val_loss: 0.1536 - val_mean_squared_error: 0.0571
# Epoch 133/200
#  - 97s - loss: 0.0335 - mean_squared_error: 0.0038 - val_loss: 0.1542 - val_mean_squared_error: 0.0580
# Epoch 134/200
#  - 97s - loss: 0.0319 - mean_squared_error: 0.0035 - val_loss: 0.1525 - val_mean_squared_error: 0.0569
# Epoch 135/200
#  - 97s - loss: 0.0321 - mean_squared_error: 0.0038 - val_loss: 0.1557 - val_mean_squared_error: 0.0591
# Epoch 136/200
#  - 97s - loss: 0.0320 - mean_squared_error: 0.0035 - val_loss: 0.1532 - val_mean_squared_error: 0.0577
# Epoch 137/200
#  - 97s - loss: 0.0315 - mean_squared_error: 0.0034 - val_loss: 0.1584 - val_mean_squared_error: 0.0609
# Epoch 138/200
#  - 97s - loss: 0.0317 - mean_squared_error: 0.0034 - val_loss: 0.1531 - val_mean_squared_error: 0.0574
# Epoch 139/200
#  - 97s - loss: 0.0311 - mean_squared_error: 0.0034 - val_loss: 0.1539 - val_mean_squared_error: 0.0577
# Epoch 140/200
#  - 97s - loss: 0.0311 - mean_squared_error: 0.0036 - val_loss: 0.1546 - val_mean_squared_error: 0.0581
# Epoch 141/200
#  - 97s - loss: 0.0311 - mean_squared_error: 0.0033 - val_loss: 0.1539 - val_mean_squared_error: 0.0577
# Epoch 142/200
#  - 97s - loss: 0.0308 - mean_squared_error: 0.0033 - val_loss: 0.1542 - val_mean_squared_error: 0.0578
# Epoch 143/200
#  - 97s - loss: 0.0301 - mean_squared_error: 0.0032 - val_loss: 0.1542 - val_mean_squared_error: 0.0572
# Epoch 144/200
#  - 97s - loss: 0.0306 - mean_squared_error: 0.0033 - val_loss: 0.1545 - val_mean_squared_error: 0.0582
# Epoch 145/200
#  - 97s - loss: 0.0303 - mean_squared_error: 0.0032 - val_loss: 0.1529 - val_mean_squared_error: 0.0569
# Epoch 146/200
#  - 97s - loss: 0.0302 - mean_squared_error: 0.0033 - val_loss: 0.1536 - val_mean_squared_error: 0.0572
# Epoch 147/200
#  - 97s - loss: 0.0296 - mean_squared_error: 0.0031 - val_loss: 0.1534 - val_mean_squared_error: 0.0575
# Epoch 148/200
#  - 97s - loss: 0.0304 - mean_squared_error: 0.0033 - val_loss: 0.1538 - val_mean_squared_error: 0.0578
# Epoch 149/200
#  - 97s - loss: 0.0295 - mean_squared_error: 0.0031 - val_loss: 0.1548 - val_mean_squared_error: 0.0583
# Epoch 150/200
#  - 97s - loss: 0.0293 - mean_squared_error: 0.0031 - val_loss: 0.1546 - val_mean_squared_error: 0.0585
# Epoch 151/200
#  - 97s - loss: 0.0298 - mean_squared_error: 0.0035 - val_loss: 0.1532 - val_mean_squared_error: 0.0574
# Epoch 152/200
#  - 97s - loss: 0.0296 - mean_squared_error: 0.0033 - val_loss: 0.1532 - val_mean_squared_error: 0.0573
# Epoch 153/200
#  - 97s - loss: 0.0297 - mean_squared_error: 0.0032 - val_loss: 0.1536 - val_mean_squared_error: 0.0575
# Epoch 154/200
#  - 97s - loss: 0.0299 - mean_squared_error: 0.0032 - val_loss: 0.1540 - val_mean_squared_error: 0.0576
# Epoch 155/200
#  - 97s - loss: 0.0286 - mean_squared_error: 0.0031 - val_loss: 0.1539 - val_mean_squared_error: 0.0580
# Epoch 156/200
#  - 97s - loss: 0.0293 - mean_squared_error: 0.0032 - val_loss: 0.1556 - val_mean_squared_error: 0.0587
# Epoch 157/200
#  - 97s - loss: 0.0294 - mean_squared_error: 0.0031 - val_loss: 0.1530 - val_mean_squared_error: 0.0574
# Epoch 158/200
#  - 97s - loss: 0.0291 - mean_squared_error: 0.0030 - val_loss: 0.1538 - val_mean_squared_error: 0.0578
# Epoch 159/200
#  - 97s - loss: 0.0295 - mean_squared_error: 0.0032 - val_loss: 0.1534 - val_mean_squared_error: 0.0571
# Epoch 160/200
#  - 97s - loss: 0.0289 - mean_squared_error: 0.0030 - val_loss: 0.1534 - val_mean_squared_error: 0.0569
# Epoch 161/200
#  - 97s - loss: 0.0287 - mean_squared_error: 0.0030 - val_loss: 0.1537 - val_mean_squared_error: 0.0573
# Epoch 162/200
#  - 97s - loss: 0.0297 - mean_squared_error: 0.0034 - val_loss: 0.1607 - val_mean_squared_error: 0.0611
# Epoch 163/200
#  - 97s - loss: 0.0295 - mean_squared_error: 0.0032 - val_loss: 0.1531 - val_mean_squared_error: 0.0576
# Epoch 164/200
#  - 97s - loss: 0.0273 - mean_squared_error: 0.0028 - val_loss: 0.1534 - val_mean_squared_error: 0.0579
# Epoch 165/200
#  - 97s - loss: 0.0278 - mean_squared_error: 0.0031 - val_loss: 0.1525 - val_mean_squared_error: 0.0567
# Epoch 166/200
#  - 97s - loss: 0.0287 - mean_squared_error: 0.0034 - val_loss: 0.1530 - val_mean_squared_error: 0.0569
# Epoch 167/200
#  - 97s - loss: 0.0285 - mean_squared_error: 0.0031 - val_loss: 0.1547 - val_mean_squared_error: 0.0580
# Epoch 168/200
#  - 97s - loss: 0.0286 - mean_squared_error: 0.0038 - val_loss: 0.1538 - val_mean_squared_error: 0.0570
# Epoch 169/200
#  - 97s - loss: 0.0274 - mean_squared_error: 0.0029 - val_loss: 0.1560 - val_mean_squared_error: 0.0588
# Epoch 170/200
#  - 97s - loss: 0.0283 - mean_squared_error: 0.0029 - val_loss: 0.1532 - val_mean_squared_error: 0.0570
# Epoch 171/200
#  - 97s - loss: 0.0273 - mean_squared_error: 0.0028 - val_loss: 0.1531 - val_mean_squared_error: 0.0571
# Epoch 172/200
#  - 97s - loss: 0.0272 - mean_squared_error: 0.0028 - val_loss: 0.1535 - val_mean_squared_error: 0.0569
# Epoch 173/200
#  - 97s - loss: 0.0273 - mean_squared_error: 0.0028 - val_loss: 0.1548 - val_mean_squared_error: 0.0582
# Epoch 174/200
#  - 97s - loss: 0.0273 - mean_squared_error: 0.0029 - val_loss: 0.1539 - val_mean_squared_error: 0.0576
# Epoch 175/200
#  - 97s - loss: 0.0277 - mean_squared_error: 0.0028 - val_loss: 0.1538 - val_mean_squared_error: 0.0579
# Epoch 176/200
#  - 97s - loss: 0.0273 - mean_squared_error: 0.0027 - val_loss: 0.1528 - val_mean_squared_error: 0.0565
# Epoch 177/200
#  - 97s - loss: 0.0268 - mean_squared_error: 0.0027 - val_loss: 0.1528 - val_mean_squared_error: 0.0568
# Epoch 178/200
#  - 97s - loss: 0.0271 - mean_squared_error: 0.0027 - val_loss: 0.1545 - val_mean_squared_error: 0.0571
# Epoch 179/200
#  - 97s - loss: 0.0269 - mean_squared_error: 0.0027 - val_loss: 0.1537 - val_mean_squared_error: 0.0572
# Epoch 180/200
#  - 97s - loss: 0.0269 - mean_squared_error: 0.0028 - val_loss: 0.1537 - val_mean_squared_error: 0.0575
# Epoch 181/200
#  - 97s - loss: 0.0260 - mean_squared_error: 0.0025 - val_loss: 0.1527 - val_mean_squared_error: 0.0572
# Epoch 182/200
#  - 97s - loss: 0.0269 - mean_squared_error: 0.0026 - val_loss: 0.1537 - val_mean_squared_error: 0.0575
# Epoch 183/200
#  - 97s - loss: 0.0263 - mean_squared_error: 0.0025 - val_loss: 0.1531 - val_mean_squared_error: 0.0575
# Epoch 184/200
#  - 97s - loss: 0.0260 - mean_squared_error: 0.0026 - val_loss: 0.1544 - val_mean_squared_error: 0.0586
# Epoch 185/200
#  - 97s - loss: 0.0269 - mean_squared_error: 0.0027 - val_loss: 0.1553 - val_mean_squared_error: 0.0589
# Epoch 186/200
#  - 97s - loss: 0.0262 - mean_squared_error: 0.0025 - val_loss: 0.1528 - val_mean_squared_error: 0.0567
# Epoch 187/200
#  - 97s - loss: 0.0263 - mean_squared_error: 0.0025 - val_loss: 0.1540 - val_mean_squared_error: 0.0582
# Epoch 188/200
#  - 97s - loss: 0.0267 - mean_squared_error: 0.0032 - val_loss: 0.1532 - val_mean_squared_error: 0.0576
# Epoch 189/200
#  - 97s - loss: 0.0269 - mean_squared_error: 0.0027 - val_loss: 0.1531 - val_mean_squared_error: 0.0575
# Epoch 190/200
#  - 97s - loss: 0.0260 - mean_squared_error: 0.0025 - val_loss: 0.1527 - val_mean_squared_error: 0.0570
# Epoch 191/200
#  - 97s - loss: 0.0255 - mean_squared_error: 0.0024 - val_loss: 0.1537 - val_mean_squared_error: 0.0572
# Epoch 192/200
#  - 97s - loss: 0.0250 - mean_squared_error: 0.0024 - val_loss: 0.1532 - val_mean_squared_error: 0.0569
# Epoch 193/200
#  - 97s - loss: 0.0246 - mean_squared_error: 0.0023 - val_loss: 0.1546 - val_mean_squared_error: 0.0578
# Epoch 194/200
#  - 97s - loss: 0.0254 - mean_squared_error: 0.0025 - val_loss: 0.1536 - val_mean_squared_error: 0.0576
# Epoch 195/200
#  - 97s - loss: 0.0248 - mean_squared_error: 0.0023 - val_loss: 0.1528 - val_mean_squared_error: 0.0567
# Epoch 196/200
#  - 97s - loss: 0.0254 - mean_squared_error: 0.0024 - val_loss: 0.1522 - val_mean_squared_error: 0.0568
# Epoch 197/200
#  - 97s - loss: 0.0256 - mean_squared_error: 0.0025 - val_loss: 0.1541 - val_mean_squared_error: 0.0583
# Epoch 198/200
#  - 97s - loss: 0.0249 - mean_squared_error: 0.0023 - val_loss: 0.1552 - val_mean_squared_error: 0.0592
# Epoch 199/200
#  - 97s - loss: 0.0253 - mean_squared_error: 0.0023 - val_loss: 0.1536 - val_mean_squared_error: 0.0578
# Epoch 200/200
#  - 97s - loss: 0.0251 - mean_squared_error: 0.0023 - val_loss: 0.1544 - val_mean_squared_error: 0.0584
# (Fold 4) score, mse, mae, mape: 5159.78870, 0.05302, 0.14703, 0.01104.

# %%
print('Total computing time:', t1-t0)
# Out:
# Total computing time: 100041.94307160378

# %%
print('Kfold cv score (mean, stdev):', np.mean(scores), np.std(scores)) # 5868.87314
# Out:
# Kfold cv score (mean, stdev): 5171.436449277401 27.0600158893791

# %%
predicts_test.head()
# Out:
#         building_id   target_0   target_1   target_2   target_3   target_4
# 0  X5gsdTWGS3W7JJQB  15.370914  15.343225  15.439053  15.183949  15.052156
# 1  BTshNOJyKHnT2YIT  13.171639  12.987412  13.108602  13.129660  13.129212
# 2  dhdymr0lV8N5kZOT  13.746473  13.792964  13.784403  13.736965  13.718224
# 3  VEwyGGMcD56w5BOc  14.907567  14.673841  14.765310  14.915156  14.807371
# 4  wmUeMoJZfsqaSX9b  12.128737  12.056951  12.077527  12.016287  12.189663

# %%
pd.concat(predicts_val, axis=0).to_csv('output/'+model_name+'-cv.csv', index=False)

predicts_test['target_mean'] = \
    predicts_test[['target_'+str(i) for i in range(len(id_cv))]].mean(axis=1)
predicts_test['total_price'] = post_processing(predicts_test['target_mean'].values, df_test)
predicts_test[['building_id', 'total_price']].to_csv('output/'+model_name+'-test-kfold.csv', index=False)

# %%
print('Best iterations:', best_iterations)
print('Mean best iterations:', int(np.mean(best_iterations)))
# Out:
# Best iterations: [198, 140, 171, 193, 196]
# Mean best iterations: 179

# %% [markdown]
# #### Hist

# %%
plot_keras_hist(hists)

# %%
plot_keras_hist(hists, ylim=(min(hists[0].history['val_loss']), 
                             min(hists[0].history['val_loss'])+0.01), metrics_plot=['val_loss'])

# %% [markdown]
# ### One-fold prediction

# %%
params['epochs'] = int(np.mean(best_iterations)*1.15)

# %%
params
# Out:
# {'batch_size': 64,
#  'epochs': 206,
#  'learning_rate': 0.001,
#  'n_neurons': (1024, 1024, 1024, 1024, 1024, 512, 512, 512, 512, 512),
#  'optimizer': keras.optimizers.Adam}

# %%
df_train = train.copy()
df_test = test.copy()

# Feature eng
feat_eng = FeatureEngineering(cols_num=cols_num, 
                              cols_cat=cols_cat, 
                              cols_bin=cols_bin, 
                              col_target=col_target, 
                              fillna_values=fillna_values, 
                              cols_right_skew=cols_right_skew,
                              is_embedding=is_embedding, 
                              is_tar_encoded=is_tar_encoded,
                              rare_village_threshold=rare_village_threshold, 
                              rare_town_threshold=rare_town_threshold,)
df_train = feat_eng.fit_transform(df_train, df_test)
df_test = feat_eng.transform(df_test)

# Construct X y matrices
if is_embedding:
    X_train = build_features_matrices(df_train, cols_num=cols_num+cols_tar_encoded, cols_cat=cols_cat, cols_bin=cols_bin)
    X_test = build_features_matrices(df_test, cols_num=cols_num+cols_tar_encoded, cols_cat=cols_cat, cols_bin=cols_bin)
else:
    X_train = build_features_matrices(df_train, cols_num=cols_num+cols_tar_encoded, cols_cat=[], cols_bin=cols_bin)
    X_test = build_features_matrices(df_test, cols_num=cols_num+cols_tar_encoded, cols_cat=[], cols_bin=cols_bin)
y_train = df_train[col_target+'_scaled']

# Compute network size
n_cols_num_bin = len(cols_num+cols_bin+cols_tar_encoded)
if is_embedding:
    cat_n_classes = {c: feat_eng.cat_astyper.cat_n_classes[c] for c in cols_cat}
    cat_embed_sizes = {c: int(2*np.log(cat_n_classes[c]+1)+1) for c in cat_n_classes}
else:
    cat_n_classes = {}
    cat_embed_sizes = {}
print('Numerical input dims:', n_cols_num_bin)
print('Embeding  input dims:', cat_n_classes)
print('Embeding output dims:', cat_embed_sizes)
print('Total embedding output dims:', np.sum(list(cat_embed_sizes.values())))

# Build model
model = build_model(n_cols_num_bin, cat_n_classes, cat_embed_sizes, 
                    n_neurons=params['n_neurons'], learning_rate=params['learning_rate'], 
                    optimizer=params['optimizer'])

# Train model
hist = model.fit(x=X_train, y=y_train, batch_size=params['batch_size'], epochs=params['epochs'], 
                 verbose=2)

# Predict on test set
df_test[col_target+'_scaled_pred'] = model.predict(X_test, batch_size=1024)
feat_eng.target_inverse_transform(df_test, col_target+'_scaled_pred', col_target+'_pred')
df_test['total_price_pred'] = post_processing(df_test[col_target+'_pred'], df_test)

df_test_pred = pd.DataFrame({'building_id': df_test['building_id'], 
                             'total_price': df_test['total_price_pred']})
display(df_test_pred.head(20))
# Out:
# Numerical input dims: 205
# Embeding  input dims: {'building_material': 10, 'city': 12, 'building_type': 6, 'building_use': 11, 'parking_way': 4, 'town': 209, 'village': 2667, 'encoded_latlon': 7}
# Embeding output dims: {'building_material': 5, 'city': 6, 'building_type': 4, 'building_use': 5, 'parking_way': 4, 'town': 11, 'village': 16, 'encoded_latlon': 5}
# Total embedding output dims: 56
# Epoch 1/206
#  - 120s - loss: 0.2651 - mean_squared_error: 0.1342
# Epoch 2/206
#  - 118s - loss: 0.2052 - mean_squared_error: 0.0806
# Epoch 3/206
#  - 118s - loss: 0.1876 - mean_squared_error: 0.0691
# Epoch 4/206
#  - 118s - loss: 0.1766 - mean_squared_error: 0.0627
# Epoch 5/206
#  - 121s - loss: 0.1686 - mean_squared_error: 0.0577
# Epoch 6/206
#  - 121s - loss: 0.1620 - mean_squared_error: 0.0536
# Epoch 7/206
#  - 121s - loss: 0.1553 - mean_squared_error: 0.0500
# Epoch 8/206
#  - 122s - loss: 0.1485 - mean_squared_error: 0.0468
# Epoch 9/206
#  - 124s - loss: 0.1438 - mean_squared_error: 0.0443
# Epoch 10/206
#  - 126s - loss: 0.1388 - mean_squared_error: 0.0416
# Epoch 11/206
#  - 126s - loss: 0.1350 - mean_squared_error: 0.0399
# Epoch 12/206
#  - 126s - loss: 0.1311 - mean_squared_error: 0.0378
# Epoch 13/206
#  - 126s - loss: 0.1266 - mean_squared_error: 0.0360
# Epoch 14/206
#  - 126s - loss: 0.1239 - mean_squared_error: 0.0345
# Epoch 15/206
#  - 126s - loss: 0.1195 - mean_squared_error: 0.0327
# Epoch 16/206
#  - 127s - loss: 0.1161 - mean_squared_error: 0.0308
# Epoch 17/206
#  - 130s - loss: 0.1129 - mean_squared_error: 0.0295
# Epoch 18/206
#  - 129s - loss: 0.1100 - mean_squared_error: 0.0284
# Epoch 19/206
#  - 130s - loss: 0.1077 - mean_squared_error: 0.0272
# Epoch 20/206
#  - 130s - loss: 0.1045 - mean_squared_error: 0.0261
# Epoch 21/206
#  - 131s - loss: 0.1019 - mean_squared_error: 0.0248
# Epoch 22/206
#  - 131s - loss: 0.1009 - mean_squared_error: 0.0245
# Epoch 23/206
#  - 132s - loss: 0.0989 - mean_squared_error: 0.0239
# Epoch 24/206
#  - 132s - loss: 0.0958 - mean_squared_error: 0.0226
# Epoch 25/206
#  - 134s - loss: 0.0939 - mean_squared_error: 0.0217
# Epoch 26/206
#  - 130s - loss: 0.0914 - mean_squared_error: 0.0207
# Epoch 27/206
#  - 118s - loss: 0.0903 - mean_squared_error: 0.0202
# Epoch 28/206
#  - 118s - loss: 0.0897 - mean_squared_error: 0.0209
# Epoch 29/206
#  - 118s - loss: 0.0865 - mean_squared_error: 0.0188
# Epoch 30/206
#  - 119s - loss: 0.0847 - mean_squared_error: 0.0182
# Epoch 31/206
#  - 118s - loss: 0.0827 - mean_squared_error: 0.0176
# Epoch 32/206
#  - 119s - loss: 0.0819 - mean_squared_error: 0.0171
# Epoch 33/206
#  - 119s - loss: 0.0798 - mean_squared_error: 0.0165
# Epoch 34/206
#  - 119s - loss: 0.0782 - mean_squared_error: 0.0160
# Epoch 35/206
#  - 119s - loss: 0.0773 - mean_squared_error: 0.0159
# Epoch 36/206
#  - 120s - loss: 0.0759 - mean_squared_error: 0.0150
# Epoch 37/206
#  - 120s - loss: 0.0744 - mean_squared_error: 0.0146
# Epoch 38/206
#  - 123s - loss: 0.0730 - mean_squared_error: 0.0141
# Epoch 39/206
#  - 125s - loss: 0.0715 - mean_squared_error: 0.0137
# Epoch 40/206
#  - 128s - loss: 0.0710 - mean_squared_error: 0.0140
# Epoch 41/206
#  - 129s - loss: 0.0703 - mean_squared_error: 0.0131
# Epoch 42/206
#  - 130s - loss: 0.0685 - mean_squared_error: 0.0127
# Epoch 43/206
#  - 129s - loss: 0.0678 - mean_squared_error: 0.0125
# Epoch 44/206
#  - 129s - loss: 0.0667 - mean_squared_error: 0.0122
# Epoch 45/206
#  - 129s - loss: 0.0659 - mean_squared_error: 0.0120
# Epoch 46/206
#  - 122s - loss: 0.0647 - mean_squared_error: 0.0117
# Epoch 47/206
#  - 120s - loss: 0.0637 - mean_squared_error: 0.0116
# Epoch 48/206
#  - 123s - loss: 0.0632 - mean_squared_error: 0.0111
# Epoch 49/206
#  - 123s - loss: 0.0623 - mean_squared_error: 0.0109
# Epoch 50/206
#  - 122s - loss: 0.0617 - mean_squared_error: 0.0109
# Epoch 51/206
#  - 118s - loss: 0.0611 - mean_squared_error: 0.0105
# Epoch 52/206
#  - 118s - loss: 0.0595 - mean_squared_error: 0.0101
# Epoch 53/206
#  - 118s - loss: 0.0592 - mean_squared_error: 0.0123
# Epoch 54/206
#  - 118s - loss: 0.0585 - mean_squared_error: 0.0098
# Epoch 55/206
#  - 118s - loss: 0.0568 - mean_squared_error: 0.0093
# Epoch 56/206
#  - 118s - loss: 0.0556 - mean_squared_error: 0.0091
# Epoch 57/206
#  - 118s - loss: 0.0558 - mean_squared_error: 0.0090
# Epoch 58/206
#  - 118s - loss: 0.0552 - mean_squared_error: 0.0089
# Epoch 59/206
#  - 118s - loss: 0.0546 - mean_squared_error: 0.0087
# Epoch 60/206
#  - 118s - loss: 0.0538 - mean_squared_error: 0.0086
# Epoch 61/206
#  - 118s - loss: 0.0534 - mean_squared_error: 0.0084
# Epoch 62/206
#  - 119s - loss: 0.0526 - mean_squared_error: 0.0082
# Epoch 63/206
#  - 119s - loss: 0.0526 - mean_squared_error: 0.0081
# Epoch 64/206
#  - 126s - loss: 0.0519 - mean_squared_error: 0.0080
# Epoch 65/206
#  - 119s - loss: 0.0512 - mean_squared_error: 0.0079
# Epoch 66/206
#  - 120s - loss: 0.0505 - mean_squared_error: 0.0077
# Epoch 67/206
#  - 122s - loss: 0.0502 - mean_squared_error: 0.0076
# Epoch 68/206
#  - 126s - loss: 0.0497 - mean_squared_error: 0.0075
# Epoch 69/206
#  - 129s - loss: 0.0499 - mean_squared_error: 0.0076
# Epoch 70/206
#  - 131s - loss: 0.0478 - mean_squared_error: 0.0071
# Epoch 71/206
#  - 132s - loss: 0.0474 - mean_squared_error: 0.0071
# Epoch 72/206
#  - 132s - loss: 0.0478 - mean_squared_error: 0.0070
# Epoch 73/206
#  - 132s - loss: 0.0476 - mean_squared_error: 0.0070
# Epoch 74/206
#  - 131s - loss: 0.0458 - mean_squared_error: 0.0066
# Epoch 75/206
#  - 131s - loss: 0.0455 - mean_squared_error: 0.0064
# Epoch 76/206
#  - 131s - loss: 0.0457 - mean_squared_error: 0.0066
# Epoch 77/206
#  - 131s - loss: 0.0453 - mean_squared_error: 0.0065
# Epoch 78/206
#  - 132s - loss: 0.0453 - mean_squared_error: 0.0090
# Epoch 79/206
#  - 131s - loss: 0.0450 - mean_squared_error: 0.0064
# Epoch 80/206
#  - 131s - loss: 0.0439 - mean_squared_error: 0.0062
# Epoch 81/206
#  - 123s - loss: 0.0439 - mean_squared_error: 0.0061
# Epoch 82/206
#  - 118s - loss: 0.0438 - mean_squared_error: 0.0060
# Epoch 83/206
#  - 118s - loss: 0.0433 - mean_squared_error: 0.0060
# Epoch 84/206
#  - 118s - loss: 0.0426 - mean_squared_error: 0.0058
# Epoch 85/206
#  - 119s - loss: 0.0427 - mean_squared_error: 0.0059
# Epoch 86/206
#  - 118s - loss: 0.0415 - mean_squared_error: 0.0056
# Epoch 87/206
#  - 118s - loss: 0.0419 - mean_squared_error: 0.0057
# Epoch 88/206
#  - 118s - loss: 0.0411 - mean_squared_error: 0.0056
# Epoch 89/206
#  - 118s - loss: 0.0412 - mean_squared_error: 0.0059
# Epoch 90/206
#  - 118s - loss: 0.0409 - mean_squared_error: 0.0055
# Epoch 91/206
#  - 118s - loss: 0.0410 - mean_squared_error: 0.0055
# Epoch 92/206
#  - 118s - loss: 0.0405 - mean_squared_error: 0.0054
# Epoch 93/206
#  - 119s - loss: 0.0400 - mean_squared_error: 0.0054
# Epoch 94/206
#  - 119s - loss: 0.0402 - mean_squared_error: 0.0053
# Epoch 95/206
#  - 119s - loss: 0.0399 - mean_squared_error: 0.0053
# Epoch 96/206
#  - 119s - loss: 0.0389 - mean_squared_error: 0.0051
# Epoch 97/206
#  - 120s - loss: 0.0390 - mean_squared_error: 0.0051
# Epoch 98/206
#  - 121s - loss: 0.0388 - mean_squared_error: 0.0050
# Epoch 99/206
#  - 123s - loss: 0.0385 - mean_squared_error: 0.0053
# Epoch 100/206
#  - 124s - loss: 0.0385 - mean_squared_error: 0.0052
# Epoch 101/206
#  - 126s - loss: 0.0379 - mean_squared_error: 0.0051
# Epoch 102/206
#  - 127s - loss: 0.0375 - mean_squared_error: 0.0052
# Epoch 103/206
#  - 125s - loss: 0.0368 - mean_squared_error: 0.0047
# Epoch 104/206
#  - 123s - loss: 0.0371 - mean_squared_error: 0.0047
# Epoch 105/206
#  - 123s - loss: 0.0371 - mean_squared_error: 0.0048
# Epoch 106/206
#  - 124s - loss: 0.0366 - mean_squared_error: 0.0046
# Epoch 107/206
#  - 126s - loss: 0.0367 - mean_squared_error: 0.0047
# Epoch 108/206
#  - 128s - loss: 0.0364 - mean_squared_error: 0.0046
# Epoch 109/206
#  - 129s - loss: 0.0362 - mean_squared_error: 0.0045
# Epoch 110/206
#  - 129s - loss: 0.0361 - mean_squared_error: 0.0047
# Epoch 111/206
#  - 118s - loss: 0.0351 - mean_squared_error: 0.0044
# Epoch 112/206
#  - 118s - loss: 0.0354 - mean_squared_error: 0.0044
# Epoch 113/206
#  - 118s - loss: 0.0362 - mean_squared_error: 0.0045
# Epoch 114/206
#  - 119s - loss: 0.0361 - mean_squared_error: 0.0045
# Epoch 115/206
#  - 119s - loss: 0.0354 - mean_squared_error: 0.0044
# Epoch 116/206
#  - 122s - loss: 0.0352 - mean_squared_error: 0.0043
# Epoch 117/206
#  - 126s - loss: 0.0348 - mean_squared_error: 0.0043
# Epoch 118/206
#  - 127s - loss: 0.0346 - mean_squared_error: 0.0042
# Epoch 119/206
#  - 124s - loss: 0.0349 - mean_squared_error: 0.0043
# Epoch 120/206
#  - 121s - loss: 0.0344 - mean_squared_error: 0.0043
# Epoch 121/206
#  - 119s - loss: 0.0340 - mean_squared_error: 0.0042
# Epoch 122/206
#  - 119s - loss: 0.0343 - mean_squared_error: 0.0042
# Epoch 123/206
#  - 125s - loss: 0.0350 - mean_squared_error: 0.0042
# Epoch 124/206
#  - 120s - loss: 0.0343 - mean_squared_error: 0.0041
# Epoch 125/206
#  - 119s - loss: 0.0336 - mean_squared_error: 0.0041
# Epoch 126/206
#  - 119s - loss: 0.0329 - mean_squared_error: 0.0040
# Epoch 127/206
#  - 118s - loss: 0.0333 - mean_squared_error: 0.0040
# Epoch 128/206
#  - 118s - loss: 0.0335 - mean_squared_error: 0.0040
# Epoch 129/206
#  - 118s - loss: 0.0323 - mean_squared_error: 0.0039
# Epoch 130/206
#  - 118s - loss: 0.0326 - mean_squared_error: 0.0039
# Epoch 131/206
#  - 118s - loss: 0.0333 - mean_squared_error: 0.0040
# Epoch 132/206
#  - 118s - loss: 0.0332 - mean_squared_error: 0.0040
# Epoch 133/206
#  - 118s - loss: 0.0325 - mean_squared_error: 0.0039
# Epoch 134/206
#  - 118s - loss: 0.0324 - mean_squared_error: 0.0039
# Epoch 135/206
#  - 118s - loss: 0.0327 - mean_squared_error: 0.0039
# Epoch 136/206
#  - 118s - loss: 0.0316 - mean_squared_error: 0.0037
# Epoch 137/206
#  - 118s - loss: 0.0319 - mean_squared_error: 0.0037
# Epoch 138/206
#  - 118s - loss: 0.0314 - mean_squared_error: 0.0037
# Epoch 139/206
#  - 118s - loss: 0.0322 - mean_squared_error: 0.0038
# Epoch 140/206
#  - 118s - loss: 0.0321 - mean_squared_error: 0.0037
# Epoch 141/206
#  - 118s - loss: 0.0312 - mean_squared_error: 0.0037
# Epoch 142/206
#  - 118s - loss: 0.0308 - mean_squared_error: 0.0036
# Epoch 143/206
#  - 119s - loss: 0.0313 - mean_squared_error: 0.0037
# Epoch 144/206
#  - 118s - loss: 0.0312 - mean_squared_error: 0.0036
# Epoch 145/206
#  - 118s - loss: 0.0306 - mean_squared_error: 0.0036
# Epoch 146/206
#  - 118s - loss: 0.0310 - mean_squared_error: 0.0035
# Epoch 147/206
#  - 119s - loss: 0.0305 - mean_squared_error: 0.0035
# Epoch 148/206
#  - 121s - loss: 0.0299 - mean_squared_error: 0.0034
# Epoch 149/206
#  - 119s - loss: 0.0306 - mean_squared_error: 0.0035
# Epoch 150/206
#  - 119s - loss: 0.0311 - mean_squared_error: 0.0035
# Epoch 151/206
#  - 118s - loss: 0.0310 - mean_squared_error: 0.0035
# Epoch 152/206
#  - 119s - loss: 0.0308 - mean_squared_error: 0.0035
# Epoch 153/206
#  - 118s - loss: 0.0302 - mean_squared_error: 0.0034
# Epoch 154/206
#  - 118s - loss: 0.0310 - mean_squared_error: 0.0035
# Epoch 155/206
#  - 118s - loss: 0.0305 - mean_squared_error: 0.0034
# Epoch 156/206
#  - 118s - loss: 0.0334 - mean_squared_error: 0.0038
# Epoch 157/206
#  - 118s - loss: 0.0333 - mean_squared_error: 0.0038
# Epoch 158/206
#  - 118s - loss: 0.0304 - mean_squared_error: 0.0035
# Epoch 159/206
#  - 118s - loss: 0.0309 - mean_squared_error: 0.0035
# Epoch 160/206
#  - 118s - loss: 0.0296 - mean_squared_error: 0.0034
# Epoch 161/206
#  - 118s - loss: 0.0310 - mean_squared_error: 0.0035
# Epoch 162/206
#  - 118s - loss: 0.0313 - mean_squared_error: 0.0035
# Epoch 163/206
#  - 118s - loss: 0.0306 - mean_squared_error: 0.0035
# Epoch 164/206
#  - 118s - loss: 0.0298 - mean_squared_error: 0.0033
# Epoch 165/206
#  - 118s - loss: 0.0294 - mean_squared_error: 0.0032
# Epoch 166/206
#  - 118s - loss: 0.0317 - mean_squared_error: 0.0174
# Epoch 167/206
#  - 118s - loss: 0.0301 - mean_squared_error: 0.0033
# Epoch 168/206
#  - 118s - loss: 0.0297 - mean_squared_error: 0.0033
# Epoch 169/206
#  - 118s - loss: 0.0303 - mean_squared_error: 0.0034
# Epoch 170/206
#  - 118s - loss: 0.0293 - mean_squared_error: 0.0032
# Epoch 171/206
#  - 118s - loss: 0.0299 - mean_squared_error: 0.0033
# Epoch 172/206
#  - 118s - loss: 0.0289 - mean_squared_error: 0.0031
# Epoch 173/206
#  - 118s - loss: 0.0291 - mean_squared_error: 0.0032
# Epoch 174/206
#  - 118s - loss: 0.0291 - mean_squared_error: 0.0032
# Epoch 175/206
#  - 118s - loss: 0.0285 - mean_squared_error: 0.0031
# Epoch 176/206
#  - 118s - loss: 0.0290 - mean_squared_error: 0.0035
# Epoch 177/206
#  - 118s - loss: 0.0279 - mean_squared_error: 0.0030
# Epoch 178/206
#  - 118s - loss: 0.0272 - mean_squared_error: 0.0029
# Epoch 179/206
#  - 118s - loss: 0.0287 - mean_squared_error: 0.0031
# Epoch 180/206
#  - 118s - loss: 0.0273 - mean_squared_error: 0.0029
# Epoch 181/206
#  - 118s - loss: 0.0283 - mean_squared_error: 0.0030
# Epoch 182/206
#  - 118s - loss: 0.0290 - mean_squared_error: 0.0031
# Epoch 183/206
#  - 118s - loss: 0.0286 - mean_squared_error: 0.0030
# Epoch 184/206
#  - 118s - loss: 0.0289 - mean_squared_error: 0.0031
# Epoch 185/206
#  - 119s - loss: 0.0315 - mean_squared_error: 0.0036
# Epoch 186/206
#  - 118s - loss: 0.0281 - mean_squared_error: 0.0030
# Epoch 187/206
#  - 118s - loss: 0.0277 - mean_squared_error: 0.0029
# Epoch 188/206
#  - 118s - loss: 0.0288 - mean_squared_error: 0.0030
# Epoch 189/206
#  - 118s - loss: 0.0276 - mean_squared_error: 0.0029
# Epoch 190/206
#  - 118s - loss: 0.0276 - mean_squared_error: 0.0029
# Epoch 191/206
#  - 118s - loss: 0.0274 - mean_squared_error: 0.0029
# Epoch 192/206
#  - 118s - loss: 0.0278 - mean_squared_error: 0.0029
# Epoch 193/206
#  - 118s - loss: 0.0286 - mean_squared_error: 0.0030
# Epoch 194/206
#  - 118s - loss: 0.0277 - mean_squared_error: 0.0029
# Epoch 195/206
#  - 118s - loss: 0.0280 - mean_squared_error: 0.0029
# Epoch 196/206
#  - 118s - loss: 0.0277 - mean_squared_error: 0.0029
# Epoch 197/206
#  - 118s - loss: 0.0278 - mean_squared_error: 0.0029
# Epoch 198/206
#  - 118s - loss: 0.0276 - mean_squared_error: 0.0032
# Epoch 199/206
#  - 118s - loss: 0.0266 - mean_squared_error: 0.0027
# Epoch 200/206
#  - 118s - loss: 0.0295 - mean_squared_error: 0.0031
# Epoch 201/206
#  - 118s - loss: 0.0295 - mean_squared_error: 0.0031
# Epoch 202/206
#  - 118s - loss: 0.0284 - mean_squared_error: 0.0029
# Epoch 203/206
#  - 118s - loss: 0.0283 - mean_squared_error: 0.0029
# Epoch 204/206
#  - 118s - loss: 0.0274 - mean_squared_error: 0.0028
# Epoch 205/206
#  - 118s - loss: 0.0276 - mean_squared_error: 0.0028
# Epoch 206/206
#  - 118s - loss: 0.0289 - mean_squared_error: 0.0030
#          building_id   total_price
# 0   X5gsdTWGS3W7JJQB  1.568054e+07
# 1   BTshNOJyKHnT2YIT  4.024808e+06
# 2   dhdymr0lV8N5kZOT  1.232749e+07
# 3   VEwyGGMcD56w5BOc  6.866298e+06
# 4   wmUeMoJZfsqaSX9b  1.040580e+06
# 5   EtBjGAHmHCe9t7TZ  2.001168e+06
# 6   hPNH34vmaZtvBtqc  1.265585e+07
# 7   wXjeI38bYDMJJwZC  6.341510e+06
# 8   fxZSGX6aPAFKU8W4  1.719071e+06
# 9   ewr0Fx6ign87OwaV  4.463393e+06
# 10  gHKurnEP4AowzsLg  8.769355e+05
# 11  PmLfTgY2FElLrTl0  5.692780e+06
# 12  eM2NppIOwzW0o8iy  9.428514e+06
# 13  dxxwNun97NH4WTrZ  3.406761e+06
# 14  jykBfhh3vdeFUi3H  3.897127e+06
# 15  NlXbvdFfmJZf3L18  2.130702e+07
# 16  D7jaFWHCzSqLBwdt  9.681275e+05
# 17  L10dBBdqGmemweSl  6.074067e+06
# 18  OgB0AdiPKlElakKN  1.147027e+06
# 19  StiWNN1GQrpPBOYt  2.503229e+06

# %%
df_test_pred.to_csv('output/'+model_name+'-test-one.csv', index=False)

# %% [markdown]
# ### Result

# %% [markdown]
# Round 2:
#
# (('epochs', 200), ('n_neurons', (1024, 1024, 1024, 1024, 1024, 512, 512, 512, 512, 512)), ('optimizer', <class 'keras.optimizers.Adam'>), ('learning_rate', 0.001), ('batch_size', 64)) 5010.503401721518 0.052174035 0.15091588 0.011324741 [4954.842085674405, 5003.840687379241, 5072.827432110906] [0.051094234, 0.052469276, 0.0529586] [0.15171897, 0.1507649, 0.15026379] [0.011382295, 0.011312374, 0.011279553]

# %% [markdown]
# ### Hist

# %%
plot_keras_hist(hist)

# %%
plot_keras_hist(hist, ylim=(min(hist.history['loss'])-0.001, 
                            min(hist.history['loss'])+0.04), metrics_plot=['loss'])
