# %% [markdown]
# ### Import packages

# %%
import itertools
import numpy as np
import pandas as pd
import lightgbm as lgb
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split

from utilities import cal_score, convert_types
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/lightgbm/__init__.py:45: FutureWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS will be built by the Apple Clang compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you won't need to install the gcc compiler anymore.
# Instead of that, you'll need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", FutureWarning)

# %% [markdown]
# ### Columns

# %%
cols_num = ['txn_dt', 'total_floor', 'building_complete_dt', 'parking_area', 'parking_price', 'txn_floor', 'land_area', 'building_area', 'lat', 'lon', 'village_income_median', 'town_population', 'town_area', 'town_population_density', 'doc_rate', 'master_rate', 'bachelor_rate', 'jobschool_rate', 'highschool_rate', 'junior_rate', 'elementary_rate', 'born_rate', 'death_rate', 'marriage_rate', 'divorce_rate', 'N_50', 'N_500', 'N_1000', 'N_5000', 'N_10000', 'I_10', 'I_50', 'I_100', 'I_250', 'I_500', 'I_1000', 'I_5000', 'I_10000', 'I_MIN', 'II_10', 'II_50', 'II_100', 'II_250', 'II_500', 'II_1000', 'II_5000', 'II_10000', 'II_MIN', 'III_10', 'III_50', 'III_100', 'III_250', 'III_500', 'III_1000', 'III_5000', 'III_10000', 'III_MIN', 'IV_10', 'IV_50', 'IV_100', 'IV_250', 'IV_500', 'IV_1000', 'IV_5000', 'IV_10000', 'IV_MIN', 'V_10', 'V_50', 'V_100', 'V_250', 'V_500', 'V_1000', 'V_5000', 'V_10000', 'V_MIN', 'VI_50', 'VI_100', 'VI_250', 'VI_500', 'VI_1000', 'VI_5000', 'VI_10000', 'VI_MIN', 'VII_10', 'VII_50', 'VII_100', 'VII_250', 'VII_500', 'VII_1000', 'VII_5000', 'VII_10000', 'VII_MIN', 'VIII_10', 'VIII_50', 'VIII_100', 'VIII_250', 'VIII_500', 'VIII_1000', 'VIII_5000', 'VIII_10000', 'VIII_MIN', 'IX_10', 'IX_50', 'IX_100', 'IX_250', 'IX_500', 'IX_1000', 'IX_5000', 'IX_10000', 'IX_MIN', 'X_10', 'X_50', 'X_100', 'X_250', 'X_500', 'X_1000', 'X_5000', 'X_10000', 'X_MIN', 'XI_10', 'XI_50', 'XI_100', 'XI_250', 'XI_500', 'XI_1000', 'XI_5000', 'XI_10000', 'XI_MIN', 'XII_10', 'XII_50', 'XII_100', 'XII_250', 'XII_500', 'XII_1000', 'XII_5000', 'XII_10000', 'XII_MIN', 'XIII_10', 'XIII_50', 'XIII_100', 'XIII_250', 'XIII_500', 'XIII_1000', 'XIII_5000', 'XIII_10000', 'XIII_MIN', 'XIV_10', 'XIV_50', 'XIV_100', 'XIV_250', 'XIV_500', 'XIV_1000', 'XIV_5000', 'XIV_10000', 'XIV_MIN']
cols_cat = ['building_material', 'city', 'building_type', 'building_use', 'parking_way', 'town', 'village']
cols_bin = ['I_index_50', 'I_index_500', 'I_index_1000', 'II_index_50', 'II_index_500', 'II_index_1000', 'III_index_50', 'III_index_500', 'III_index_1000', 'IV_index_50', 'IV_index_500', 'IV_index_1000', 'IV_index_5000', 'V_index_50', 'V_index_500', 'V_index_1000', 'VI_10', 'VI_index_50', 'VI_index_500', 'VI_index_1000', 'VII_index_50', 'VII_index_500', 'VII_index_1000', 'VIII_index_50', 'VIII_index_500', 'VIII_index_1000', 'IX_index_50', 'IX_index_500', 'IX_index_1000', 'IX_index_5000', 'X_index_50', 'X_index_500', 'X_index_1000', 'XI_index_50', 'XI_index_500', 'XI_index_1000', 'XI_index_5000', 'XI_index_10000', 'XII_index_50', 'XII_index_500', 'XII_index_1000', 'XIII_index_50', 'XIII_index_500', 'XIII_index_1000', 'XIII_index_5000', 'XIII_index_10000', 'XIV_index_50', 'XIV_index_500', 'XIV_index_1000']
cols_feats = cols_num + cols_cat + cols_bin

col_target = 'total_price'
col_target_log1p = 'target'

# %% [markdown]
# ### Read data

# %%
df = pd.read_csv('dataset/train.csv', dtype=object)

# %%
df.columns
# Out:
# Index(['building_id', 'building_material', 'city', 'txn_dt', 'total_floor',
#        'building_type', 'building_use', 'building_complete_dt', 'parking_way',
#        'parking_area',
#        ...
#        'XIV_500', 'XIV_index_500', 'XIV_1000', 'XIV_index_1000', 'XIV_5000',
#        'XIV_index_5000', 'XIV_10000', 'XIV_index_10000', 'XIV_MIN',
#        'total_price'],
#       dtype='object', length=235)

# %% [markdown]
# ### Preprocessing

# %%
# Convert types
df = convert_types(df, cols_num, col_target=col_target)

# Generate feats (train-test-same feats)
#create_feats(df)

# %% [markdown]
# ### Feat engineering

# %%
from feature_engineering import CategoricalColumnsEncoder

# %%
class FeatureEngineering():
    def __init__(self):
        pass
    
    def fit_transform(self, df, cols_cat, cols_bin):
        df = df.copy()
        # Denote categorical-type
        self.cat_encoder = CategoricalColumnsEncoder(mode='pandas')
        self.cat_encoder.fit_transform(df, cols_cat+cols_bin)
        return df
    
    def transform(self, df):
        df = df.copy()
        self.cat_encoder.transform(df)
        return df

# %% [markdown]
# ### Grid search

# %%
def custom_asymmetric_train(y_true, y_pred):
    residual = (y_true - y_pred).astype("float")
    grad = np.where(residual<0, -2*10.0*residual, -2*residual)
    hess = np.where(residual<0, 2*10.0, 2.0)
    return grad, hess

def hit_rate(y_pred, dataset_true):
    y_true = dataset_true.get_label()
    y_pred = np.clip(np.exp(y_pred.astype("float")) - 1, 0, None)
    y_true = np.clip(np.exp(y_true.astype("float")) - 1, 0, None)
    rate = np.mean(np.abs(y_pred - y_true) <= 0.1 * y_true)
    mape = np.mean(np.abs(y_pred - y_true) / y_true)
    return "hit_rate", np.round(rate, decimals=4)*10000 + (1-mape), False

# %%
# pars
is_log1p = True # if train on log1p target
# pars

# grid search
params_gsearch = {'task': ['train'],'boosting_type': ['gbdt'],
                  #'metric': [['mse', 'mae']],
                  'objective': ['mse'], # 'mae', 'mape'
                  'num_leaves': [255],
                  'learning_rate': [0.01],
                  'feature_fraction': [0.7],
                  'min_data_in_leaf': [20],
                  'lambda_l1': [0.1]}

params_gsearch = {'task': ['train'],'boosting_type': ['gbdt'],
                  #'metric': [['mse', 'mae']],
                  'objective': ['mse'], # 'mae', 'mape', 'regression'
                  'num_leaves': [255],
                  'learning_rate': [0.01],
                  'feature_fraction': [0.7],
                  'min_data_in_leaf': [20],
                  'lambda_l1': [0.1]}

params_names = params_gsearch.keys()

gsearch = {}
folds = KFold(n_splits=3)
for i_fold, (itrain, ival) in enumerate(folds.split(df)): # kfold
    print('==== Fold', i_fold+1, '====')
    
    # split train, val
    df_train = df.loc[itrain]
    df_val = df.loc[ival]
    
    # feat eng
    feat_eng = FeatureEngineering()
    df_train = feat_eng.fit_transform(df_train, cols_cat, cols_bin)
    df_val = feat_eng.transform(df_val)

    # Construct lgb dataset
    if is_log1p:
        lgb_train = lgb.Dataset(df_train[cols_feats], df_train['target']).construct()
        lgb_val = lgb.Dataset(df_val[cols_feats], df_val['target'], reference=lgb_train).construct()
    else:
        lgb_train = lgb.Dataset(df_train[cols_feats], df_train['total_price']).construct()
        lgb_val = lgb.Dataset(df_val[cols_feats], df_val['total_price'], reference=lgb_train).construct()
        
    # grid search
    for values in itertools.product(*[params_gsearch[key] for key in params_names]):
        params = dict(zip(params_names, values))
        print('params:', params)
        
        model = lgb.train(params, lgb_train,
                          num_boost_round=10000,
                          valid_sets=lgb_val,
                          verbose_eval=200,
                          #fobj=custom_asymmetric_train,
                          #feval=custom_asymmetric_valid,
                          feval=hit_rate,
                          #early_stopping_rounds=200,
                          )
        y_pred = model.predict(df_val[cols_feats])
        
        if is_log1p:
            y_pred_expm1 = np.expm1(y_pred)
            y_pred_final = np.clip(y_pred_expm1, 0, None)
        else:
            y_pred_final = y_pred
            
        score = cal_score(df_val['total_price'], y_pred_final)
        tuple_params = tuple(params.items())
        gsearch[tuple_params] = gsearch.get(tuple_params, []) + [score]

# aggregate, sort gsearch results
gsearch_results = [[key, np.mean(val), val] for key, val in gsearch.items()]
gsearch_results.sort(key= lambda x: x[1], reverse = True)
display(gsearch_results)
# Out:
# ==== Fold 1 ====
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'num_leaves': 255, 'learning_rate': 0.01, 'feature_fraction': 0.7, 'min_data_in_leaf': 20, 'lambda_l1': 0.1}
# [200]	valid_0's l2: 0.106711	valid_0's hit_rate: 2912.75
# [400]	valid_0's l2: 0.0567184	valid_0's hit_rate: 4294.83
# [600]	valid_0's l2: 0.0495915	valid_0's hit_rate: 4708.84
# [800]	valid_0's l2: 0.0469991	valid_0's hit_rate: 4904.85
# [1000]	valid_0's l2: 0.0457271	valid_0's hit_rate: 5026.85
# [1200]	valid_0's l2: 0.0449713	valid_0's hit_rate: 5114.85
# [1400]	valid_0's l2: 0.044516	valid_0's hit_rate: 5164.85
# [1600]	valid_0's l2: 0.044191	valid_0's hit_rate: 5212.85
# [1800]	valid_0's l2: 0.0439695	valid_0's hit_rate: 5260.85
# [2000]	valid_0's l2: 0.0438008	valid_0's hit_rate: 5283.85
# [2200]	valid_0's l2: 0.0436661	valid_0's hit_rate: 5320.85
# [2400]	valid_0's l2: 0.0435732	valid_0's hit_rate: 5332.86
# [2600]	valid_0's l2: 0.0434891	valid_0's hit_rate: 5349.86
# [2800]	valid_0's l2: 0.0434246	valid_0's hit_rate: 5364.86
# [3000]	valid_0's l2: 0.0433769	valid_0's hit_rate: 5372.86
# [3200]	valid_0's l2: 0.0433338	valid_0's hit_rate: 5385.86
# [3400]	valid_0's l2: 0.0432912	valid_0's hit_rate: 5404.86
# [3600]	valid_0's l2: 0.0432677	valid_0's hit_rate: 5409.86
# [3800]	valid_0's l2: 0.0432452	valid_0's hit_rate: 5414.86
# [4000]	valid_0's l2: 0.0432298	valid_0's hit_rate: 5417.86
# [4200]	valid_0's l2: 0.0432112	valid_0's hit_rate: 5416.86
# [4400]	valid_0's l2: 0.0431972	valid_0's hit_rate: 5423.86
# [4600]	valid_0's l2: 0.0431844	valid_0's hit_rate: 5429.86
# [4800]	valid_0's l2: 0.0431745	valid_0's hit_rate: 5429.86
# [5000]	valid_0's l2: 0.0431637	valid_0's hit_rate: 5426.86
# [5200]	valid_0's l2: 0.0431561	valid_0's hit_rate: 5430.86
# [5400]	valid_0's l2: 0.0431503	valid_0's hit_rate: 5440.86
# [5600]	valid_0's l2: 0.0431445	valid_0's hit_rate: 5438.86
# [5800]	valid_0's l2: 0.0431404	valid_0's hit_rate: 5438.86
# [6000]	valid_0's l2: 0.0431318	valid_0's hit_rate: 5442.86
# [6200]	valid_0's l2: 0.0431275	valid_0's hit_rate: 5448.86
# [6400]	valid_0's l2: 0.0431253	valid_0's hit_rate: 5450.86
# [6600]	valid_0's l2: 0.0431194	valid_0's hit_rate: 5448.86
# [6800]	valid_0's l2: 0.0431173	valid_0's hit_rate: 5448.86
# [7000]	valid_0's l2: 0.0431171	valid_0's hit_rate: 5450.86
# [7200]	valid_0's l2: 0.0431162	valid_0's hit_rate: 5448.86
# [7400]	valid_0's l2: 0.0431134	valid_0's hit_rate: 5447.86
# [7600]	valid_0's l2: 0.0431101	valid_0's hit_rate: 5449.86
# [7800]	valid_0's l2: 0.0431095	valid_0's hit_rate: 5448.86
# [8000]	valid_0's l2: 0.0431084	valid_0's hit_rate: 5450.86
# [8200]	valid_0's l2: 0.0431084	valid_0's hit_rate: 5448.86
# [8400]	valid_0's l2: 0.0431071	valid_0's hit_rate: 5449.86
# [8600]	valid_0's l2: 0.0431053	valid_0's hit_rate: 5451.86
# [8800]	valid_0's l2: 0.0431045	valid_0's hit_rate: 5450.86
# [9000]	valid_0's l2: 0.0431049	valid_0's hit_rate: 5450.86
# [9200]	valid_0's l2: 0.0431043	valid_0's hit_rate: 5446.86
# [9400]	valid_0's l2: 0.0431036	valid_0's hit_rate: 5446.86
# [9600]	valid_0's l2: 0.043102	valid_0's hit_rate: 5448.86
# [9800]	valid_0's l2: 0.043101	valid_0's hit_rate: 5447.86
# [10000]	valid_0's l2: 0.0431001	valid_0's hit_rate: 5446.86
# ==== Fold 2 ====
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'num_leaves': 255, 'learning_rate': 0.01, 'feature_fraction': 0.7, 'min_data_in_leaf': 20, 'lambda_l1': 0.1}
# [200]	valid_0's l2: 0.104488	valid_0's hit_rate: 2934.75
# [400]	valid_0's l2: 0.0561633	valid_0's hit_rate: 4349.83
# [600]	valid_0's l2: 0.0493982	valid_0's hit_rate: 4782.84
# [800]	valid_0's l2: 0.0467835	valid_0's hit_rate: 4984.85
# [1000]	valid_0's l2: 0.045375	valid_0's hit_rate: 5120.85
# [1200]	valid_0's l2: 0.0445743	valid_0's hit_rate: 5199.85
# [1400]	valid_0's l2: 0.044068	valid_0's hit_rate: 5270.86
# [1600]	valid_0's l2: 0.0437303	valid_0's hit_rate: 5302.86
# [1800]	valid_0's l2: 0.0434549	valid_0's hit_rate: 5359.86
# [2000]	valid_0's l2: 0.0432681	valid_0's hit_rate: 5384.86
# [2200]	valid_0's l2: 0.0431106	valid_0's hit_rate: 5404.86
# [2400]	valid_0's l2: 0.0429922	valid_0's hit_rate: 5430.86
# [2600]	valid_0's l2: 0.0428847	valid_0's hit_rate: 5446.86
# [2800]	valid_0's l2: 0.042798	valid_0's hit_rate: 5470.86
# [3000]	valid_0's l2: 0.0427245	valid_0's hit_rate: 5482.86
# [3200]	valid_0's l2: 0.0426773	valid_0's hit_rate: 5488.86
# [3400]	valid_0's l2: 0.0426353	valid_0's hit_rate: 5492.86
# [3600]	valid_0's l2: 0.0426051	valid_0's hit_rate: 5504.86
# [3800]	valid_0's l2: 0.0425751	valid_0's hit_rate: 5513.86
# [4000]	valid_0's l2: 0.0425463	valid_0's hit_rate: 5522.86
# [4200]	valid_0's l2: 0.0425276	valid_0's hit_rate: 5522.86
# [4400]	valid_0's l2: 0.0425104	valid_0's hit_rate: 5526.86
# [4600]	valid_0's l2: 0.042497	valid_0's hit_rate: 5530.86
# [4800]	valid_0's l2: 0.0424844	valid_0's hit_rate: 5540.86
# [5000]	valid_0's l2: 0.042478	valid_0's hit_rate: 5538.86
# [5200]	valid_0's l2: 0.042472	valid_0's hit_rate: 5539.86
# [5400]	valid_0's l2: 0.0424633	valid_0's hit_rate: 5546.86
# [5600]	valid_0's l2: 0.0424549	valid_0's hit_rate: 5550.86
# [5800]	valid_0's l2: 0.0424491	valid_0's hit_rate: 5549.86
# [6000]	valid_0's l2: 0.0424447	valid_0's hit_rate: 5546.86
# [6200]	valid_0's l2: 0.0424434	valid_0's hit_rate: 5550.86
# [6400]	valid_0's l2: 0.0424415	valid_0's hit_rate: 5552.86
# [6600]	valid_0's l2: 0.0424389	valid_0's hit_rate: 5549.86
# [6800]	valid_0's l2: 0.0424384	valid_0's hit_rate: 5548.86
# [7000]	valid_0's l2: 0.0424356	valid_0's hit_rate: 5548.86
# [7200]	valid_0's l2: 0.0424352	valid_0's hit_rate: 5550.86
# [7400]	valid_0's l2: 0.042437	valid_0's hit_rate: 5546.86
# [7600]	valid_0's l2: 0.042435	valid_0's hit_rate: 5548.86
# [7800]	valid_0's l2: 0.0424363	valid_0's hit_rate: 5547.86
# [8000]	valid_0's l2: 0.0424356	valid_0's hit_rate: 5547.86
# [8200]	valid_0's l2: 0.042436	valid_0's hit_rate: 5543.86
# [8400]	valid_0's l2: 0.0424373	valid_0's hit_rate: 5540.86
# [8600]	valid_0's l2: 0.0424371	valid_0's hit_rate: 5542.86
# [8800]	valid_0's l2: 0.042436	valid_0's hit_rate: 5546.86
# [9000]	valid_0's l2: 0.0424367	valid_0's hit_rate: 5548.86
# [9200]	valid_0's l2: 0.0424363	valid_0's hit_rate: 5549.86
# [9400]	valid_0's l2: 0.0424368	valid_0's hit_rate: 5550.86
# [9600]	valid_0's l2: 0.0424374	valid_0's hit_rate: 5550.86
# [9800]	valid_0's l2: 0.0424388	valid_0's hit_rate: 5550.86
# [10000]	valid_0's l2: 0.0424397	valid_0's hit_rate: 5554.86
# ==== Fold 3 ====
# params: {'task': 'train', 'boosting_type': 'gbdt', 'objective': 'mse', 'num_leaves': 255, 'learning_rate': 0.01, 'feature_fraction': 0.7, 'min_data_in_leaf': 20, 'lambda_l1': 0.1}
# [200]	valid_0's l2: 0.105088	valid_0's hit_rate: 2866.75
# [400]	valid_0's l2: 0.055675	valid_0's hit_rate: 4298.83
# [600]	valid_0's l2: 0.0489187	valid_0's hit_rate: 4671.85
# [800]	valid_0's l2: 0.0464269	valid_0's hit_rate: 4844.85
# [1000]	valid_0's l2: 0.0452293	valid_0's hit_rate: 4998.85
# [1200]	valid_0's l2: 0.0444814	valid_0's hit_rate: 5079.86
# [1400]	valid_0's l2: 0.0440825	valid_0's hit_rate: 5142.86
# [1600]	valid_0's l2: 0.0438066	valid_0's hit_rate: 5198.86
# [1800]	valid_0's l2: 0.0435931	valid_0's hit_rate: 5231.86
# [2000]	valid_0's l2: 0.0434372	valid_0's hit_rate: 5256.86
# [2200]	valid_0's l2: 0.0433266	valid_0's hit_rate: 5288.86
# [2400]	valid_0's l2: 0.0432452	valid_0's hit_rate: 5310.86
# [2600]	valid_0's l2: 0.0431834	valid_0's hit_rate: 5321.86
# [2800]	valid_0's l2: 0.0431321	valid_0's hit_rate: 5347.86
# [3000]	valid_0's l2: 0.0430875	valid_0's hit_rate: 5357.86
# [3200]	valid_0's l2: 0.0430507	valid_0's hit_rate: 5370.86
# [3400]	valid_0's l2: 0.0430246	valid_0's hit_rate: 5384.86
# [3600]	valid_0's l2: 0.0430003	valid_0's hit_rate: 5387.86
# [3800]	valid_0's l2: 0.0429887	valid_0's hit_rate: 5390.86
# [4000]	valid_0's l2: 0.0429811	valid_0's hit_rate: 5392.86
# [4200]	valid_0's l2: 0.0429657	valid_0's hit_rate: 5399.86
# [4400]	valid_0's l2: 0.0429589	valid_0's hit_rate: 5414.86
# [4600]	valid_0's l2: 0.0429508	valid_0's hit_rate: 5419.86
# [4800]	valid_0's l2: 0.0429488	valid_0's hit_rate: 5420.86
# [5000]	valid_0's l2: 0.0429506	valid_0's hit_rate: 5418.86
# [5200]	valid_0's l2: 0.0429489	valid_0's hit_rate: 5416.86
# [5400]	valid_0's l2: 0.0429468	valid_0's hit_rate: 5422.86
# [5600]	valid_0's l2: 0.0429451	valid_0's hit_rate: 5424.86
# [5800]	valid_0's l2: 0.0429439	valid_0's hit_rate: 5426.86
# [6000]	valid_0's l2: 0.0429445	valid_0's hit_rate: 5434.86
# [6200]	valid_0's l2: 0.0429463	valid_0's hit_rate: 5436.86
# [6400]	valid_0's l2: 0.0429458	valid_0's hit_rate: 5438.86
# [6600]	valid_0's l2: 0.042946	valid_0's hit_rate: 5438.86
# [6800]	valid_0's l2: 0.0429444	valid_0's hit_rate: 5440.86
# [7000]	valid_0's l2: 0.0429479	valid_0's hit_rate: 5440.86
# [7200]	valid_0's l2: 0.0429502	valid_0's hit_rate: 5441.86
# [7400]	valid_0's l2: 0.0429503	valid_0's hit_rate: 5444.86
# [7600]	valid_0's l2: 0.0429513	valid_0's hit_rate: 5450.86
# [7800]	valid_0's l2: 0.042952	valid_0's hit_rate: 5444.86
# [8000]	valid_0's l2: 0.0429527	valid_0's hit_rate: 5448.86
# [8200]	valid_0's l2: 0.0429538	valid_0's hit_rate: 5448.86
# [8400]	valid_0's l2: 0.0429552	valid_0's hit_rate: 5448.86
# [8600]	valid_0's l2: 0.0429545	valid_0's hit_rate: 5443.86
# [8800]	valid_0's l2: 0.0429546	valid_0's hit_rate: 5446.86
# [9000]	valid_0's l2: 0.0429546	valid_0's hit_rate: 5444.86
# [9200]	valid_0's l2: 0.0429546	valid_0's hit_rate: 5445.86
# [9400]	valid_0's l2: 0.0429559	valid_0's hit_rate: 5445.86
# [9600]	valid_0's l2: 0.0429571	valid_0's hit_rate: 5444.86
# [9800]	valid_0's l2: 0.0429582	valid_0's hit_rate: 5444.86
# [10000]	valid_0's l2: 0.0429588	valid_0's hit_rate: 5444.86
# [[(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5482.19485441842,
#   [5449.8584886062135, 5554.862112396429, 5441.863962252616]]]

# %%
display(gsearch_results)
# Out:
# [[(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5023.182736892787,
#   [5014.8459736956465, 5000.84919448768, 5053.853042495033]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5026.183789802272,
#   [5038.847251680061, 5016.850701760834, 5022.853415965921]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5028.84949301197,
#   [5020.8461883311675, 5016.849252355429, 5048.853038349313]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5029.515981733999,
#   [5028.845935476341, 5014.849325185851, 5044.852684539805]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5061.185163377122,
#   [5042.847915836736, 5087.852222661738, 5052.855351632893]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5061.517370066363,
#   [5048.84753221264, 5074.851020546955, 5060.853557439496]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5061.849611276552,
#   [5047.845008434154, 5059.850580238533, 5077.853245156969]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5063.18411972004,
#   [5056.847791594149, 5075.851100801499, 5056.853466764471]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5063.518368996546,
#   [5042.847835024761, 5102.8521449641685, 5044.855127000708]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5064.182774225271,
#   [5028.84496424926, 5074.850024286722, 5088.853334139829]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5064.851781242386,
#   [5056.847751907599, 5088.852332431127, 5048.855259388434]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5079.853072300993,
#   [5073.848964939022, 5132.853895278646, 5032.856356685307]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5087.853279970792,
#   [5087.849362683311, 5132.854044474116, 5042.856432754948]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5088.852897204494,
#   [5074.848954669152, 5130.853786631916, 5060.855950312416]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5091.186567665991,
#   [5090.849292514758, 5140.853895858782, 5041.856514624434]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5091.515224408798,
#   [5128.845501346741, 5128.849016279555, 5016.851155600096]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5092.850009410556,
#   [5050.845024283073, 5105.850928325586, 5121.854075623007]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5095.186220631843,
#   [5070.849114547782, 5142.853683156331, 5071.855864191414]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5095.516340050995,
#   [5044.845065050615, 5182.851151087212, 5058.852804015155]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5096.852812844696,
#   [5099.848979846671, 5120.85343452912, 5069.856024158295]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5100.182079447667,
#   [5118.845341508692, 5100.84910544337, 5080.85179139094]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5102.187329683767,
#   [5083.849513739034, 5164.855307299631, 5057.857168012637]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5103.515810771431,
#   [5154.846249053898, 5118.849655714478, 5036.851527545915]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5107.515334943978,
#   [5102.8454334315165, 5145.848695173265, 5073.8518762271515]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5123.183249639459,
#   [5130.846408742339, 5167.850543059521, 5070.852797116517]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5124.183395154625,
#   [5104.845869533456, 5162.850594853459, 5104.85372107696]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5128.516130786023,
#   [5127.845316514697, 5144.850208104249, 5112.852867739123]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5128.520887259844,
#   [5094.849417362966, 5194.8556698782195, 5095.857574538346]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5129.84942533212,
#   [5130.846450696445, 5172.850282837258, 5085.851542462655]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5135.184198026158,
#   [5144.846737074249, 5150.851508128449, 5109.854348875777]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5135.850399228472,
#   [5164.847130835843, 5157.850712588851, 5084.853354260725]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5137.187535062089,
#   [5125.849567189588, 5186.8553695334085, 5098.857668463272]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5138.184070715161,
#   [5136.847231892987, 5162.850829678324, 5114.854150574172]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5139.848761933043,
#   [5077.845542240573, 5226.849543042635, 5114.851200515919]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5151.85123376652,
#   [5124.8478791253365, 5198.851730483778, 5131.854091690447]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5162.185042274945,
#   [5162.848549156607, 5184.852067802114, 5138.854509866113]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5163.184895942407,
#   [5167.847943812035, 5230.852845945416, 5090.853898069771]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5163.517828585117,
#   [5164.84714298027, 5200.851994162196, 5124.854348612884]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5163.85143245641,
#   [5188.849088026773, 5193.852552952897, 5108.852656389561]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5164.185207875162,
#   [5150.84833543091, 5188.852256122843, 5152.855032071734]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5164.517742824242,
#   [5170.8483517963605, 5186.851770639544, 5135.853106036823]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5164.851445754648,
#   [5122.847551186212, 5220.852206151809, 5150.854579925922]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5166.51847021354,
#   [5135.847970946269, 5224.852901979432, 5138.85453771492]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5169.851467949784,
#   [5138.847431850067, 5204.85239390412, 5165.854578095166]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5170.518380345219,
#   [5173.84886457855, 5206.8520592109, 5130.8542172462085]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5173.184933584666,
#   [5130.847875379684, 5249.852469111958, 5138.854456262357]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5173.185309957857,
#   [5149.8479504786765, 5226.853711423284, 5142.85426797161]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5173.518734201223,
#   [5128.847602156089, 5240.853134912062, 5150.855465535518]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5174.516299842139,
#   [5139.845923829532, 5218.850003295574, 5164.852972401311]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5182.185074967819,
#   [5150.846943558983, 5218.852804976418, 5176.855476368054]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5183.518587434665,
#   [5190.848553967961, 5218.852949709066, 5140.85425862697]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5185.185121047075,
#   [5135.847511850407, 5258.852901309136, 5160.854949981683]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5187.852836157676,
#   [5163.84864027853, 5246.853687127526, 5152.856181066973]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5188.185124123379,
#   [5202.847759579512, 5240.85270188589, 5120.854910904734]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5188.5189655826925,
#   [5183.848686646756, 5212.853285103428, 5168.854924997895]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5190.8491841282,
#   [5160.845139327808, 5261.850074045978, 5149.852339010813]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5191.852803946756,
#   [5144.849890023103, 5223.852658757246, 5206.855863059918]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5193.185893912904,
#   [5180.849450238768, 5214.852565102851, 5183.855666397093]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5195.8536936930905,
#   [5162.850477609785, 5266.8542153579, 5157.856388111587]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5196.186699647551,
#   [5180.849359133851, 5257.853662609884, 5149.857077198917]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5196.852199916389,
#   [5188.848453857209, 5238.8531990053225, 5162.854946886633]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5197.186213495921,
#   [5164.850258000755, 5226.852715014942, 5199.855667472066]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5199.852304380637,
#   [5158.848557192056, 5239.853121864016, 5200.855234085838]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5200.185364978326,
#   [5194.847938226786, 5254.852476022614, 5150.855680685579]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5204.518757695573,
#   [5172.8484354435595, 5257.852960421412, 5182.854877221748]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5206.853111785857,
#   [5122.848426149675, 5306.854658431659, 5190.856250776236]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5210.187081557998,
#   [5170.849331517521, 5270.85457954081, 5188.8573336156605]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5211.51962193065,
#   [5210.849044676908, 5220.853636882048, 5202.856184232993]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5212.187103481871,
#   [5185.850315453853, 5270.854686019547, 5179.856308972214]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5213.18742502449,
#   [5212.850748136208, 5228.854470253416, 5197.857056683847]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5214.186986592032,
#   [5206.849210692544, 5250.854650728603, 5184.857098354949]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5214.852351260238,
#   [5190.848790780979, 5269.853358055088, 5183.854904944647]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5219.187165359473,
#   [5157.849196659079, 5272.854942701793, 5226.857356717546]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5219.519621395112,
#   [5192.848175299666, 5294.853460552618, 5170.857228333051]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5223.186681286811,
#   [5193.849763532452, 5282.854637793681, 5192.855642534301]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5226.185773171885,
#   [5212.850126464429, 5258.852429048843, 5206.8547640023835]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5228.520974000092,
#   [5192.85042168943, 5253.854587003069, 5238.8579133077765]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5230.519167330336,
#   [5224.849378898788, 5264.853255800269, 5201.854867291951]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5231.851319379778,
#   [5209.848129327362, 5255.85187031682, 5229.853958495155]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5233.187074580895,
#   [5222.849493781393, 5268.853621833285, 5207.858108128007]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5238.5200578331305,
#   [5221.8478543516385, 5270.854508275882, 5222.857810871871]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5241.187787308324,
#   [5218.851166819788, 5280.854880979149, 5223.857314126035]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5241.52085304135,
#   [5242.850552090396, 5268.854826663163, 5212.857180370492]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5243.185531418078,
#   [5253.849897600899, 5287.852416385321, 5187.854280268015]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5244.187779020417,
#   [5227.851430977212, 5313.8549970576505, 5190.856909026389]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5247.855539884432,
#   [5212.851083159526, 5312.857085166884, 5217.858451326886]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5249.518832468125,
#   [5276.849453842398, 5276.852612727201, 5194.8544308347755]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5250.187621286707,
#   [5234.850318405961, 5278.855433414045, 5236.857112040117]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5252.522487985864,
#   [5249.851937388092, 5302.856384675658, 5204.859141893842]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5257.188094340733,
#   [5228.851720350853, 5284.855233447131, 5257.8573292242145]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5257.854285179862,
#   [5258.851212944981, 5291.855157222778, 5222.856485371827]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5259.189150692288,
#   [5235.851620883256, 5316.857076193419, 5224.85875500019]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.1),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5259.852205237461,
#   [5262.849131103664, 5305.85273193972, 5210.854752668999]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5261.854831251899,
#   [5250.85059857128, 5317.855578317647, 5216.858316866768]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5267.5188635438835,
#   [5218.848368766195, 5320.853185836779, 5262.855036028677]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5270.189313304294,
#   [5274.8522569597035, 5290.856266982724, 5244.859415970456]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5271.522611684722,
#   [5266.852055338078, 5308.856374596283, 5238.859405119802]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5272.852604504981,
#   [5242.849428380779, 5336.853310152238, 5238.855074981926]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5273.855330070764,
#   [5240.851112989633, 5331.856015111907, 5248.858862110748]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5274.521658466934,
#   [5252.850412609516, 5314.85555591374, 5255.859006877547]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5276.854609080859,
#   [5284.851576427385, 5314.855344898907, 5230.8569059162855]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5277.189336622444,
#   [5262.851620158521, 5329.856999503551, 5238.85939020526]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5277.522013829403,
#   [5258.851023593192, 5346.856787426139, 5226.858230468876]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5277.8549175286835,
#   [5258.8518167317925, 5317.855743499154, 5256.857192355104]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5278.520945808027,
#   [5238.85060113309, 5343.855390394977, 5252.856845896014]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5278.52309636394,
#   [5232.852381057966, 5352.857873534233, 5249.859034499621]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5280.5227659678685,
#   [5244.852277686657, 5333.857304963334, 5262.8587152536165]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5280.524377536212,
#   [5279.853872713578, 5300.858538639907, 5260.860721255152]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5286.188459539307,
#   [5290.85281877953, 5328.855524293884, 5238.857035544508]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5287.522319750534,
#   [5250.851107540448, 5360.856528918099, 5250.859322793056]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5292.855241527452,
#   [5263.851068477048, 5360.856192133866, 5253.858463971441]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5298.858008424795,
#   [5274.853764232769, 5344.859212997478, 5276.861048044139]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5301.190410543131,
#   [5260.85311749884, 5356.858417529136, 5285.859696601417]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5302.857994283867,
#   [5294.853962921641, 5341.858994217334, 5271.861025712628]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5303.1906618521225,
#   [5293.853191786555, 5353.857984511872, 5261.86080925794]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5304.18864038793,
#   [5293.850789724242, 5337.856304368955, 5280.858827070593]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5308.522997526177,
#   [5295.852486951366, 5334.85691456651, 5294.859591060656]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5312.85641388129,
#   [5288.852155292326, 5367.857724125881, 5281.859362225662]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5313.523009195691,
#   [5299.852267424944, 5396.857392148656, 5243.859368013472]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5317.523833679991,
#   [5290.852931922155, 5402.858754510203, 5258.8598146076165]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5317.5255977568095,
#   [5292.854704765424, 5354.860260800383, 5304.861827704622]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5318.190200094899,
#   [5299.852194441386, 5388.858124728667, 5265.860281114647]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5318.85809854862,
#   [5308.854424647611, 5394.859079883834, 5252.860791114413]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5319.191097956545,
#   [5312.853939007434, 5372.858596431441, 5271.860758430761]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5319.520878525891,
#   [5284.851271302911, 5380.854837323943, 5292.856526950818]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5321.854091025019,
#   [5305.851194513423, 5376.854582418296, 5282.85649614334]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5322.189611353263,
#   [5316.850700648599, 5366.857621278662, 5282.860512132527]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5324.187545358886,
#   [5304.850348193099, 5381.855053088816, 5285.857234794742]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5328.18978566652,
#   [5300.852557256585, 5354.857292484279, 5328.859507258696]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5328.855541292108,
#   [5300.852944815441, 5390.856289283877, 5294.857389777006]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5328.856404899995,
#   [5314.852841050146, 5346.857311673396, 5324.859061976443]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5333.854182489856,
#   [5296.850568604622, 5417.85505121137, 5286.856927653574]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5335.190319281854,
#   [5299.851653604692, 5396.858256040137, 5308.861048200732]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5337.857882648373,
#   [5333.853471137318, 5374.859282512561, 5304.86089429524]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5341.855825612727,
#   [5321.852961642614, 5396.856214536945, 5306.858300658621]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5344.523428028547,
#   [5298.85348426516, 5430.857805462058, 5303.858994358423]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5345.523015485171,
#   [5307.852238052747, 5419.85750519212, 5308.859303210644]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5346.524431530155,
#   [5334.853594249896, 5388.858982274843, 5315.860718065727]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5348.524223872172,
#   [5296.853359279886, 5447.8586430740725, 5300.860669262558]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5350.859709293115,
#   [5329.855491168371, 5410.861248021257, 5311.862388689714]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 31),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5354.190473401232,
#   [5357.85178789923, 5394.858578676308, 5309.861053628159]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5359.8577981352855,
#   [5320.853207366027, 5428.859275926296, 5329.860911113534]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5361.526357025511,
#   [5352.855383415424, 5426.861207728402, 5304.862479932707]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5371.189460861276,
#   [5308.852707702953, 5424.856834739548, 5379.858840141326]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5377.191935430753,
#   [5327.854264286582, 5451.860309391925, 5351.861232613753]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 63),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5378.525602524715,
#   [5380.8553195283575, 5431.860191274752, 5322.861296771039]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5386.1922439952805,
#   [5346.855265902674, 5453.860038770365, 5357.861427312805]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5402.859590815048,
#   [5361.855687936169, 5479.860872860576, 5366.8622116484]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.05),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5406.192157830399,
#   [5362.855628460701, 5474.859561488891, 5380.861283541605]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5409.524115729254,
#   [5344.854423761511, 5503.858280913313, 5379.859642512937]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 1.0),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5415.5241648917345,
#   [5382.854838694745, 5477.857783167399, 5385.859872813058]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 1)),
#   5419.192186575617,
#   [5402.854999269098, 5496.859675195641, 5357.86188526211]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5419.193726410874,
#   [5372.856735842055, 5482.861598233919, 5401.862845156649]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5421.860431425669,
#   [5367.856637756439, 5492.861681914439, 5404.862974606126]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0.1)),
#   5425.526117749989,
#   [5397.855926017928, 5470.860083752386, 5407.862343479651]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 100),
#    ('lambda_l1', 0)),
#   5431.859281412991,
#   [5392.855867130822, 5487.860027455996, 5414.861949652153]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5440.194142761986,
#   [5426.856856343162, 5516.8623405777935, 5376.8632313650005]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5449.195118292196,
#   [5422.857996661213, 5516.863151849006, 5407.864206366367]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 1)),
#   5450.860319016889,
#   [5400.856447461234, 5534.861366734114, 5416.863142855318]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.4),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5460.195157528567,
#   [5444.858060942816, 5542.863203624898, 5392.864208017986]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0)),
#   5477.861453760545,
#   [5456.858328294146, 5545.86217192456, 5430.863861062928]],
#  [(('task', 'train'),
#    ('boosting_type', 'gbdt'),
#    ('metric', 'mae'),
#    ('objective', 'mse'),
#    ('num_leaves', 255),
#    ('learning_rate', 0.01),
#    ('feature_fraction', 0.7),
#    ('min_data_in_leaf', 20),
#    ('lambda_l1', 0.1)),
#   5481.861521114605,
#   [5449.8584886062135, 5554.862112396429, 5440.863962341173]]]
